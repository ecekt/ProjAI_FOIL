# %%
import pandas as pd
import json
from collections import defaultdict
import csv
from argparse import ArgumentParser
import numpy as np
import tensorflow as tf
from keras.preprocessing.sequence import pad_sequences
from keras.utils import Progbar
from random import randint

from scipy import stats
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

import itertools

from nltk.stem.wordnet import WordNetLemmatizer
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import inflect

# %matplotlib inline

import sys

sys.path.append('/home/ece/Desktop/nlp/vqa/FOIL-resources/coco/PythonAPI')
sys.path.append('/home/ece/Desktop/nlp/vqa/FOIL-resources/coco/PythonAPI/pycocotools/')

from pycocotools.coco import COCO

import json
from pprint import pprint
import re
import nltk
import copy
import random
import math
from sklearn.feature_extraction.text import CountVectorizer
import numpy as np
import pickle
import os.path

from mosestokenizer import *
tokenize = MosesTokenizer('en')
# Out:
# Using TensorFlow backend.

# %%
preprocessed_foil_train = pd.read_csv(
    "foil_train.tsv",
    sep="\t",
    names=["label", "caption", "jpg"]
)

foil_words = set()
with open("foilv1.0_train2017.json") as in_file:
    foil_train = json.load(in_file)
    for annotation in foil_train["annotations"]:
        foil_words.add(annotation["foil_word"])

# %%
foil_train
# Out:
# {'annotations': [{'caption': 'A long restaurant table with rattan rounded back chairs.',
#    'foil_id': 2000001,
#    'foil_word': 'ORIG',
#    'id': 789366,
#    'image_id': 57870,
#    'target_word': 'ORIG'},
#   {'caption': 'a long table with a plant on top of it surrounded with wooden chairs ',
#    'foil_id': 2000002,
#    'foil_word': 'ORIG',
#    'id': 789888,
#    'image_id': 57870,
#    'target_word': 'ORIG'},
#   {'caption': 'A restaurant has modern wooden tables and chairs.',
#    'foil_id': 2000004,
#    'foil_word': 'ORIG',
#    'id': 787980,
#    'image_id': 57870,
#    'target_word': 'ORIG'},
#   {'caption': 'a chair is adorned with wooden chairs with blue accents.',
#    'foil_id': 2000005,
#    'foil_word': 'chair',
#    'id': 794853,
#    'image_id': 57870,
#    'target_word': 'table'},
#   {'caption': 'a long toilet with a flower arrangement in the middle for meetings',
#    'foil_id': 2000006,
#    'foil_word': 'toilet',
#    'id': 791316,
#    'image_id': 57870,
#    'target_word': 'table'},
#   {'caption': 'a person standing inside of a phone booth ',
#    'foil_id': 2000007,
#    'foil_word': 'ORIG',
#    'id': 814735,
#    'image_id': 222016,
#    'target_word': 'ORIG'},
#   {'caption': 'a big red telephone booth that a man is standing in',
#    'foil_id': 2000008,
#    'foil_word': 'ORIG',
#    'id': 813979,
#    'image_id': 222016,
#    'target_word': 'ORIG'},
#   {'caption': 'a man using a keyboard in a phone booth.',
#    'foil_id': 2000010,
#    'foil_word': 'keyboard',
#    'id': 817379,
#    'image_id': 222016,
#    'target_word': 'phone'},
#   {'caption': 'a man is standing in a red keyboard booth.',
#    'foil_id': 2000011,
#    'foil_word': 'keyboard',
#    'id': 816950,
#    'image_id': 222016,
#    'target_word': 'phone'},
#   {'caption': 'this is an image of a man in a laptop booth.',
#    'foil_id': 2000013,
#    'foil_word': 'laptop',
#    'id': 816446,
#    'image_id': 222016,
#    'target_word': 'phone'},
#   {'caption': 'A small kitchen that utilizes all of its space. ',
#    'foil_id': 2000014,
#    'foil_word': 'ORIG',
#    'id': 638287,
#    'image_id': 520950,
#    'target_word': 'ORIG'},
#   {'caption': 'a kitchen with counter, toaster and other accessories.',
#    'foil_id': 2000015,
#    'foil_word': 'toaster',
#    'id': 638152,
#    'image_id': 520950,
#    'target_word': 'oven'},
#   {'caption': ' A man smiling and walking through a doorway.',
#    'foil_id': 2000017,
#    'foil_word': 'ORIG',
#    'id': 263365,
#    'image_id': 547471,
#    'target_word': 'ORIG'},
#   {'caption': 'a black and white photo of a man in suit and suitcase.',
#    'foil_id': 2000019,
#    'foil_word': 'suitcase',
#    'id': 265939,
#    'image_id': 547471,
#    'target_word': 'tie'},
#   {'caption': 'The clock has a large face with numbers.',
#    'foil_id': 2000021,
#    'foil_word': 'ORIG',
#    'id': 392777,
#    'image_id': 122688,
#    'target_word': 'ORIG'},
#   {'caption': 'A table and chairs with a large clock on the wall.',
#    'foil_id': 2000023,
#    'foil_word': 'ORIG',
#    'id': 397142,
#    'image_id': 122688,
#    'target_word': 'ORIG'},
#   {'caption': 'a large clock on the wall above a radiator ',
#    'foil_id': 2000024,
#    'foil_word': 'ORIG',
#    'id': 398966,
#    'image_id': 122688,
#    'target_word': 'ORIG'},
#   {'caption': 'a clock with big numbers at the end of a chair',
#    'foil_id': 2000025,
#    'foil_word': 'chair',
#    'id': 394802,
#    'image_id': 122688,
#    'target_word': 'table'},
#   {'caption': 'the huge vase on the wall is near a wooden table.',
#    'foil_id': 2000027,
#    'foil_word': 'vase',
#    'id': 390926,
#    'image_id': 122688,
#    'target_word': 'clock'},
#   {'caption': 'A group of people standing next to a yellow and blue double decker bus.',
#    'foil_id': 2000028,
#    'foil_word': 'ORIG',
#    'id': 566641,
#    'image_id': 392136,
#    'target_word': 'ORIG'},
#   {'caption': 'Several people are standing on the sidewalk as a bus goes by.',
#    'foil_id': 2000029,
#    'foil_word': 'ORIG',
#    'id': 565456,
#    'image_id': 392136,
#    'target_word': 'ORIG'},
#   {'caption': 'motorcycle rushing by a group of people walking in a city.',
#    'foil_id': 2000030,
#    'foil_word': 'motorcycle',
#    'id': 566152,
#    'image_id': 392136,
#    'target_word': 'bus'},
#   {'caption': 'a double-decker car moving down the street as people stand waiting.',
#    'foil_id': 2000031,
#    'foil_word': 'car',
#    'id': 566413,
#    'image_id': 392136,
#    'target_word': 'bus'},
#   {'caption': 'a large airplane and some people on the street.',
#    'foil_id': 2000032,
#    'foil_word': 'airplane',
#    'id': 562912,
#    'image_id': 392136,
#    'target_word': 'bus'},
#   {'caption': 'A bicycle parked in a kitchen with a stove and cabinets.',
#    'foil_id': 2000034,
#    'foil_word': 'ORIG',
#    'id': 276123,
#    'image_id': 398494,
#    'target_word': 'ORIG'},
#   {'caption': 'A bicycle leaning on the stove and cabinets located inside the kitchen.',
#    'foil_id': 2000035,
#    'foil_word': 'ORIG',
#    'id': 279687,
#    'image_id': 398494,
#    'target_word': 'ORIG'},
#   {'caption': 'A black bicycle leaning against the kitchen cabinets.',
#    'foil_id': 2000036,
#    'foil_word': 'ORIG',
#    'id': 278571,
#    'image_id': 398494,
#    'target_word': 'ORIG'},
#   {'caption': 'a car parked in a kitchen by the stove.',
#    'foil_id': 2000038,
#    'foil_word': 'car',
#    'id': 282204,
#    'image_id': 398494,
#    'target_word': 'bicycle'},
#   {'caption': 'small white kitchen with a bike and tie parked in it',
#    'foil_id': 2000040,
#    'foil_word': 'tie',
#    'id': 279294,
#    'image_id': 398494,
#    'target_word': 'backpack'},
#   {'caption': 'A man in a beanie and glasses leans over a counter.',
#    'foil_id': 2000042,
#    'foil_word': 'ORIG',
#    'id': 331068,
#    'image_id': 90570,
#    'target_word': 'ORIG'},
#   {'caption': 'a man with a beard and a blue shirt is making some food',
#    'foil_id': 2000043,
#    'foil_word': 'ORIG',
#    'id': 337434,
#    'image_id': 90570,
#    'target_word': 'ORIG'},
#   {'caption': 'a person working behind the counter of a food motorcycle.',
#    'foil_id': 2000045,
#    'foil_word': 'motorcycle',
#    'id': 340272,
#    'image_id': 90570,
#    'target_word': 'truck'},
#   {'caption': 'two people in a food train, one looking at an order.',
#    'foil_id': 2000046,
#    'foil_word': 'train',
#    'id': 329613,
#    'image_id': 90570,
#    'target_word': 'truck'},
#   {'caption': 'a person in white is standing in a kitchen',
#    'foil_id': 2000047,
#    'foil_word': 'ORIG',
#    'id': 669465,
#    'image_id': 504616,
#    'target_word': 'ORIG'},
#   {'caption': 'The baker is getting ready for his bread to be ready.',
#    'foil_id': 2000048,
#    'foil_word': 'ORIG',
#    'id': 682557,
#    'image_id': 504616,
#    'target_word': 'ORIG'},
#   {'caption': 'a chef slides a apple into a brick oven.',
#    'foil_id': 2000050,
#    'foil_word': 'apple',
#    'id': 670608,
#    'image_id': 504616,
#    'target_word': 'pizza'},
#   {'caption': 'a man with a bat cap and an apron using a brick oven.',
#    'foil_id': 2000052,
#    'foil_word': 'bat',
#    'id': 675480,
#    'image_id': 504616,
#    'target_word': 'ball'},
#   {'caption': 'a man wearing an apron and standing next to an sink',
#    'foil_id': 2000053,
#    'foil_word': 'sink',
#    'id': 673656,
#    'image_id': 504616,
#    'target_word': 'oven'},
#   {'caption': 'There is a man cutting meat on a cutting board',
#    'foil_id': 2000055,
#    'foil_word': 'ORIG',
#    'id': 301131,
#    'image_id': 161919,
#    'target_word': 'ORIG'},
#   {'caption': 'Man cutting a hot piece of meat on a cutting board. ',
#    'foil_id': 2000057,
#    'foil_word': 'ORIG',
#    'id': 303018,
#    'image_id': 161919,
#    'target_word': 'ORIG'},
#   {'caption': 'a person is cutting a roast with a bowl and knife.',
#    'foil_id': 2000058,
#    'foil_word': 'bowl',
#    'id': 299640,
#    'image_id': 161919,
#    'target_word': 'fork'},
#   {'caption': 'a man is slicing meat with a spoon.',
#    'foil_id': 2000059,
#    'foil_word': 'spoon',
#    'id': 301443,
#    'image_id': 161919,
#    'target_word': 'knife'},
#   {'caption': 'a room filled with wooden table and chairs',
#    'foil_id': 2000061,
#    'foil_word': 'ORIG',
#    'id': 808117,
#    'image_id': 457732,
#    'target_word': 'ORIG'},
#   {'caption': 'A dark kitchen with several tables and chairs.',
#    'foil_id': 2000062,
#    'foil_word': 'ORIG',
#    'id': 806461,
#    'image_id': 457732,
#    'target_word': 'ORIG'},
#   {'caption': 'a big kitchen filled with some tables and shelves ',
#    'foil_id': 2000064,
#    'foil_word': 'ORIG',
#    'id': 808240,
#    'image_id': 457732,
#    'target_word': 'ORIG'},
#   {'caption': 'a kitchen with a couch and some chairs',
#    'foil_id': 2000065,
#    'foil_word': 'couch',
#    'id': 802054,
#    'image_id': 457732,
#    'target_word': 'table'},
#   {'caption': 'the room has couch, chairs, counters and shelves.',
#    'foil_id': 2000067,
#    'foil_word': 'couch',
#    'id': 807025,
#    'image_id': 457732,
#    'target_word': 'table'},
#   {'caption': 'A kitchen with wood shelves and appliances. ',
#    'foil_id': 2000069,
#    'foil_word': 'ORIG',
#    'id': 667577,
#    'image_id': 44404,
#    'target_word': 'ORIG'},
#   {'caption': 'a kitchen that has a stove and a icebox',
#    'foil_id': 2000071,
#    'foil_word': 'ORIG',
#    'id': 668372,
#    'image_id': 44404,
#    'target_word': 'ORIG'},
#   {'caption': 'the window above the kitchen oven is opened.',
#    'foil_id': 2000073,
#    'foil_word': 'oven',
#    'id': 665342,
#    'image_id': 44404,
#    'target_word': 'sink'},
#   {'caption': 'a fridge, sink and sink in the kitchen',
#    'foil_id': 2000074,
#    'foil_word': 'sink',
#    'id': 669281,
#    'image_id': 44404,
#    'target_word': 'microwave'},
#   {'caption': 'a kitchen has wood cabinets, a dishwasher, microwave, and refrigerator.',
#    'foil_id': 2000076,
#    'foil_word': 'microwave',
#    'id': 663785,
#    'image_id': 44404,
#    'target_word': 'sink'},
#   {'caption': 'Adults using laptop computers while sitting at outdoor venue.',
#    'foil_id': 2000078,
#    'foil_word': 'ORIG',
#    'id': 447789,
#    'image_id': 170558,
#    'target_word': 'ORIG'},
#   {'caption': 'A row of men using laptops on side of a building.',
#    'foil_id': 2000079,
#    'foil_word': 'ORIG',
#    'id': 449424,
#    'image_id': 170558,
#    'target_word': 'ORIG'},
#   {'caption': 'Young men sit next to each other working on laptops. ',
#    'foil_id': 2000080,
#    'foil_word': 'ORIG',
#    'id': 826903,
#    'image_id': 170558,
#    'target_word': 'ORIG'},
#   {'caption': 'a man is on his phone while people looking on.',
#    'foil_id': 2000081,
#    'foil_word': 'phone',
#    'id': 454098,
#    'image_id': 170558,
#    'target_word': 'laptop'},
#   {'caption': 'a number of people siting on a bench with a tv',
#    'foil_id': 2000083,
#    'foil_word': 'tv',
#    'id': 454632,
#    'image_id': 170558,
#    'target_word': 'laptop'},
#   {'caption': 'A group of people standing at a table with wine making pizzas. ',
#    'foil_id': 2000084,
#    'foil_word': 'ORIG',
#    'id': 492993,
#    'image_id': 405613,
#    'target_word': 'ORIG'},
#   {'caption': 'THERE ARE PEOPLE THAT ARE GETTING FOOD OFF OF THE TABLE ',
#    'foil_id': 2000086,
#    'foil_word': 'ORIG',
#    'id': 498972,
#    'image_id': 405613,
#    'target_word': 'ORIG'},
#   {'caption': 'a group of men at a toilet preparing food together',
#    'foil_id': 2000088,
#    'foil_word': 'toilet',
#    'id': 486903,
#    'image_id': 405613,
#    'target_word': 'table'},
#   {'caption': 'people preparing what they want to eat on a chair',
#    'foil_id': 2000089,
#    'foil_word': 'chair',
#    'id': 491646,
#    'image_id': 405613,
#    'target_word': 'table'},
#   {'caption': 'some men standing around a counter while making a donut',
#    'foil_id': 2000090,
#    'foil_word': 'donut',
#    'id': 489318,
#    'image_id': 405613,
#    'target_word': 'pizza'},
#   {'caption': 'A man chopping vegetables on a white board.',
#    'foil_id': 2000092,
#    'foil_word': 'ORIG',
#    'id': 215924,
#    'image_id': 283524,
#    'target_word': 'ORIG'},
#   {'caption': 'a man cutting up vegetables on top of a food cart.',
#    'foil_id': 2000094,
#    'foil_word': 'ORIG',
#    'id': 204659,
#    'image_id': 283524,
#    'target_word': 'ORIG'},
#   {'caption': 'a man cutting up scallions at an outdoor couch',
#    'foil_id': 2000095,
#    'foil_word': 'couch',
#    'id': 214298,
#    'image_id': 283524,
#    'target_word': 'table'},
#   {'caption': 'a man stands with a bowl and onions in front of a garage.',
#    'foil_id': 2000097,
#    'foil_word': 'bowl',
#    'id': 234917,
#    'image_id': 283524,
#    'target_word': 'knife'},
#   {'caption': 'Dining room table set for a casual meal, with flowers.',
#    'foil_id': 2000099,
#    'foil_word': 'ORIG',
#    'id': 512711,
#    'image_id': 71631,
#    'target_word': 'ORIG'},
#   {'caption': 'a table with a red tablecloth and white placemats',
#    'foil_id': 2000101,
#    'foil_word': 'ORIG',
#    'id': 590288,
#    'image_id': 71631,
#    'target_word': 'ORIG'},
#   {'caption': 'A red table topped with four white place mats.',
#    'foil_id': 2000103,
#    'foil_word': 'ORIG',
#    'id': 587054,
#    'image_id': 71631,
#    'target_word': 'ORIG'},
#   {'caption': 'there is a dining room toilet with a red cloth and a vase with roses',
#    'foil_id': 2000104,
#    'foil_word': 'toilet',
#    'id': 589694,
#    'image_id': 71631,
#    'target_word': 'table'},
#   {'caption': 'a small dinning table with all red napkins and a red chair cloth.',
#    'foil_id': 2000105,
#    'foil_word': 'chair',
#    'id': 594356,
#    'image_id': 71631,
#    'target_word': 'table'},
#   {'caption': 'a couple of people that have kites in the sky',
#    'foil_id': 2000107,
#    'foil_word': 'ORIG',
#    'id': 589062,
#    'image_id': 365363,
#    'target_word': 'ORIG'},
#   {'caption': 'A man and a boy fly kites in the snow in front of pine trees.',
#    'foil_id': 2000108,
#    'foil_word': 'ORIG',
#    'id': 588054,
#    'image_id': 365363,
#    'target_word': 'ORIG'},
#   {'caption': 'two people flying a skateboard above pine trees.',
#    'foil_id': 2000109,
#    'foil_word': 'skateboard',
#    'id': 583866,
#    'image_id': 365363,
#    'target_word': 'kite'},
#   {'caption': 'two people flying a ball in a field with a forest in the background.',
#    'foil_id': 2000111,
#    'foil_word': 'ball',
#    'id': 587583,
#    'image_id': 365363,
#    'target_word': 'kite'},
#   {'caption': "A restaurant's grill top is full of meats and sandwiches.",
#    'foil_id': 2000112,
#    'foil_word': 'ORIG',
#    'id': 673953,
#    'image_id': 470072,
#    'target_word': 'ORIG'},
#   {'caption': 'two men standing next to an refrigerator with sandwiches',
#    'foil_id': 2000113,
#    'foil_word': 'refrigerator',
#    'id': 670965,
#    'image_id': 470072,
#    'target_word': 'oven'},
#   {'caption': 'A man laying on his stomach with a towel on his head.',
#    'foil_id': 2000114,
#    'foil_word': 'ORIG',
#    'id': 695846,
#    'image_id': 344806,
#    'target_word': 'ORIG'},
#   {'caption': 'This is a photo of someones bare back.',
#    'foil_id': 2000115,
#    'foil_word': 'ORIG',
#    'id': 704135,
#    'image_id': 344806,
#    'target_word': 'ORIG'},
#   {'caption': 'a man is lying face down on the table',
#    'foil_id': 2000116,
#    'foil_word': 'table',
#    'id': 705452,
#    'image_id': 344806,
#    'target_word': 'bed'},
#   {'caption': 'a man on his stomach in a white couch.',
#    'foil_id': 2000117,
#    'foil_word': 'couch',
#    'id': 703280,
#    'image_id': 344806,
#    'target_word': 'bed'},
#   {'caption': 'someone that is laying face down on a couch',
#    'foil_id': 2000119,
#    'foil_word': 'couch',
#    'id': 700544,
#    'image_id': 344806,
#    'target_word': 'bed'},
#   {'caption': 'A crowded kitchen with dishes hanging from the walls',
#    'foil_id': 2000121,
#    'foil_word': 'ORIG',
#    'id': 608424,
#    'image_id': 84427,
#    'target_word': 'ORIG'},
#   {'caption': 'A strange dark kitchen has an interesting curtain.',
#    'foil_id': 2000123,
#    'foil_word': 'ORIG',
#    'id': 599814,
#    'image_id': 84427,
#    'target_word': 'ORIG'},
#   {'caption': 'a small cluttered kitchen with a window and refrigerator.',
#    'foil_id': 2000124,
#    'foil_word': 'refrigerator',
#    'id': 598704,
#    'image_id': 84427,
#    'target_word': 'sink'},
#   {'caption': 'a kitchen with a refrigerator a dish rack on the wall and utensils hanging from a window.',
#    'foil_id': 2000126,
#    'foil_word': 'refrigerator',
#    'id': 599571,
#    'image_id': 84427,
#    'target_word': 'sink'},
#   {'caption': 'A little boy that has a spoon with food on it.',
#    'foil_id': 2000127,
#    'foil_word': 'ORIG',
#    'id': 626290,
#    'image_id': 317237,
#    'target_word': 'ORIG'},
#   {'caption': 'a kid using a spoon eating from a plate',
#    'foil_id': 2000129,
#    'foil_word': 'ORIG',
#    'id': 624241,
#    'image_id': 317237,
#    'target_word': 'ORIG'},
#   {'caption': 'An Asian baby feeding himself noodles from a bowl.',
#    'foil_id': 2000130,
#    'foil_word': 'ORIG',
#    'id': 624064,
#    'image_id': 317237,
#    'target_word': 'ORIG'},
#   {'caption': 'an asian child is eating noodles with a bowl with help using his own hands in the kitchen.',
#    'foil_id': 2000131,
#    'foil_word': 'bowl',
#    'id': 626485,
#    'image_id': 317237,
#    'target_word': 'fork'},
#   {'caption': 'a small child eating noodles from a bottle in a kitchen',
#    'foil_id': 2000132,
#    'foil_word': 'bottle',
#    'id': 623845,
#    'image_id': 317237,
#    'target_word': 'bowl'},
#   {'caption': 'Group of children entertaining. Selves in a skatepark',
#    'foil_id': 2000134,
#    'foil_word': 'ORIG',
#    'id': 771170,
#    'image_id': 409382,
#    'target_word': 'ORIG'},
#   {'caption': 'two boys sitting down one has his skate board on his head',
#    'foil_id': 2000136,
#    'foil_word': 'ORIG',
#    'id': 765692,
#    'image_id': 409382,
#    'target_word': 'ORIG'},
#   {'caption': 'people on a glove ramp with one doing a trick and one with skateboard on his head.',
#    'foil_id': 2000137,
#    'foil_word': 'glove',
#    'id': 763922,
#    'image_id': 409382,
#    'target_word': 'skateboard'},
#   {'caption': 'a man performs skateboard tricks while two onlookers watch, one with a bat on his head',
#    'foil_id': 2000138,
#    'foil_word': 'bat',
#    'id': 773438,
#    'image_id': 409382,
#    'target_word': 'skateboard'},
#   {'caption': 'a modern looking kitchen with steel countertops and utensils',
#    'foil_id': 2000140,
#    'foil_word': 'ORIG',
#    'id': 799293,
#    'image_id': 570608,
#    'target_word': 'ORIG'},
#   {'caption': 'a kitchen that has a toaster and some cabinets in it',
#    'foil_id': 2000142,
#    'foil_word': 'toaster',
#    'id': 797451,
#    'image_id': 570608,
#    'target_word': 'microwave'},
#   {'caption': 'A man in light colored clothing stands near white tents while people sit on grass on a blankent.',
#    'foil_id': 2000143,
#    'foil_word': 'ORIG',
#    'id': 468367,
#    'image_id': 469605,
#    'target_word': 'ORIG'},
#   {'caption': 'A man on a cellphone near a group of people on the lawn,',
#    'foil_id': 2000144,
#    'foil_word': 'ORIG',
#    'id': 823476,
#    'image_id': 469605,
#    'target_word': 'ORIG'},
#   {'caption': 'the man talks on a cell tv far from three others sitting on a blanket.',
#    'foil_id': 2000145,
#    'foil_word': 'tv',
#    'id': 467341,
#    'image_id': 469605,
#    'target_word': 'phone'},
#   {'caption': 'there is a man standing on a field talking on the remote',
#    'foil_id': 2000147,
#    'foil_word': 'remote',
#    'id': 456457,
#    'image_id': 469605,
#    'target_word': 'phone'},
#   {'caption': 'a man is standing in the grass talking on a tv.',
#    'foil_id': 2000149,
#    'foil_word': 'tv',
#    'id': 458119,
#    'image_id': 469605,
#    'target_word': 'phone'},
#   {'caption': 'Two men are smiling looking at a laptop computer.',
#    'foil_id': 2000150,
#    'foil_word': 'ORIG',
#    'id': 205911,
#    'image_id': 356702,
#    'target_word': 'ORIG'},
#   {'caption': 'Two men laugh as they look at a computer.',
#    'foil_id': 2000152,
#    'foil_word': 'ORIG',
#    'id': 205257,
#    'image_id': 356702,
#    'target_word': 'ORIG'},
#   {'caption': 'Two men happily working on a plastic computer',
#    'foil_id': 2000153,
#    'foil_word': 'ORIG',
#    'id': 210765,
#    'image_id': 356702,
#    'target_word': 'ORIG'},
#   {'caption': 'a pair of men looking at a tablet perched on a bed.',
#    'foil_id': 2000155,
#    'foil_word': 'bed',
#    'id': 203397,
#    'image_id': 356702,
#    'target_word': 'table'},
#   {'caption': "a couple of young men sitting in front of a child's tv.",
#    'foil_id': 2000157,
#    'foil_word': 'tv',
#    'id': 190242,
#    'image_id': 356702,
#    'target_word': 'laptop'},
#   {'caption': 'A large bottle of wine sitting on a kitchen counter.',
#    'foil_id': 2000158,
#    'foil_word': 'ORIG',
#    'id': 153349,
#    'image_id': 405207,
#    'target_word': 'ORIG'},
#   {'caption': 'a soup kitchen full of soup bowls and food ',
#    'foil_id': 2000160,
#    'foil_word': 'ORIG',
#    'id': 217345,
#    'image_id': 405207,
#    'target_word': 'ORIG'},
#   {'caption': 'a wine glass that is three fourths full is sitting on a table.',
#    'foil_id': 2000161,
#    'foil_word': 'glass',
#    'id': 199690,
#    'image_id': 405207,
#    'target_word': 'bottle'},
#   {'caption': 'a corked spoon of wine near stacks of dishes and food.',
#    'foil_id': 2000163,
#    'foil_word': 'spoon',
#    'id': 212326,
#    'image_id': 405207,
#    'target_word': 'bottle'},
#   {'caption': 'a closeup of soup bowls, a bowl of wine and other food.',
#    'foil_id': 2000164,
#    'foil_word': 'bowl',
#    'id': 184714,
#    'image_id': 405207,
#    'target_word': 'bottle'},
#   {'caption': 'A man at a table observing something away from him.',
#    'foil_id': 2000165,
#    'foil_word': 'ORIG',
#    'id': 484286,
#    'image_id': 214704,
#    'target_word': 'ORIG'},
#   {'caption': 'Bearded man in colorized image looks off to the side.',
#    'foil_id': 2000166,
#    'foil_word': 'ORIG',
#    'id': 481241,
#    'image_id': 214704,
#    'target_word': 'ORIG'},
#   {'caption': 'A man with a beard with his head turned sitting down.',
#    'foil_id': 2000168,
#    'foil_word': 'ORIG',
#    'id': 481649,
#    'image_id': 214704,
#    'target_word': 'ORIG'},
#   {'caption': 'a young man that is sitting at a kitchen bed is looking of to the side.',
#    'foil_id': 2000170,
#    'foil_word': 'bed',
#    'id': 478034,
#    'image_id': 214704,
#    'target_word': 'table'},
#   {'caption': 'a person sitting down with a remote behind him',
#    'foil_id': 2000172,
#    'foil_word': 'remote',
#    'id': 486458,
#    'image_id': 214704,
#    'target_word': 'tv'},
#   {'caption': 'A woman offering a man a taste of something in front of other people.',
#    'foil_id': 2000173,
#    'foil_word': 'ORIG',
#    'id': 707273,
#    'image_id': 279108,
#    'target_word': 'ORIG'},
#   {'caption': 'A woman feeds a man a bite of food.',
#    'foil_id': 2000175,
#    'foil_word': 'ORIG',
#    'id': 709985,
#    'image_id': 279108,
#    'target_word': 'ORIG'},
#   {'caption': 'a woman cup feeding an old man',
#    'foil_id': 2000177,
#    'foil_word': 'cup',
#    'id': 719888,
#    'image_id': 279108,
#    'target_word': 'spoon'},
#   {'caption': 'a woman feeding a man food from a bowl.',
#    'foil_id': 2000178,
#    'foil_word': 'bowl',
#    'id': 705422,
#    'image_id': 279108,
#    'target_word': 'spoon'},
#   {'caption': 'A little girl in a red jumpsuit and sweater is near a red bike and red table.',
#    'foil_id': 2000179,
#    'foil_word': 'ORIG',
#    'id': 470794,
#    'image_id': 393493,
#    'target_word': 'ORIG'},
#   {'caption': 'A little girl standing next to a red bike near leaves.',
#    'foil_id': 2000180,
#    'foil_word': 'ORIG',
#    'id': 474805,
#    'image_id': 393493,
#    'target_word': 'ORIG'},
#   {'caption': 'little girl looking down at leaves with her motorcycle with training wheels parked next to her.',
#    'foil_id': 2000182,
#    'foil_word': 'motorcycle',
#    'id': 467305,
#    'image_id': 393493,
#    'target_word': 'bicycle'},
#   {'caption': 'small child next to a picnic chair and tricycle.',
#    'foil_id': 2000183,
#    'foil_word': 'chair',
#    'id': 819473,
#    'image_id': 393493,
#    'target_word': 'table'},
#   {'caption': 'a young child in a park next to a red hydrant and red bicycle that as training wheels.',
#    'foil_id': 2000184,
#    'foil_word': 'hydrant',
#    'id': 473197,
#    'image_id': 393493,
#    'target_word': 'bench'},
#   {'caption': 'The bathroom is decorated in an elaborate style.',
#    'foil_id': 2000186,
#    'foil_word': 'ORIG',
#    'id': 386534,
#    'image_id': 62426,
#    'target_word': 'ORIG'},
#   {'caption': 'a toaster and bath in a small room.',
#    'foil_id': 2000188,
#    'foil_word': 'toaster',
#    'id': 384212,
#    'image_id': 62426,
#    'target_word': 'sink'},
#   {'caption': 'A golden bath area with a chandelier and blue and white bathtub.',
#    'foil_id': 2000190,
#    'foil_word': 'ORIG',
#    'id': 136259,
#    'image_id': 19380,
#    'target_word': 'ORIG'},
#   {'caption': 'A bathroom double vanity and tub with a chandelier above and intricate tile work.',
#    'foil_id': 2000191,
#    'foil_word': 'ORIG',
#    'id': 120179,
#    'image_id': 19380,
#    'target_word': 'ORIG'},
#   {'caption': 'a bathroom with a yellow oven next to a white bath tub.',
#    'foil_id': 2000193,
#    'foil_word': 'oven',
#    'id': 105956,
#    'image_id': 19380,
#    'target_word': 'sink'},
#   {'caption': 'double refrigerator vanity next to a bathtub with a chandelier in the ceiling.',
#    'foil_id': 2000195,
#    'foil_word': 'refrigerator',
#    'id': 140999,
#    'image_id': 19380,
#    'target_word': 'sink'},
#   {'caption': 'a bathroom with mint green walls and pictures ',
#    'foil_id': 2000196,
#    'foil_word': 'ORIG',
#    'id': 146758,
#    'image_id': 485894,
#    'target_word': 'ORIG'},
#   {'caption': 'a mint green bathroom with bicycle pictures on the wall',
#    'foil_id': 2000197,
#    'foil_word': 'bicycle',
#    'id': 127579,
#    'image_id': 485894,
#    'target_word': 'car'},
#   {'caption': 'Black and white photograph of a child crying in mirror.',
#    'foil_id': 2000198,
#    'foil_word': 'ORIG',
#    'id': 308803,
#    'image_id': 446014,
#    'target_word': 'ORIG'},
#   {'caption': 'a little child crying while standing at a bathroom oven.',
#    'foil_id': 2000199,
#    'foil_word': 'oven',
#    'id': 311302,
#    'image_id': 446014,
#    'target_word': 'sink'},
#   {'caption': 'A woman in sunglasses is sitting on a bike with a dog.',
#    'foil_id': 2000201,
#    'foil_word': 'ORIG',
#    'id': 272888,
#    'image_id': 530683,
#    'target_word': 'ORIG'},
#   {'caption': 'A woman in a black and white dress on a bicycle.',
#    'foil_id': 2000202,
#    'foil_word': 'ORIG',
#    'id': 269888,
#    'image_id': 530683,
#    'target_word': 'ORIG'},
#   {'caption': 'A woman stand near a group of people, and everyone is on bikes.',
#    'foil_id': 2000204,
#    'foil_word': 'ORIG',
#    'id': 272270,
#    'image_id': 530683,
#    'target_word': 'ORIG'},
#   {'caption': 'a woman in a dress riding a train.',
#    'foil_id': 2000205,
#    'foil_word': 'train',
#    'id': 266525,
#    'image_id': 530683,
#    'target_word': 'bicycle'},
#   {'caption': 'a woman and a bird on a bike on the street.',
#    'foil_id': 2000207,
#    'foil_word': 'bird',
#    'id': 274229,
#    'image_id': 530683,
#    'target_word': 'dog'},
#   {'caption': 'a bathroom that has a toilet and some nasty stuff all over',
#    'foil_id': 2000208,
#    'foil_word': 'ORIG',
#    'id': 551419,
#    'image_id': 292835,
#    'target_word': 'ORIG'},
#   {'caption': 'A view of a very dirty bathroom that needs to be cleaned.',
#    'foil_id': 2000209,
#    'foil_word': 'ORIG',
#    'id': 547399,
#    'image_id': 292835,
#    'target_word': 'ORIG'},
#   {'caption': 'a spoon is on the floor in front of a broken toilet.',
#    'foil_id': 2000210,
#    'foil_word': 'spoon',
#    'id': 549682,
#    'image_id': 292835,
#    'target_word': 'bowl'},
#   {'caption': 'a bowl sitting in a bathroom across from a couch.',
#    'foil_id': 2000212,
#    'foil_word': 'couch',
#    'id': 557287,
#    'image_id': 292835,
#    'target_word': 'toilet'},
#   {'caption': 'a white bed in a bathroom under a window.',
#    'foil_id': 2000214,
#    'foil_word': 'bed',
#    'id': 549757,
#    'image_id': 292835,
#    'target_word': 'toilet'},
#   {'caption': 'Two bathroom sinks are shown in a beat up bathroom.',
#    'foil_id': 2000216,
#    'foil_word': 'ORIG',
#    'id': 158134,
#    'image_id': 262845,
#    'target_word': 'ORIG'},
#   {'caption': 'a dirty double microwave bathroom with a curtain.',
#    'foil_id': 2000218,
#    'foil_word': 'microwave',
#    'id': 157759,
#    'image_id': 262845,
#    'target_word': 'sink'},
#   {'caption': 'The bathroom has red carpet and yellowish appliances.',
#    'foil_id': 2000220,
#    'foil_word': 'ORIG',
#    'id': 799458,
#    'image_id': 299411,
#    'target_word': 'ORIG'},
#   {'caption': 'a painting or drawing of a bathroom with red flooring',
#    'foil_id': 2000221,
#    'foil_word': 'ORIG',
#    'id': 804090,
#    'image_id': 299411,
#    'target_word': 'ORIG'},
#   {'caption': 'a bathroom that has a sink and a couch in it',
#    'foil_id': 2000222,
#    'foil_word': 'couch',
#    'id': 796989,
#    'image_id': 299411,
#    'target_word': 'toilet'},
#   {'caption': 'an old bathroom with yellow colored table, sink and bath tub.',
#    'foil_id': 2000223,
#    'foil_word': 'table',
#    'id': 806319,
#    'image_id': 299411,
#    'target_word': 'toilet'},
#   {'caption': 'A white bicycle anchored between the parking posts.',
#    'foil_id': 2000225,
#    'foil_word': 'ORIG',
#    'id': 731960,
#    'image_id': 239811,
#    'target_word': 'ORIG'},
#   {'caption': 'A white bike parked next to a  couple of statues.',
#    'foil_id': 2000227,
#    'foil_word': 'ORIG',
#    'id': 730286,
#    'image_id': 239811,
#    'target_word': 'ORIG'},
#   {'caption': 'Bike monument in a city atmosphere with people walking and relaxing nearby.',
#    'foil_id': 2000228,
#    'foil_word': 'ORIG',
#    'id': 730469,
#    'image_id': 239811,
#    'target_word': 'ORIG'},
#   {'caption': 'a white car leans against a post on the sidewalk.',
#    'foil_id': 2000230,
#    'foil_word': 'car',
#    'id': 728990,
#    'image_id': 239811,
#    'target_word': 'bicycle'},
#   {'caption': 'a solid white boat is parked next to statues on a sidewalk.',
#    'foil_id': 2000231,
#    'foil_word': 'boat',
#    'id': 728789,
#    'image_id': 239811,
#    'target_word': 'bicycle'},
#   {'caption': 'A bathroom sink with a large mirror over it. ',
#    'foil_id': 2000233,
#    'foil_word': 'ORIG',
#    'id': 88708,
#    'image_id': 2024,
#    'target_word': 'ORIG'},
#   {'caption': 'A bathroom looks new with nothing in it.',
#    'foil_id': 2000234,
#    'foil_word': 'ORIG',
#    'id': 79588,
#    'image_id': 2024,
#    'target_word': 'ORIG'},
#   {'caption': 'a mirror in the bathroom displays couch paper and another mirror.',
#    'foil_id': 2000235,
#    'foil_word': 'couch',
#    'id': 80386,
#    'image_id': 2024,
#    'target_word': 'toilet'},
#   {'caption': 'a bathroom sink beneath a very large mirror reflecting a roll of couch paper.',
#    'foil_id': 2000237,
#    'foil_word': 'couch',
#    'id': 84757,
#    'image_id': 2024,
#    'target_word': 'toilet'},
#   {'caption': 'this is a bathroom with a oven and a mirror.',
#    'foil_id': 2000239,
#    'foil_word': 'oven',
#    'id': 86161,
#    'image_id': 2024,
#    'target_word': 'sink'},
#   {'caption': 'A bathroom featuring an antique style sink and tiled walls',
#    'foil_id': 2000241,
#    'foil_word': 'ORIG',
#    'id': 806926,
#    'image_id': 95133,
#    'target_word': 'ORIG'},
#   {'caption': 'a bathroom scene with a wooden door and a sink in view',
#    'foil_id': 2000242,
#    'foil_word': 'ORIG',
#    'id': 804790,
#    'image_id': 95133,
#    'target_word': 'ORIG'},
#   {'caption': 'A picture that is on the wall near a sink.',
#    'foil_id': 2000244,
#    'foil_word': 'ORIG',
#    'id': 807229,
#    'image_id': 95133,
#    'target_word': 'ORIG'},
#   {'caption': 'a white oven with brass fixtures in a small bathroom.',
#    'foil_id': 2000245,
#    'foil_word': 'oven',
#    'id': 812335,
#    'image_id': 95133,
#    'target_word': 'sink'},
#   {'caption': 'a microwave a picture a mirror and white tiles',
#    'foil_id': 2000246,
#    'foil_word': 'microwave',
#    'id': 807346,
#    'image_id': 95133,
#    'target_word': 'sink'},
#   {'caption': 'Two bathroom sinks mounted against a mirror, with soap in between the two sinks.',
#    'foil_id': 2000248,
#    'foil_word': 'ORIG',
#    'id': 557261,
#    'image_id': 287541,
#    'target_word': 'ORIG'},
#   {'caption': 'Two pedestal sinks at a mirror in a public restroom.',
#    'foil_id': 2000249,
#    'foil_word': 'ORIG',
#    'id': 558284,
#    'image_id': 287541,
#    'target_word': 'ORIG'},
#   {'caption': 'a couple of bottles of soap are sitting on refrigerator',
#    'foil_id': 2000250,
#    'foil_word': 'refrigerator',
#    'id': 559157,
#    'image_id': 287541,
#    'target_word': 'sink'},
#   {'caption': 'a close up view of a couple of sinks and soap cup.',
#    'foil_id': 2000251,
#    'foil_word': 'cup',
#    'id': 558374,
#    'image_id': 287541,
#    'target_word': 'bottle'},
#   {'caption': 'a man hunkered down between two bicycles ',
#    'foil_id': 2000252,
#    'foil_word': 'ORIG',
#    'id': 551810,
#    'image_id': 441488,
#    'target_word': 'ORIG'},
#   {'caption': 'Man taking picture while crouching on ground by two parked bicycles. ',
#    'foil_id': 2000253,
#    'foil_word': 'ORIG',
#    'id': 550271,
#    'image_id': 441488,
#    'target_word': 'ORIG'},
#   {'caption': 'man with bicycles squatting while taking a picture with a tv camera.',
#    'foil_id': 2000254,
#    'foil_word': 'tv',
#    'id': 554900,
#    'image_id': 441488,
#    'target_word': 'phone'},
#   {'caption': 'man kneeling between two bicycles looking at his laptop',
#    'foil_id': 2000255,
#    'foil_word': 'laptop',
#    'id': 512303,
#    'image_id': 441488,
#    'target_word': 'phone'},
#   {'caption': 'There is a toilet with a picture above it, there are four rolls of tissue.',
#    'foil_id': 2000256,
#    'foil_word': 'ORIG',
#    'id': 86338,
#    'image_id': 179620,
#    'target_word': 'ORIG'},
#   {'caption': 'A bathroom with a toilet and white walls. ',
#    'foil_id': 2000257,
#    'foil_word': 'ORIG',
#    'id': 88015,
#    'image_id': 179620,
#    'target_word': 'ORIG'},
#   {'caption': 'a toilet bowl with rolls of chair paper stacked next to it',
#    'foil_id': 2000258,
#    'foil_word': 'chair',
#    'id': 83437,
#    'image_id': 179620,
#    'target_word': 'toilet'},
#   {'caption': 'a white walled bathroom with six rolls of bed paper next to a white toilet.',
#    'foil_id': 2000259,
#    'foil_word': 'bed',
#    'id': 820303,
#    'image_id': 179620,
#    'target_word': 'toilet'},
#   {'caption': 'a bathroom chair sitting next to a few roles of toilet paper.',
#    'foil_id': 2000260,
#    'foil_word': 'chair',
#    'id': 83623,
#    'image_id': 179620,
#    'target_word': 'toilet'},
#   {'caption': 'A room with a table and chairs and bikes hanging up.',
#    'foil_id': 2000261,
#    'foil_word': 'ORIG',
#    'id': 657065,
#    'image_id': 70000,
#    'target_word': 'ORIG'},
#   {'caption': 'A dark room with a long wooden table and a bike hanging on the wall.',
#    'foil_id': 2000262,
#    'foil_word': 'ORIG',
#    'id': 658868,
#    'image_id': 70000,
#    'target_word': 'ORIG'},
#   {'caption': 'Bright loft space with large rustic dining table and bikes on the wall.',
#    'foil_id': 2000264,
#    'foil_word': 'ORIG',
#    'id': 650456,
#    'image_id': 70000,
#    'target_word': 'ORIG'},
#   {'caption': 'there is a long bed in the middle of this room.',
#    'foil_id': 2000266,
#    'foil_word': 'bed',
#    'id': 658364,
#    'image_id': 70000,
#    'target_word': 'table'},
#   {'caption': 'a room with windows, bikes, chairs, and a bed.',
#    'foil_id': 2000268,
#    'foil_word': 'bed',
#    'id': 655202,
#    'image_id': 70000,
#    'target_word': 'table'},
#   {'caption': 'This bathroom has a large jacuzzi tub and two sinks',
#    'foil_id': 2000269,
#    'foil_word': 'ORIG',
#    'id': 145671,
#    'image_id': 543877,
#    'target_word': 'ORIG'},
#   {'caption': 'a bathroom features white, bottle sinks and a bathtub.',
#    'foil_id': 2000270,
#    'foil_word': 'bottle',
#    'id': 120390,
#    'image_id': 543877,
#    'target_word': 'bowl'},
#   {'caption': 'A cat playing with the rug around a toilet.',
#    'foil_id': 2000271,
#    'foil_word': 'ORIG',
#    'id': 430944,
#    'image_id': 420721,
#    'target_word': 'ORIG'},
#   {'caption': 'A cat laying next to a white toilet in a bathroom.',
#    'foil_id': 2000273,
#    'foil_word': 'ORIG',
#    'id': 426333,
#    'image_id': 420721,
#    'target_word': 'ORIG'},
#   {'caption': 'a playful giraffe pulls up the corner of a bathroom rug.',
#    'foil_id': 2000274,
#    'foil_word': 'giraffe',
#    'id': 424206,
#    'image_id': 420721,
#    'target_word': 'cat'},
#   {'caption': 'a bath room with a chair and a cat on the rug',
#    'foil_id': 2000275,
#    'foil_word': 'chair',
#    'id': 425961,
#    'image_id': 420721,
#    'target_word': 'toilet'},
#   {'caption': 'a large furry elephant pulling up the bathroom carpet',
#    'foil_id': 2000277,
#    'foil_word': 'elephant',
#    'id': 421311,
#    'image_id': 420721,
#    'target_word': 'cat'},
#   {'caption': 'A toilet and sink in a small bathroom.',
#    'foil_id': 2000278,
#    'foil_word': 'ORIG',
#    'id': 359595,
#    'image_id': 540162,
#    'target_word': 'ORIG'},
#   {'caption': 'Toilet with upraised lid sitting next to bookshelves.',
#    'foil_id': 2000280,
#    'foil_word': 'ORIG',
#    'id': 356052,
#    'image_id': 540162,
#    'target_word': 'ORIG'},
#   {'caption': 'A bookshelf on the outside of a bathroom with a toilet.',
#    'foil_id': 2000281,
#    'foil_word': 'ORIG',
#    'id': 365748,
#    'image_id': 540162,
#    'target_word': 'ORIG'},
#   {'caption': 'a shelf with books and bed paper outside of a small bathroom.',
#    'foil_id': 2000282,
#    'foil_word': 'bed',
#    'id': 358422,
#    'image_id': 540162,
#    'target_word': 'toilet'},
#   {'caption': 'a couch with an adjacent bookshelf of books.',
#    'foil_id': 2000284,
#    'foil_word': 'couch',
#    'id': 362445,
#    'image_id': 540162,
#    'target_word': 'toilet'},
#   {'caption': 'A man wearing a purple hoodie urinating in a dirty restroom. ',
#    'foil_id': 2000286,
#    'foil_word': 'ORIG',
#    'id': 77951,
#    'image_id': 218956,
#    'target_word': 'ORIG'},
#   {'caption': 'A man is urinating in an unfinished restroom.',
#    'foil_id': 2000288,
#    'foil_word': 'ORIG',
#    'id': 78281,
#    'image_id': 218956,
#    'target_word': 'ORIG'},
#   {'caption': 'a man peeing in the bed with some note written in front of him.',
#    'foil_id': 2000289,
#    'foil_word': 'bed',
#    'id': 76013,
#    'image_id': 218956,
#    'target_word': 'toilet'},
#   {'caption': 'a man is standing in front of a bed.',
#    'foil_id': 2000291,
#    'foil_word': 'bed',
#    'id': 74516,
#    'image_id': 218956,
#    'target_word': 'toilet'},
#   {'caption': 'a man standing in front of a white bed in a restroom.',
#    'foil_id': 2000293,
#    'foil_word': 'bed',
#    'id': 73013,
#    'image_id': 218956,
#    'target_word': 'toilet'},
#   {'caption': 'some people riding some bikes down the road ',
#    'foil_id': 2000294,
#    'foil_word': 'ORIG',
#    'id': 617321,
#    'image_id': 318574,
#    'target_word': 'ORIG'},
#   {'caption': 'motorcycle wheels are lined up on bicycles in a row.',
#    'foil_id': 2000296,
#    'foil_word': 'motorcycle',
#    'id': 614018,
#    'image_id': 318574,
#    'target_word': 'bicycle'},
#   {'caption': 'A plain bathroom features a white toilet and sink and a beige bathtub.',
#    'foil_id': 2000297,
#    'foil_word': 'ORIG',
#    'id': 177681,
#    'image_id': 172899,
#    'target_word': 'ORIG'},
#   {'caption': 'Three piece bathroom with white sink and toilet and beige tub/shower.',
#    'foil_id': 2000298,
#    'foil_word': 'ORIG',
#    'id': 185955,
#    'image_id': 172899,
#    'target_word': 'ORIG'},
#   {'caption': 'A bathroom with both white and beige fixtures.  ',
#    'foil_id': 2000299,
#    'foil_word': 'ORIG',
#    'id': 185454,
#    'image_id': 172899,
#    'target_word': 'ORIG'},
#   {'caption': 'a bathroom white toaster, toilet and shower, looks clean.',
#    'foil_id': 2000301,
#    'foil_word': 'toaster',
#    'id': 186186,
#    'image_id': 172899,
#    'target_word': 'sink'},
#   {'caption': 'a bathroom scene complete with a tab, refrigerator and toilet.',
#    'foil_id': 2000303,
#    'foil_word': 'refrigerator',
#    'id': 170664,
#    'image_id': 172899,
#    'target_word': 'sink'},
#   {'caption': 'A run down bathroom with paint peeling off the walls. ',
#    'foil_id': 2000304,
#    'foil_word': 'ORIG',
#    'id': 390526,
#    'image_id': 352884,
#    'target_word': 'ORIG'},
#   {'caption': 'The paint of an abandoned bathroom peels off the walls.',
#    'foil_id': 2000305,
#    'foil_word': 'ORIG',
#    'id': 395881,
#    'image_id': 352884,
#    'target_word': 'ORIG'},
#   {'caption': 'a crumbling bathroom has a oven and a medicine cabinet.',
#    'foil_id': 2000307,
#    'foil_word': 'oven',
#    'id': 393241,
#    'image_id': 352884,
#    'target_word': 'sink'},
#   {'caption': 'bathroom with destroyed walls, a toaster and a mirrored cabinet.',
#    'foil_id': 2000308,
#    'foil_word': 'toaster',
#    'id': 390067,
#    'image_id': 352884,
#    'target_word': 'sink'},
#   {'caption': 'A black and white photo of restroom toilet with a filthy floor.',
#    'foil_id': 2000309,
#    'foil_word': 'ORIG',
#    'id': 363616,
#    'image_id': 394326,
#    'target_word': 'ORIG'},
#   {'caption': 'A dirty looking bathroom with a sink and a toilet.',
#    'foil_id': 2000311,
#    'foil_word': 'ORIG',
#    'id': 369448,
#    'image_id': 394326,
#    'target_word': 'ORIG'},
#   {'caption': 'a black and white photo of a dirty bathroom with focus on the couch.',
#    'foil_id': 2000312,
#    'foil_word': 'couch',
#    'id': 370819,
#    'image_id': 394326,
#    'target_word': 'toilet'},
#   {'caption': 'black and white photograph of bathroom bed and sink.',
#    'foil_id': 2000314,
#    'foil_word': 'bed',
#    'id': 367795,
#    'image_id': 394326,
#    'target_word': 'toilet'},
#   {'caption': 'a toilet and oven sit in a dark room.',
#    'foil_id': 2000316,
#    'foil_word': 'oven',
#    'id': 373978,
#    'image_id': 394326,
#    'target_word': 'sink'},
#   {'caption': 'a bathroom scene with a white toilet covered with a red bow',
#    'foil_id': 2000318,
#    'foil_word': 'ORIG',
#    'id': 78131,
#    'image_id': 535786,
#    'target_word': 'ORIG'},
#   {'caption': 'A white bathroom with a carefully gift-wrapped toilet bowl.',
#    'foil_id': 2000319,
#    'foil_word': 'ORIG',
#    'id': 83486,
#    'image_id': 535786,
#    'target_word': 'ORIG'},
#   {'caption': 'There is a picture of a bathroom with a toliet wrapped in a red ribbon.',
#    'foil_id': 2000321,
#    'foil_word': 'ORIG',
#    'id': 83111,
#    'image_id': 535786,
#    'target_word': 'ORIG'},
#   {'caption': 'a brand new couch with a bow across the seat.',
#    'foil_id': 2000323,
#    'foil_word': 'couch',
#    'id': 85178,
#    'image_id': 535786,
#    'target_word': 'toilet'},
#   {'caption': 'a couch with a bow on it inside a bathroom.',
#    'foil_id': 2000324,
#    'foil_word': 'couch',
#    'id': 75626,
#    'image_id': 535786,
#    'target_word': 'toilet'},
#   {'caption': 'Many people are strolling through the open plaza. ',
#    'foil_id': 2000325,
#    'foil_word': 'ORIG',
#    'id': 689727,
#    'image_id': 357684,
#    'target_word': 'ORIG'},
#   {'caption': 'Several groups of people are standing outside of a building.',
#    'foil_id': 2000327,
#    'foil_word': 'ORIG',
#    'id': 683724,
#    'image_id': 357684,
#    'target_word': 'ORIG'},
#   {'caption': 'a view of a drier tower with people around it.',
#    'foil_id': 2000329,
#    'foil_word': 'drier',
#    'id': 684795,
#    'image_id': 357684,
#    'target_word': 'clock'},
#   {'caption': 'a small vase tower in a town plaza.',
#    'foil_id': 2000330,
#    'foil_word': 'vase',
#    'id': 687183,
#    'image_id': 357684,
#    'target_word': 'clock'},
#   {'caption': 'A white toilet sitting in a demolished bathroom.',
#    'foil_id': 2000332,
#    'foil_word': 'ORIG',
#    'id': 681600,
#    'image_id': 576757,
#    'target_word': 'ORIG'},
#   {'caption': 'Construction tools sit in a bathroom that has has the walls and floor torn up.',
#    'foil_id': 2000334,
#    'foil_word': 'ORIG',
#    'id': 683847,
#    'image_id': 576757,
#    'target_word': 'ORIG'},
#   {'caption': 'an unfinished bathroom has a table and tools',
#    'foil_id': 2000335,
#    'foil_word': 'table',
#    'id': 677499,
#    'image_id': 576757,
#    'target_word': 'toilet'},
#   {'caption': 'a bathroom table in the middle of being remodeled.',
#    'foil_id': 2000336,
#    'foil_word': 'table',
#    'id': 684972,
#    'image_id': 576757,
#    'target_word': 'toilet'},
#   {'caption': "a bathroom that's being remodeled and has a bed.",
#    'foil_id': 2000338,
#    'foil_word': 'bed',
#    'id': 686856,
#    'image_id': 576757,
#    'target_word': 'toilet'},
#   {'caption': 'Bathroom that has a toilet, shower, and sink.',
#    'foil_id': 2000340,
#    'foil_word': 'ORIG',
#    'id': 38557,
#    'image_id': 165499,
#    'target_word': 'ORIG'},
#   {'caption': "A modern bathroom has a corner shower that's clear.",
#    'foil_id': 2000341,
#    'foil_word': 'ORIG',
#    'id': 39436,
#    'image_id': 165499,
#    'target_word': 'ORIG'},
#   {'caption': 'A bathroom with a see-through shower door. ',
#    'foil_id': 2000343,
#    'foil_word': 'ORIG',
#    'id': 39808,
#    'image_id': 165499,
#    'target_word': 'ORIG'},
#   {'caption': 'a bathroom with a white sink shower and table',
#    'foil_id': 2000344,
#    'foil_word': 'table',
#    'id': 36976,
#    'image_id': 165499,
#    'target_word': 'toilet'},
#   {'caption': 'a bathroom shower with knife doors and tile walls.',
#    'foil_id': 2000345,
#    'foil_word': 'knife',
#    'id': 32041,
#    'image_id': 165499,
#    'target_word': 'glass'},
#   {'caption': 'The small bathroom has a grey and white motif.',
#    'foil_id': 2000347,
#    'foil_word': 'ORIG',
#    'id': 114821,
#    'image_id': 181104,
#    'target_word': 'ORIG'},
#   {'caption': 'a white bathtub sitting in a bathroom next to a refrigerator.',
#    'foil_id': 2000349,
#    'foil_word': 'refrigerator',
#    'id': 104522,
#    'image_id': 181104,
#    'target_word': 'sink'},
#   {'caption': 'A bathroom is freshly cleaned and ready for hotel patrons.',
#    'foil_id': 2000351,
#    'foil_word': 'ORIG',
#    'id': 535518,
#    'image_id': 55627,
#    'target_word': 'ORIG'},
#   {'caption': 'Heated towel racks and a built in hairdryer in a hotel bathroom',
#    'foil_id': 2000353,
#    'foil_word': 'ORIG',
#    'id': 540189,
#    'image_id': 55627,
#    'target_word': 'ORIG'},
#   {'caption': 'a bathroom with a mirror above the sink, a towel rack and table.',
#    'foil_id': 2000354,
#    'foil_word': 'table',
#    'id': 536640,
#    'image_id': 55627,
#    'target_word': 'toilet'},
#   {'caption': 'there is a sink and chair in the bathroom.',
#    'foil_id': 2000356,
#    'foil_word': 'chair',
#    'id': 539166,
#    'image_id': 55627,
#    'target_word': 'toilet'},
#   {'caption': 'closed toilet, toaster, and mirror in a modern bathroom.',
#    'foil_id': 2000358,
#    'foil_word': 'toaster',
#    'id': 536067,
#    'image_id': 55627,
#    'target_word': 'sink'},
#   {'caption': 'A mirror that is sitting behind a sink.',
#    'foil_id': 2000360,
#    'foil_word': 'ORIG',
#    'id': 752490,
#    'image_id': 241364,
#    'target_word': 'ORIG'},
#   {'caption': 'A decently sized bathroom with a nice sink',
#    'foil_id': 2000361,
#    'foil_word': 'ORIG',
#    'id': 763017,
#    'image_id': 241364,
#    'target_word': 'ORIG'},
#   {'caption': 'A white bathroom with chrome fixtures and blue tile.',
#    'foil_id': 2000362,
#    'foil_word': 'ORIG',
#    'id': 758802,
#    'image_id': 241364,
#    'target_word': 'ORIG'},
#   {'caption': 'a hotel bathroom with a large toaster sticking out of the counter.',
#    'foil_id': 2000364,
#    'foil_word': 'toaster',
#    'id': 760713,
#    'image_id': 241364,
#    'target_word': 'sink'},
#   {'caption': 'a bathroom with a sink and a couch in it.',
#    'foil_id': 2000366,
#    'foil_word': 'couch',
#    'id': 756836,
#    'image_id': 241364,
#    'target_word': 'toilet'},
#   {'caption': 'A marble tiled counter in a small bathroom',
#    'foil_id': 2000368,
#    'foil_word': 'ORIG',
#    'id': 493506,
#    'image_id': 209967,
#    'target_word': 'ORIG'},
#   {'caption': 'this bathroom has a sculpture hanging on the wall',
#    'foil_id': 2000370,
#    'foil_word': 'ORIG',
#    'id': 497019,
#    'image_id': 209967,
#    'target_word': 'ORIG'},
#   {'caption': 'a bathroom with a monogrammed symbol above a bed.',
#    'foil_id': 2000372,
#    'foil_word': 'bed',
#    'id': 493932,
#    'image_id': 209967,
#    'target_word': 'toilet'},
#   {'caption': 'a toaster and vanity with overhead lights a decorative piece on the wall and a commode.',
#    'foil_id': 2000374,
#    'foil_word': 'toaster',
#    'id': 490119,
#    'image_id': 209967,
#    'target_word': 'sink'},
#   {'caption': 'the light is on over the microwave in the bathroom.',
#    'foil_id': 2000376,
#    'foil_word': 'microwave',
#    'id': 490329,
#    'image_id': 209967,
#    'target_word': 'sink'},
#   {'caption': 'a small sink with a small bottle of soap ',
#    'foil_id': 2000377,
#    'foil_word': 'ORIG',
#    'id': 516038,
#    'image_id': 153674,
#    'target_word': 'ORIG'},
#   {'caption': 'A bathroom sink with the faucet on the side',
#    'foil_id': 2000379,
#    'foil_word': 'ORIG',
#    'id': 396077,
#    'image_id': 153674,
#    'target_word': 'ORIG'},
#   {'caption': 'Two sinks that are set right next to each other.',
#    'foil_id': 2000381,
#    'foil_word': 'ORIG',
#    'id': 513761,
#    'image_id': 153674,
#    'target_word': 'ORIG'},
# ...
#    'id': 321330,
#    'license': 4,
#    'width': 480},
#   {'coco_url': 'http://mscoco.org/images/378499',
#    'date_captured': '2013-11-15 14:03:29',
#    'file_name': 'COCO_train2014_000000378499.jpg',
#    'flickr_url': 'http://farm8.staticflickr.com/7189/6826885034_a13bd2020a_z.jpg',
#    'height': 480,
#    'id': 378499,
#    'license': 4,
#    'width': 640},
#   {'coco_url': 'http://mscoco.org/images/301191',
#    'date_captured': '2013-11-15 14:22:11',
#    'file_name': 'COCO_train2014_000000301191.jpg',
#    'flickr_url': 'http://farm2.staticflickr.com/1345/939725314_781ecc479e_z.jpg',
#    'height': 480,
#    'id': 301191,
#    'license': 4,
#    'width': 640},
#   {'coco_url': 'http://mscoco.org/images/539647',
#    'date_captured': '2013-11-15 14:26:59',
#    'file_name': 'COCO_train2014_000000539647.jpg',
#    'flickr_url': 'http://farm1.staticflickr.com/38/108575104_1cd0ceb96d_z.jpg',
#    'height': 427,
#    'id': 539647,
#    'license': 1,
#    'width': 640},
#   {'coco_url': 'http://mscoco.org/images/322992',
#    'date_captured': '2013-11-15 14:28:25',
#    'file_name': 'COCO_train2014_000000322992.jpg',
#    'flickr_url': 'http://farm3.staticflickr.com/2109/2489723717_2a220e2c6b_z.jpg',
#    'height': 640,
#    'id': 322992,
#    'license': 2,
#    'width': 480},
#   {'coco_url': 'http://mscoco.org/images/76014',
#    'date_captured': '2013-11-15 14:48:30',
#    'file_name': 'COCO_train2014_000000076014.jpg',
#    'flickr_url': 'http://farm8.staticflickr.com/7381/9387779138_f84d233f3e_z.jpg',
#    'height': 427,
#    'id': 76014,
#    'license': 2,
#    'width': 640},
#   {'coco_url': 'http://mscoco.org/images/58403',
#    'date_captured': '2013-11-15 14:49:04',
#    'file_name': 'COCO_train2014_000000058403.jpg',
#    'flickr_url': 'http://farm3.staticflickr.com/2359/2538174930_245b91af0e_z.jpg',
#    'height': 429,
#    'id': 58403,
#    'license': 3,
#    'width': 640},
#   {'coco_url': 'http://mscoco.org/images/193821',
#    'date_captured': '2013-11-15 17:31:29',
#    'file_name': 'COCO_train2014_000000193821.jpg',
#    'flickr_url': 'http://farm3.staticflickr.com/2474/3933059078_3e362f5d3f_z.jpg',
#    'height': 480,
#    'id': 193821,
#    'license': 1,
#    'width': 640},
#   {'coco_url': 'http://mscoco.org/images/385448',
#    'date_captured': '2013-11-15 17:32:09',
#    'file_name': 'COCO_train2014_000000385448.jpg',
#    'flickr_url': 'http://farm4.staticflickr.com/3228/2832758661_2141898197_z.jpg',
#    'height': 512,
#    'id': 385448,
#    'license': 3,
#    'width': 640},
#   {'coco_url': 'http://mscoco.org/images/380108',
#    'date_captured': '2013-11-15 18:09:02',
#    'file_name': 'COCO_train2014_000000380108.jpg',
#    'flickr_url': 'http://farm2.staticflickr.com/1122/633786533_e5dc2088a4_z.jpg',
#    'height': 480,
#    'id': 380108,
#    'license': 3,
#    'width': 640},
#   {'coco_url': 'http://mscoco.org/images/285729',
#    'date_captured': '2013-11-15 19:19:34',
#    'file_name': 'COCO_train2014_000000285729.jpg',
#    'flickr_url': 'http://farm9.staticflickr.com/8501/8290053952_ca60aff595_z.jpg',
#    'height': 480,
#    'id': 285729,
#    'license': 1,
#    'width': 640},
#   {'coco_url': 'http://mscoco.org/images/328592',
#    'date_captured': '2013-11-15 20:20:08',
#    'file_name': 'COCO_train2014_000000328592.jpg',
#    'flickr_url': 'http://farm8.staticflickr.com/7398/9146539670_68643200aa_z.jpg',
#    'height': 480,
#    'id': 328592,
#    'license': 1,
#    'width': 640},
#   {'coco_url': 'http://mscoco.org/images/163483',
#    'date_captured': '2013-11-15 21:03:15',
#    'file_name': 'COCO_train2014_000000163483.jpg',
#    'flickr_url': 'http://farm8.staticflickr.com/7063/6821333738_721533687d_z.jpg',
#    'height': 254,
#    'id': 163483,
#    'license': 1,
#    'width': 640},
#   {'coco_url': 'http://mscoco.org/images/503050',
#    'date_captured': '2013-11-15 21:30:00',
#    'file_name': 'COCO_train2014_000000503050.jpg',
#    'flickr_url': 'http://farm1.staticflickr.com/106/298138827_19bb723252_z.jpg',
#    'height': 563,
#    'id': 503050,
#    'license': 3,
#    'width': 640},
#   {'coco_url': 'http://mscoco.org/images/355054',
#    'date_captured': '2013-11-15 22:35:41',
#    'file_name': 'COCO_train2014_000000355054.jpg',
#    'flickr_url': 'http://farm8.staticflickr.com/7016/6671618001_c92783a197_z.jpg',
#    'height': 426,
#    'id': 355054,
#    'license': 3,
#    'width': 640},
#   {'coco_url': 'http://mscoco.org/images/313007',
#    'date_captured': '2013-11-15 22:36:18',
#    'file_name': 'COCO_train2014_000000313007.jpg',
#    'flickr_url': 'http://farm6.staticflickr.com/5228/5774003047_f70e25d6c7_z.jpg',
#    'height': 640,
#    'id': 313007,
#    'license': 3,
#    'width': 427},
#   {'coco_url': 'http://mscoco.org/images/531096',
#    'date_captured': '2013-11-15 22:39:04',
#    'file_name': 'COCO_train2014_000000531096.jpg',
#    'flickr_url': 'http://farm4.staticflickr.com/3459/3256954189_ac83898c67_z.jpg',
#    'height': 480,
#    'id': 531096,
#    'license': 1,
#    'width': 640},
#   {'coco_url': 'http://mscoco.org/images/95381',
#    'date_captured': '2013-11-15 23:40:21',
#    'file_name': 'COCO_train2014_000000095381.jpg',
#    'flickr_url': 'http://farm4.staticflickr.com/3340/5826743170_2f1ca8df2d_z.jpg',
#    'height': 427,
#    'id': 95381,
#    'license': 4,
#    'width': 640},
#   {'coco_url': 'http://mscoco.org/images/69209',
#    'date_captured': '2013-11-15 23:50:31',
#    'file_name': 'COCO_train2014_000000069209.jpg',
#    'flickr_url': 'http://farm4.staticflickr.com/3644/3675304140_e4715e6e7f_z.jpg',
#    'height': 480,
#    'id': 69209,
#    'license': 5,
#    'width': 640},
#   {'coco_url': 'http://mscoco.org/images/503249',
#    'date_captured': '2013-11-16 00:11:19',
#    'file_name': 'COCO_train2014_000000503249.jpg',
#    'flickr_url': 'http://farm5.staticflickr.com/4122/4736707349_5c3b12f7d6_z.jpg',
#    'height': 480,
#    'id': 503249,
#    'license': 2,
#    'width': 640},
#   {'coco_url': 'http://mscoco.org/images/166086',
#    'date_captured': '2013-11-16 02:13:14',
#    'file_name': 'COCO_train2014_000000166086.jpg',
#    'flickr_url': 'http://farm8.staticflickr.com/7034/6807823515_6cbb2f98e0_z.jpg',
#    'height': 361,
#    'id': 166086,
#    'license': 2,
#    'width': 640},
#   {'coco_url': 'http://mscoco.org/images/435803',
#    'date_captured': '2013-11-16 02:27:05',
#    'file_name': 'COCO_train2014_000000435803.jpg',
#    'flickr_url': 'http://farm7.staticflickr.com/6094/6342539210_c56af77f68_z.jpg',
#    'height': 333,
#    'id': 435803,
#    'license': 2,
#    'width': 640},
#   {'coco_url': 'http://mscoco.org/images/302282',
#    'date_captured': '2013-11-16 02:38:59',
#    'file_name': 'COCO_train2014_000000302282.jpg',
#    'flickr_url': 'http://farm7.staticflickr.com/6078/6159379713_615d3a1f99_z.jpg',
#    'height': 361,
#    'id': 302282,
#    'license': 2,
#    'width': 640},
#   {'coco_url': 'http://mscoco.org/images/504769',
#    'date_captured': '2013-11-16 02:39:01',
#    'file_name': 'COCO_train2014_000000504769.jpg',
#    'flickr_url': 'http://farm7.staticflickr.com/6153/6159916184_99d4b7c457_z.jpg',
#    'height': 360,
#    'id': 504769,
#    'license': 2,
#    'width': 640},
#   {'coco_url': 'http://mscoco.org/images/208329',
#    'date_captured': '2013-11-16 03:01:15',
#    'file_name': 'COCO_train2014_000000208329.jpg',
#    'flickr_url': 'http://farm7.staticflickr.com/6006/5978717097_f674ab9b5a_z.jpg',
#    'height': 625,
#    'id': 208329,
#    'license': 2,
#    'width': 640},
#   {'coco_url': 'http://mscoco.org/images/167856',
#    'date_captured': '2013-11-16 04:14:25',
#    'file_name': 'COCO_train2014_000000167856.jpg',
#    'flickr_url': 'http://farm6.staticflickr.com/5093/5520648921_eb3ccfdb67_z.jpg',
#    'height': 360,
#    'id': 167856,
#    'license': 2,
#    'width': 640},
#   {'coco_url': 'http://mscoco.org/images/506097',
#    'date_captured': '2013-11-16 04:33:02',
#    'file_name': 'COCO_train2014_000000506097.jpg',
#    'flickr_url': 'http://farm6.staticflickr.com/5042/5336086737_ef5a46a54c_z.jpg',
#    'height': 360,
#    'id': 506097,
#    'license': 2,
#    'width': 640},
#   {'coco_url': 'http://mscoco.org/images/116956',
#    'date_captured': '2013-11-16 05:33:30',
#    'file_name': 'COCO_train2014_000000116956.jpg',
#    'flickr_url': 'http://farm5.staticflickr.com/4109/4959581705_1cb199952d_z.jpg',
#    'height': 544,
#    'id': 116956,
#    'license': 3,
#    'width': 640},
#   {'coco_url': 'http://mscoco.org/images/492303',
#    'date_captured': '2013-11-16 05:40:19',
#    'file_name': 'COCO_train2014_000000492303.jpg',
#    'flickr_url': 'http://farm5.staticflickr.com/4124/4975118301_59de2cd940_z.jpg',
#    'height': 453,
#    'id': 492303,
#    'license': 3,
#    'width': 640},
#   {'coco_url': 'http://mscoco.org/images/543217',
#    'date_captured': '2013-11-16 12:23:33',
#    'file_name': 'COCO_train2014_000000543217.jpg',
#    'flickr_url': 'http://farm4.staticflickr.com/3458/3901336894_eec6e4cd08_z.jpg',
#    'height': 424,
#    'id': 543217,
#    'license': 1,
#    'width': 640},
#   {'coco_url': 'http://mscoco.org/images/545124',
#    'date_captured': '2013-11-16 12:52:11',
#    'file_name': 'COCO_train2014_000000545124.jpg',
#    'flickr_url': 'http://farm9.staticflickr.com/8102/8543118233_3471866b11_z.jpg',
#    'height': 427,
#    'id': 545124,
#    'license': 3,
#    'width': 640},
#   {'coco_url': 'http://mscoco.org/images/416718',
#    'date_captured': '2013-11-16 12:53:26',
#    'file_name': 'COCO_train2014_000000416718.jpg',
#    'flickr_url': 'http://farm6.staticflickr.com/5493/9456989535_2722d91ae8_z.jpg',
#    'height': 427,
#    'id': 416718,
#    'license': 3,
#    'width': 640},
#   {'coco_url': 'http://mscoco.org/images/368440',
#    'date_captured': '2013-11-16 12:53:31',
#    'file_name': 'COCO_train2014_000000368440.jpg',
#    'flickr_url': 'http://farm8.staticflickr.com/7419/9165381756_957bf60618_z.jpg',
#    'height': 427,
#    'id': 368440,
#    'license': 3,
#    'width': 640},
#   {'coco_url': 'http://mscoco.org/images/526890',
#    'date_captured': '2013-11-16 13:05:46',
#    'file_name': 'COCO_train2014_000000526890.jpg',
#    'flickr_url': 'http://farm8.staticflickr.com/7211/6959655634_8b3e7ba3bb_z.jpg',
#    'height': 480,
#    'id': 526890,
#    'license': 1,
#    'width': 640},
#   {'coco_url': 'http://mscoco.org/images/188911',
#    'date_captured': '2013-11-16 13:10:46',
#    'file_name': 'COCO_train2014_000000188911.jpg',
#    'flickr_url': 'http://farm9.staticflickr.com/8304/8016581785_448c855e93_z.jpg',
#    'height': 478,
#    'id': 188911,
#    'license': 1,
#    'width': 640},
#   {'coco_url': 'http://mscoco.org/images/187844',
#    'date_captured': '2013-11-16 14:02:08',
#    'file_name': 'COCO_train2014_000000187844.jpg',
#    'flickr_url': 'http://farm9.staticflickr.com/8377/8437157906_0edc668db9_z.jpg',
#    'height': 427,
#    'id': 187844,
#    'license': 3,
#    'width': 640},
#   {'coco_url': 'http://mscoco.org/images/185888',
#    'date_captured': '2013-11-16 14:02:11',
#    'file_name': 'COCO_train2014_000000185888.jpg',
#    'flickr_url': 'http://farm9.staticflickr.com/8189/8437158176_0e2221f23d_z.jpg',
#    'height': 427,
#    'id': 185888,
#    'license': 3,
#    'width': 640},
#   {'coco_url': 'http://mscoco.org/images/24020',
#    'date_captured': '2013-11-16 14:02:20',
#    'file_name': 'COCO_train2014_000000024020.jpg',
#    'flickr_url': 'http://farm9.staticflickr.com/8335/8437158242_1a8a02be75_z.jpg',
#    'height': 427,
#    'id': 24020,
#    'license': 3,
#    'width': 640},
#   {'coco_url': 'http://mscoco.org/images/435284',
#    'date_captured': '2013-11-16 14:04:30',
#    'file_name': 'COCO_train2014_000000435284.jpg',
#    'flickr_url': 'http://farm9.staticflickr.com/8516/8436073457_0ae1e010f0_z.jpg',
#    'height': 427,
#    'id': 435284,
#    'license': 3,
#    'width': 640},
#   {'coco_url': 'http://mscoco.org/images/13188',
#    'date_captured': '2013-11-16 14:04:38',
#    'file_name': 'COCO_train2014_000000013188.jpg',
#    'flickr_url': 'http://farm9.staticflickr.com/8471/8437158738_2312f1bc15_z.jpg',
#    'height': 427,
#    'id': 13188,
#    'license': 3,
#    'width': 640},
#   {'coco_url': 'http://mscoco.org/images/438978',
#    'date_captured': '2013-11-16 14:05:53',
#    'file_name': 'COCO_train2014_000000438978.jpg',
#    'flickr_url': 'http://farm9.staticflickr.com/8513/8358609477_2aae445c64_z.jpg',
#    'height': 427,
#    'id': 438978,
#    'license': 3,
#    'width': 640},
#   {'coco_url': 'http://mscoco.org/images/111223',
#    'date_captured': '2013-11-16 14:25:36',
#    'file_name': 'COCO_train2014_000000111223.jpg',
#    'flickr_url': 'http://farm9.staticflickr.com/8036/8034415879_e420c18d9e_z.jpg',
#    'height': 427,
#    'id': 111223,
#    'license': 3,
#    'width': 640},
#   {'coco_url': 'http://mscoco.org/images/364303',
#    'date_captured': '2013-11-16 14:42:08',
#    'file_name': 'COCO_train2014_000000364303.jpg',
#    'flickr_url': 'http://farm9.staticflickr.com/8289/7772696810_9ea15ddac2_z.jpg',
#    'height': 427,
#    'id': 364303,
#    'license': 3,
#    'width': 640},
#   {'coco_url': 'http://mscoco.org/images/314681',
#    'date_captured': '2013-11-16 14:42:10',
#    'file_name': 'COCO_train2014_000000314681.jpg',
#    'flickr_url': 'http://farm8.staticflickr.com/7263/7772698096_c771bbeb34_z.jpg',
#    'height': 427,
#    'id': 314681,
#    'license': 3,
#    'width': 640},
#   {'coco_url': 'http://mscoco.org/images/412501',
#    'date_captured': '2013-11-16 14:42:15',
#    'file_name': 'COCO_train2014_000000412501.jpg',
#    'flickr_url': 'http://farm9.staticflickr.com/8449/7890963638_9c2433851c_z.jpg',
#    'height': 427,
#    'id': 412501,
#    'license': 3,
#    'width': 640},
#   {'coco_url': 'http://mscoco.org/images/476430',
#    'date_captured': '2013-11-16 14:43:01',
#    'file_name': 'COCO_train2014_000000476430.jpg',
#    'flickr_url': 'http://farm9.staticflickr.com/8030/7890965032_8c34591748_z.jpg',
#    'height': 427,
#    'id': 476430,
#    'license': 3,
#    'width': 640},
#   {'coco_url': 'http://mscoco.org/images/359030',
#    'date_captured': '2013-11-16 14:44:46',
#    'file_name': 'COCO_train2014_000000359030.jpg',
#    'flickr_url': 'http://farm4.staticflickr.com/3242/2503713791_863ca4c415_z.jpg',
#    'height': 480,
#    'id': 359030,
#    'license': 4,
#    'width': 640},
#   {'coco_url': 'http://mscoco.org/images/48947',
#    'date_captured': '2013-11-16 14:46:35',
#    'file_name': 'COCO_train2014_000000048947.jpg',
#    'flickr_url': 'http://farm9.staticflickr.com/8291/7853915338_1b9f068ab4_z.jpg',
#    'height': 426,
#    'id': 48947,
#    'license': 2,
#    'width': 640},
#   {'coco_url': 'http://mscoco.org/images/476515',
#    'date_captured': '2013-11-16 14:55:08',
#    'file_name': 'COCO_train2014_000000476515.jpg',
#    'flickr_url': 'http://farm4.staticflickr.com/3166/2393165707_09370123b7_z.jpg',
#    'height': 481,
#    'id': 476515,
#    'license': 1,
#    'width': 640},
#   {'coco_url': 'http://mscoco.org/images/368479',
#    'date_captured': '2013-11-16 14:56:18',
#    'file_name': 'COCO_train2014_000000368479.jpg',
#    'flickr_url': 'http://farm8.staticflickr.com/7114/7486064038_c42705f7fd_z.jpg',
#    'height': 427,
#    'id': 368479,
#    'license': 3,
#    'width': 640},
#   ...],
#  'info': {'contact': 'foil.unitn@gmail.com/ravi.shekhar@unitn.it',
#   'contributor': 'FOIL Group at University of Trento,Italy',
#   'date_created': 'July, 2017',
#   'description': 'This is 1st version of the 2017 FOIL dataset.',
#   'url': 'https://foilunitn.github.io/',
#   'version': '1.0',
#   'year': 2017},
#  'licenses': [{'id': 1,
#    'name': 'Attribution-NonCommercial-ShareAlike License',
#    'url': 'http://creativecommons.org/licenses/by-nc-sa/2.0/'},
#   {'id': 2,
#    'name': 'Attribution-NonCommercial License',
#    'url': 'http://creativecommons.org/licenses/by-nc/2.0/'},
#   {'id': 3,
#    'name': 'Attribution-NonCommercial-NoDerivs License',
#    'url': 'http://creativecommons.org/licenses/by-nc-nd/2.0/'},
#   {'id': 4,
#    'name': 'Attribution License',
#    'url': 'http://creativecommons.org/licenses/by/2.0/'},
#   {'id': 5,
#    'name': 'Attribution-ShareAlike License',
#    'url': 'http://creativecommons.org/licenses/by-sa/2.0/'},
#   {'id': 6,
#    'name': 'Attribution-NoDerivs License',
#    'url': 'http://creativecommons.org/licenses/by-nd/2.0/'},
#   {'id': 7,
#    'name': 'No known copyright restrictions',
#    'url': 'http://flickr.com/commons/usage/'},
#   {'id': 9,
#    'name': 'MS-COCO license',
#    'url': 'http://mscoco.org/terms_of_use/'},
#   {'id': 10,
#    'name': 'FOIL Dataste: By University of Trento under Creative Commons Attribution 4.0 License',
#    'url': 'http://creativecommons.org/licenses/by/4.0/'}]}

# %%
with open("cocoObject_target.txt") as in_file:
    obj_targ = [l.split()[0] for l in in_file.readlines()]
    
print(obj_targ)
# Out:
# ['airplane', 'apple', 'backpack', 'ball', 'banana', 'bat', 'bear', 'bed', 'bench', 'bicycle', 'bird', 'boat', 'book', 'bottle', 'bowl', 'broccoli', 'bus', 'cake', 'car', 'carrot', 'cat', 'chair', 'clock', 'couch', 'cow', 'cup', 'dog', 'donut', 'drier', 'elephant', 'fork', 'frisbee', 'giraffe', 'glass', 'glove', 'handbag', 'horse', 'hydrant', 'keyboard', 'kite', 'knife', 'laptop', 'microwave', 'motorcycle', 'mouse', 'orange', 'oven', 'phone', 'pizza', 'racket', 'refrigerator', 'remote', 'sandwich', 'scissors', 'sheep', 'sink', 'skateboard', 'skis', 'snowboard', 'spoon', 'suitcase', 'surfboard', 'table', 'tie', 'toaster', 'toilet', 'toothbrush', 'train', 'truck', 'tv', 'umbrella', 'vase', 'zebra']

# %%
with open("annotations_trainval/captions_train2017.json") as in_file:
    train_coco = json.load(in_file)

# %%
train_captions_per_image = dict()

# %%
print(train_coco['annotations'][0])
# Out:
# {'image_id': 203564, 'id': 37, 'caption': 'A bicycle replica with a clock as the front wheel.'}

# %%
for tc in train_coco['annotations']:
    if tc['image_id'] in train_captions_per_image:
        train_captions_per_image[tc['image_id']].append((tc['caption'], tc['id']))
    else:
        train_captions_per_image[tc['image_id']] = [(tc['caption'], tc['id'])]

# %%
train_captions_per_image
# Out:
# {203564: [('A bicycle replica with a clock as the front wheel.', 37),
#   ('The bike has a clock as a tire.', 181),
#   ('A black metal bicycle with a clock inside the front wheel.', 478),
#   ('A bicycle figurine in which the front wheel is replaced with a clock\n',
#    6637),
#   ('A clock with the appearance of the wheel of a bicycle ', 6802)],
#  322141: [('A room with blue walls and a white sink and door.', 49),
#   ('Blue and white color scheme in a small bathroom.', 109),
#   ('This is a blue and white bathroom with a wall sink and a lifesaver on the wall.',
#    121),
#   ('A blue boat themed bathroom with a life preserver on the wall', 163),
#   ('A bathroom with walls that are painted baby blue.', 250)],
#  16977: [('A car that seems to be parked illegally behind a legally parked car',
#    89),
#   ('two cars parked on the sidewalk on the street', 185),
#   ('City street with parked cars and a bench.', 626),
#   ('Cars try to maneuver into parking spaces along a densely packed city street. ',
#    1229),
#   ('A couple of cars parked in a busy street sidewalk.', 3506)],
#  106140: [('A large passenger airplane flying through the air.', 98),
#   ('There is a GOL plane taking off in a partly cloudy sky.', 101),
#   ('An airplane that is, either, landing or just taking off.', 221),
#   ('An red and white airplane is in the cloudy sky.', 2219),
#   ('A passenger plane taking off into the sky. ', 3560)],
#  571635: [('A bathroom with a toilet, sink, and shower.', 342),
#   ('A full bathroom with a wicker laundry basket.', 3765),
#   ('A little bathrood decorated with many colorful objects', 9687),
#   ('A small bathroom containing a toilet and sink. ', 11109),
#   ('Bathroom containing a toilet, a sink and a wicker basket.', 11517)],
#  301837: [('A long empty, minimal modern skylit home kitchen.', 391),
#   ('A picture of a modern looking kitchen area\n', 2599),
#   ('A narrow kitchen ending with a chrome refrigerator.', 3694),
#   ('A narrow kitchen is decorated in shades of white, gray, and black.', 5209),
#   ('a room that has a stove and a icebox in it', 820033)],
#  315702: [('A bathroom sink with toiletries on the counter.', 437),
#   ('A bathroom sink and various personal hygiene items.', 452),
#   ('A messy bathroom countertop perched atop black cabinetry.', 791),
#   ('A bathroom vanity with cabinets and basin sink and several grooming products scattered across it',
#    6566),
#   ('A bathroom sink cluttered with multiple personal care items.', 8510)],
#  189634: [('This is an open box containing four cucumbers.', 455),
#   ('An open food container box with four unknown food items.', 833),
#   ('A small box filled with four green vegetables. ', 1907),
#   ('An opened box of four chocolate bananas. ', 5384),
#   ('An open box contains an unknown, purple object', 6614)],
#  472598: [('An old-fashioned green station wagon is parked on a shady driveway.',
#    456),
#   ('An old teal colored car parked on the street.', 834),
#   ('A classic car sitting beside the road with a surfboard on top. ', 1908),
#   ('An old green car parked on the side of the street.', 5385),
#   ('An antique, turquoise car is parked at the curb', 6615)],
#  162113: [('A gas stove next to a stainless steel kitchen sink and countertop.',
#    464),
#   ('A kitchen stove, sink, and counter with stuff on it.', 2666),
#   ('A kitchen with a stove, sink, and drying area. ', 5369),
#   ('This is a kitchen with dishes and a silver sink.', 6401),
#   ('A kitchen with a stove, sick, and dishes', 6785)],
#  126657: [('Several motorcycles riding down the road in formation.', 565),
#   ('A group of motorcycle riders driving past buildings.', 931),
#   ('A group of people are riding motorcycles on a road through a town. ',
#    6127),
#   ('A group of motorcyclists are driving down the city street.', 8866),
#   ('A group of motorcycles drive down a city street.', 821689)],
#  285421: [('A black cat is inside a white toilet.', 589),
#   ('A black cat drinking water from a toilet', 2242),
#   ('A cat drinking water from a toilet in a bathroom.', 2761),
#   ('A cat puts her head inside of a toilet. ', 5440),
#   ('A cat is drinking water out of a toilet.', 6241)],
#  71988: [('A man in a wheelchair and another sitting on a bench that is overlooking the water.',
#    699),
#   ('Two people sitting on dock looking at the ocean.', 3840),
#   ('Two older people sitting down in front of a beach.', 4173),
#   ('An old couple at the beach during the day.', 4740),
#   ('A person on a bench, and one on a wheelchair sitting by a seawall looking out toward the ocean',
#    5535)],
#  193622: [('A man sits with a traditionally decorated cow', 701),
#   ('A decorative man sits on the ground with a cow.', 4781),
#   ('A man sits next to his horse in an alley in costume.', 6101),
#   ('Guy and cow are sitting on the floor ', 6647),
#   ('An Indian man in religious attire sitting with a decorated cow.', 818431)],
#  459912: [('Rows of motor bikes and helmets in a city', 748),
#   ('A lot of motorbikes line up down a busy street.', 4633),
#   ('Large set of motorcycles all lined up down a street.', 8323),
#   ('A large group of motorcycles lined up on the street.', 10096),
#   ('A series of motorbikes parked in a row on a street', 15466)],
#  548498: [('A cute kitten is sitting in a dish on a table.', 754),
#   ('A small white cat on a large bowl.', 4027),
#   ('A small kitten is sitting in a bowl. ', 5377),
#   ('A cat is curled up in a bowl', 7522),
#   ('A kitten is sitting in a bowl on a table.', 820216)],
#  52087: [('A man getting a drink from a water fountain that is a toilet.',
#    827),
#   ('A boy drinking water from a toilet water fountain.', 1400),
#   ('A young man drinking from a water fountain in the shape of a toilet.',
#    2045),
#   ('A young person has his face close to the toilet bowl.', 4319),
#   ('A man taking a drink from a water fountain.', 4571)],
#  119964: [('A person holding a skateboard overlooks a dead field of crops.',
#    891),
#   ('A person sits on a patch of grass observing the scenery.', 1302),
#   ('A person holding a skate board sitting in an empty open field.', 4347),
#   ('A child with a skateboard sitting on the grass and looking at an empty field',
#    6216),
#   ('A skateboarder sitting on the edge of an open field.', 819328)],
#  230610: [('A bathroom with a sink and shower curtain with a map print.', 935),
#   ('A small and crowded bathroom with little furnishing ', 1484),
#   ('A small bathroom with a shower curtain with the NYC Subway map on it. ',
#    3446),
#   ('A bathroom with a map as a shower curtain. ', 3455),
#   ('A bathroom with pedestal sink and mirror over it.', 4193)],
#  226419: [('A random plane in the sky flying alone', 939),
#   ('An airplane flying high in the blue sky. ', 945),
#   ('A silver color jet flying through the clear sky.', 4047),
#   ("An airplane with the letters 'MT' on it, flying in the sky.", 8754),
#   ('A very large plane is flying through the sky.', 9174)],
#  218026: [('A brown and black horse in the middle of the city eating grass.',
#    961),
#   ('Two horses eating grass near a parking lot. ', 6583),
#   ('Two horses standing in a field across the stre.et from a building', 7039),
#   ('Two mules eating grass in a parking lot in front of a hotel. ', 10831),
#   ('Two horses eat grass next to a group of parked cars.', 819639)],
#  352538: [('A brown purse is sitting on a green bench.', 974),
#   ('a brown purse abandoned on a green bench.', 4355),
#   ("A woman's purse sitting on a park bench.", 6032),
#   ("A leather purse laying on it's side on a green metal bench.", 7670),
#   ('A purse sits alone on a park bench.', 9986)],
#  202913: [('Half of a white cake with coconuts on top.', 1034),
#   ('The coconut cake on a red plate is half gone.', 4100),
#   ('A half eaten dessert cake sitting on a cake plate.', 4397),
#   ('A half eaten cake with coconut shavings and creme filling.', 7637),
#   ('Half of a cake sits on a plate.', 7979)],
#  202658: [('An old toilet with a hello kitty cover top. ', 1037),
#   ('A toilet with a Hello Kitty symbol on it.', 4844),
#   ('A toilette with a pink hello kitty toilette seat cover.', 10187),
#   ('A toilet with a Hello Kitty seat sitting in a room.', 10208),
#   ('A broken toilet bowl with  a Hello Kitty toilet seat cover.', 11897)],
#  79472: [('Office space with office equipment on desk top.', 1104),
#   ('A hope office setup of computers and printers.', 2376),
#   ('a home office with laptop, printer, scanner, and extra monitor', 2607),
#   ('The computer desk in the corner is by a window.', 6297),
#   ('A laptop, monitor, printer and tablet on a desk.', 825384)],
#  346071: [("Two husky's hanging out of the car windows.", 1113),
#   ('Dogs stick their heads out of car windows', 1248),
#   ('Two husky dogs ride in a car with their heads hanging out windows.', 5958),
#   ('Two happy dogs have their head out the car window.', 6501),
#   ('Some dogs stick their heads out the car window.', 10539)],
#  6672: [('The back door with a window in the kitchen.', 1132),
#   ('The kitchen has a white door with a window.', 2155),
#   ('A kitchen door next to a kitchen sing and counter top.', 3577),
#   ('A sink next to a large white door ', 5812),
#   ('A door for exiting and entering the house in the kitchen.', 12427)],
#  419074: [('Jet liner flying off into the distance on an overcast day', 1137),
#   ('An airplane flying away in a cloudy sky.', 3762),
#   ('A plane that is flying in a clear blue sky.', 4329),
#   ('An airplane flying away in the cloudy sky.', 9564),
#   ('Four engine plane flying in lightly overcast sky.', 821675)],
#  382406: [('A woman is walking a dog in the city.', 1221),
#   ('A woman and her dog walking down a sidewalk next to a fence with some flowers. ',
#    1620),
#   ('A woman walking her dog on the sidewalk.', 2091),
#   ('A woman walks her dog along a city street.', 3237),
#   ('A woman walks her dog on a city sidewalk.', 7911)],
#  175948: [('A tiny bathroom with only a toilet and a shelf.', 1327),
#   ('Small bathroom with a toilet and a sink.', 4957),
#   ('A narrow bathroom has a white door on its side', 6475),
#   ('Rather narrow bath room that appears to be being remodeled.', 10216),
#   ('Unfinished bathroom with broken toilet next to a bookshelf.', 10960)],
#  573223: [('A little girl in a public bathroom for kids.', 1373),
#   ('A girl standing next to a toilet in a bathroom.', 3728),
#   ('Little girl in blue dress standing in a bathroom. ', 8051),
#   ('An adorable little girl in a blue dress stands in a restroom.', 8495),
#   ('A little girl in a blue dress stands in a bathroom.', 9740)],
#  402514: [('A picture of a man playing a violin in a kitchen.', 1436),
#   ('A man is playing violin in his kitchen', 1706),
#   ('A man is playing a fiddle in his kitchen.', 6023),
#   ('A man plays the violin in a home.', 12356),
#   ('An old man playing violin in a kitchen.', 15620)],
#  407286: [("A trio of dogs sitting in their owner's lap in a red convertible.",
#    1494),
#   ("Three little dogs looking out a car window while sitting on a woman's lap. ",
#    2028),
#   ('A woman driver has three dogs in the seat with her.', 2919),
#   ('A woman and her three dogs in a car.', 3417),
#   ("Three dogs on the lap of a woman in the driver's seat of a convertible.",
#    5568)],
#  82673: [('A small car is parked in front of a scooter', 1562),
#   ('A scooter is parked behind a red car.', 11969),
#   ('A small car parked in by a vespa.', 12713),
#   ('A bus rides by a small car parked in front of a motor scooter', 16211),
#   ('A small car sits parked in front of a scooter. ', 826966)],
#  141172: [('A door with a sticker of a cat door on it', 1637),
#   ("A blue door with a painting of a cat's rear end entering thru a cat door.",
#    7481),
#   ('A blue door with a picture of a cat door with cats backside hanging out on it.',
#    11318),
#   ('A picture of a cat door is on the bottom corner of a blue door.', 11615),
#   ('A painting on a door of a cat going through a cat door.', 16073)],
#  104326: [('A pinewood and green modern themed kitchen area.', 1693),
#   ('A kitchen and dining room area with a large window.', 2167),
#   ('A green kitchen with wooden counters and bright lights. ', 5338),
#   ('A bright room with green walls and cabinets.', 6394),
#   ('An empty kitchen area painted green with bulbous lights.', 8479)],
#  581177: [('A kitchen is shown with wooden cabinets and a wooden celling.',
#    1766),
#   ('A recently remodeled kitchen with marble and wooden furnishings.', 1865),
#   ('Well kept kitchen with marble counter tops and stainless steel fridge',
#    2258),
#   ('A beautiful new kitchen with natural wood cabinets.', 3125),
#   ('A neat, wood filled kitchen is photographed as if for a real estate ad.',
#    3365)],
#  267802: [('A group of people riding mopeds in a busy street. ', 1774),
#   ('People riding bikes and cars down the street. ', 4036),
#   ('Motorists and bicyclists in a busy city square.', 6319),
#   ('A crowded city street filled with traffic and bicycles.', 8206),
#   ('An Asian intersection is full of mopeds and motorcycles.', 8899)],
#  208408: [('A person walking in the rain on the sidewalk. ', 1828),
#   ('A person walking through the rain with an umbrella.', 2383),
#   ('A person walking in the rain while holding an umbrella.', 2884),
#   ('A man walks down the strip as it rains.', 13573),
#   ('A European street scene with a person and vehicles.', 16123)],
#  560591: [('a modern flush toilet in a bathroom with tile. ', 1886),
#   ('A toilet and trashcan in a white bathroom.', 4118),
#   ('A white toilet sits on a tile floor.', 5006),
#   ('A toilet in a bathroom that is next to a trash can', 6269),
#   ('White toilet by built-in shelves in a tiled bathroom.', 7679)],
#  507362: [('Fog is in the air at an intersection with several traffic lights.',
#    1933),
#   ('An intersection during a cold and foggy night.', 2830),
#   ('Empty fog covered streets in the night amongst traffic lights.', 4372),
#   ('City street at night with several stop lights.', 11200),
#   ('It is a foggy night by a traffic light.', 823544)],
#  57429: [('An airplane with its landing wheels out landing. ', 2049),
#   ('A plane that is taking off at an airport', 2139),
#   ('A man takes a picture of an airplane taking off.', 2946),
#   ('A large jet takes off from an airport runway.', 5520),
#   ('The airplane is taking off on the runway at the airport.', 821117)],
#  153184: [('Little birds sitting on the shoulder of a giraffe. ', 2076),
#   ("The top of a giraffe's head has birds on it.", 2121),
#   ('Three birds sit on the back of a giraffe. ', 4653),
#   ('A giraffe with 3 birds on his fur.', 4731),
#   ('A flock of birds sits on top of a large giraffe.', 5922)],
#  571970: [('a man with a bike at a marina', 2099),
#   ('A man stands next to his bike at the marina.', 4142),
#   ('an old man standing next to a bike and a chain fence.', 4190),
#   ('A man holding some break standing by a bicycle.', 4949),
#   ('A man who is standing next to his bicycle.', 820171)],
#  133680: [('A man is sitting on a bench next to a bike.', 2152),
#   ('A man is sitting on a bench next to a bicycle.', 2686),
#   ('A man sits on a street bench by a bike. ', 4855),
#   ('Black man sitting on a bench behind a personal bicycle. ', 8278),
#   ('A man is sitting in a busy area with his bike.', 9178)],
#  139011: [('People are waiting for the bus near a bus stop.', 2154),
#   ('A crowd of people are waiting to get on a red bus.', 2688),
#   ('A crowd of people get ready to board a bus in the city.', 4857),
#   ('Large group of people waiting for a train.', 8280),
#   ('People are waiting in a city area to board a bus.', 9180)],
#  505386: [('four urinals in a public restroom with a window', 2192),
#   ('A bathroom with four urinals on the wall.', 2576),
#   ('An old bathroom with a row of urinals.', 3362),
#   ('A row of urinals in with an open window above them.', 4052),
#   ('A row of urinals stand beneath a open window.', 4985)],
#  107990: [('A small child climbs atop a large motorcycle', 2405),
#   ('A young boy riding a motorcycle next to a silver car.', 3200),
#   ('A little baby is sitting on a huge motorcycle.', 3302),
#   ('A little boy sitting alone on a motorcycle.', 3710),
#   ('A toddler sitting on a motorcycle in a parking lot.', 5387)],
#  527510: [('A large U.S Air Force plain sits on an asphalt ramp.', 2450),
#   ('A large propeller airplane sitting on a tarmac.', 4604),
#   ('A large military plane parked in the landing area.', 7274),
#   ('A U.S. Air Force plane sits on display.', 7799),
#   ('A picture of a plane in a runway.', 15956)],
#  5247: [('A black and white photo of an older man skiing.', 2473),
#   ('Two people on the snow for cross country skiing.', 2620),
#   ('The old man cross country skis through the forest.', 4594),
#   ('A younger man and an older man skiing in the forest.', 5227),
#   ('Two people on skis going through the woods.\n', 7993)],
#  107960: [('Riding a motorcycle down a street that has no one else on it.',
#    2655),
#   ("The view from a motorcyclist's point of view, looking down a street.",
#    5580),
#   ('A man rides a motorcycle down an empty street next to houses.', 5757),
#   ('The view of the street from the perspective of the rider of a motorcycle',
#    6282),
#   ('A motorcycle moves forward down an empty street.', 11523)],
#  410627: [('The young man is stirring his pot of food with a wooden spoon.',
#    2961),
#   ('A man enjoys cooking food in a pan', 6444),
#   ('A smiling man is cooking in his kitchen.', 8523),
#   ('A man smiles as he stirs his food in the pot.', 8649),
#   ('A boy smiles while holding a pot and spoon.', 826886)],
#  232223: [('A fighter jet is flying at a fast speed.', 3001),
#   ('A fighter jet soars up into a blue sky.', 8083),
#   ('An old military jet fighter climbing in altitude.', 8380),
#   ('A fighter jet flying through the sky with smoke coming off of it.', 12349),
#   ('A figher jet creating condensation flying through the blue sky.', 14749)],
#  22793: [('A public bathroom with a bunch of urinals.', 3043),
#   ('A picture of a woman hangs on the wall above the urinals.', 4852),
#   ("A men's restroom with a poster of a woman over the urinals.", 7096),
#   ('White tiled bathroom with line of tiles and Asian female poster on the wall',
#    8881),
#   ('A mens restroom is lined up with urinals.', 10951)],
#  436456: [('The airplane is on the runway with two young men standing by.',
#    3106),
#   ('Two men walking the tarmac of an airport.', 8113),
#   ('Two men at on an airport tarmac. \n', 9673),
#   ('Two young men walking down a runway toward an airplane.', 12433),
#   ('Young men are preparing to board a small passenger plane.', 824254)],
#  368402: [('The woman in the kitchen is holding a huge pan.', 3192),
#   ('A chef carrying a large pan inside of a kitchen.', 3759),
#   ('A woman is holding a large pan in a kitchen. ', 6822),
#   ('A woman cooking in a kitchen with granite counters.', 10359),
#   ('A woman cooking in her kitchen with a black pan.', 10533)],
#  135161: [('A toilet sits next to a window and in front of a shower.', 3205),
#   ('A bathroom with only a toilet and tub with the wall covered in plastic',
#    5884),
#   ('A photograph of a bathroom undergoing some renovations.', 7996),
#   ('A bathroom being renovated featuring a toilette and shower.', 9709),
#   ('A bathroom in the middle of a reconstruction phase.', 10243)],
#  178761: [('A dog and a goat with their noses touching at fence.', 3586),
#   ('A dog greets a sheep that is in a sheep pen.', 6079),
#   ('Two animals get close through a fence. ', 6676),
#   ('A sheep and a dog touching noses through a fence.', 9718),
#   ('a couple of animals that are beside a fence', 824537)],
#  491000: [('Pedestrians walking down a sidewalk next to a small street.',
#    3753),
#   ('People walking on a city street with light traffic.', 5862),
#   ('A city street with people walking and vehicles on the road.', 8109),
#   ('A scenic photograph of an urban street with people and traffic.', 10614),
#   ('Pedestrians are strolling along a city sidestreet in a touristy neighborhood.',
#    14235)],
#  538092: [('A man standing in a kitchen while closing a cupboard door.', 3903),
#   ('A man standing in kitchen surrounded by items.', 10146),
#   ('A kitchen area with a cooler and container stacked on the floor and a man getting an item out of a cabinet.',
#    11235),
#   ('A man holding a cabinet in a kitchen.', 16539),
#   ('a man stocking up his kitchen with groceries', 820085)],
#  205577: [('A photograph of a kitchen inside a house.', 4205),
#   ('This is an apartment kitchen with white cabinets and appliances.', 9113),
#   ('A shot of a kitchen with a microwave, sink, dishwasher, and refrigerator. ',
#    10733),
#   ('A kitchen with a refrigerator, microwave, dishwasher and sink.', 11933),
#   ('A kitchen with a sink, dishwasher, microwave and refrigerator.', 820256)],
#  508672: [('a bike leaning on a metal fence next to some flowing water. ',
#    4220),
#   ('A bicycle parked next to a flooded river', 6371),
#   ('A bicycle chained to a rail near a flooded area.', 9575),
#   ('A bicycle leans against a fence near some flood waters.', 11777),
#   ('A bicycle parked on a rail next to some flooding water.', 819895)],
#  334015: [('a small toilet stall with a toilet brush and 3 rolls of toilet paper ',
#    4386),
#   ('A clean, European toilet with toilet paper and cleaning brush.', 5871),
#   ('A public toilet stall with toilet paper and a cleaning brush.', 7032),
#   ('An empty, clean toilet stall with a stack of toilet paper.', 8724),
#   ('There is a white toilet in a very narrow bathroom.', 821063)],
#  27842: [('A dual sink vanity with mirrors above the sinks.', 4451),
#   ('A long marble like bath room vanity with a stool, two sink basins with mirrors and lights over them',
#    5795),
#   ('A double sink with mirrors and a stool underneath it.', 10865),
#   ('There are two sinks in the clean bathroom.', 11279),
#   ('A bathroom with his and her mirrors and sinks.', 12137)],
#  358606: [('A fireplace with a fire built in it.', 4710),
#   ('A living room containing a modern fireplace and miscellaneous items ',
#    6165),
#   ('A lit fire place in a living room next to a TV.', 8433),
#   ('A brick fireplace with fire adorned with knick-knacks.', 12675),
#   ('A living room, with fireplace, television, and throw rug.', 14952)],
#  567730: [('The sign of a restaurant in the outside of the store.', 4774),
#   ('A sign on a building advertising an Italian restaurant.', 4840),
#   ('A sign for an Italian restaurant hangs outside a building.', 5749),
#   ('Italian Reaffaello restaurant sign at front of building.', 6190),
#   ('A sign outside of a restaurant for Italian food. ', 6928)],
#  61259: [('an airport with one plane flying away and the other sitting on the runway',
#    5008),
#   ('jumbo jet sits on the tarmac while another takes off', 5431),
#   ('A Virgin Australia airline on the tarmac. ', 6106),
#   ('Virgin sponsored airplane parked with a plane leaving in the background.',
#    8089),
#   ('One airplane is taking off from an airport while others are parked.',
#    11329)],
#  554037: [('a counter with vegetables, knife and cutting board on it. ', 5010),
#   ('asparragus, lemons and a bowl of rice on a counter top', 5433),
#   ('The preparation of salmon, asparagus and lemons. ', 6108),
#   ('Cooking table with assorted fish and lemons with asparagus. ', 8091),
#   ('A kitchen counter with cutting board, knife and food.', 11331)],
#  5394: [('A boat that looks like a car moves through the water. ', 5018),
#   ('A car modified to drive in the water on a lake.', 5024),
#   ('A car modified to be a boat on the water.', 5618),
#   ('A picture of a boat that looks like a car in the water.', 15755),
#   ('a car that has been converted into a boat floating on water', 19268)],
#  455384: [('A delivery truck with an advertisement for Entourage.', 5173),
#   ('A large van features an ad for a television show.', 5458),
#   ('A truck with an ad for a television show painted on its side', 6841),
#   ("A large delivery truck with an advertisement painted on it's side.", 7423),
#   ('An entourage decorated van is parked on the side of the road.  ', 820679)],
#  249352: [('A black and white toilet with a plunger.', 5174),
#   ('A toilet has a rug, and a plunger next to it.', 5459),
#   ('A small stall with large tiles, a toilet and two plungers', 6842),
#   ('A small restroom with a single toilet and wooden toilet seat.', 7424),
#   ('A toilet, plunger and rug in a tiled bathroom stall.', 822243)],
#  348306: [('A bike leaning against a sign in Scotland.', 5283),
#   ('A bike in front of a scenic welcome sign. ', 5292),
#   ('a welcome to Scotland sign with a bicycle leaning on it', 6588),
#   ('Bicycle leaning up against a welcome to Scotland sign.', 9696),
#   ('A sign for a village in Scotland with a bicycle in front of it.', 10128)],
#  475593: [('Women father around a desk and machinery in a factory.', 5537),
#   ('A photo set of two women at work', 6725),
#   ('Women working in a commercial bakery or kitchen.', 9977),
#   ('Two old photos with women in a kitchen.', 16349),
#   ('two women in white work at an industrial kitchen counter and stove',
#    819196)],
#  145523: [('A few items sit on top of a toilet in a bathroom stall.', 5653),
#   ('A dirty toilet in a small bathroom.with items on top.', 6301),
#   ('A toilet seat is left open inside of a bathroom.', 13792),
#   ('A dirty toilet in a small cramped space.', 17137),
#   ('A photo of a toilet with items on the tank.', 25516)],
#  143370: [('A bathroom with a poster of an ugly face above the toilette.',
#    5786),
#   ('A bathroom with a white toilet and sink.', 7337),
#   ('Large bathroom with light flowing in the window.', 8030),
#   ('A small bathroom with a toilet by the window and a pedestal sink with a mirrored medicine cabinet over it',
#    9509),
#   ('A bathroom with a toilet and a sink.', 16136)],
#  279806: [('A dirt bike rider doing a stunt jump in the air', 5835),
#   ('A man riding a dirt bike becomes airborne.', 8427),
#   ('A motorcyclist is in mid air hanging on to the handlebars.', 10986),
#   ('A person performs a stunt jump on a motorcycle.', 12540),
#   ('Daring guy does tricks mid air on motorcycle', 819868)],
#  59171: [('A couple of birds fly through a blue cloudy sky.', 5945),
#   ('Group of three people sailing kites up in the sky. ', 8357),
#   ('A beautiful blue and pink sky overlooking the beach.', 8612),
#   ('Group of people are flying kites on the beach.', 11252),
#   ('This is a gorgeous sunset at a beach with a parasailor in the distance.',
#    824548)],
#  369826: [('A picture advertising Arizona tourism in an airport', 6018),
#   ('A television that is sitting next to signs', 6672),
#   ('A television is shown in the middle of a baggage claim area.', 9123),
#   ('An airport terminal has a big screen displaying an ad for Arizona.', 9897),
#   ('A flat screen TV with a picture of a person jumping on it.', 11142)],
#  400552: [('A variety of pots are stored in a nook by a fireplace.', 6562),
#   ('A room contains baskets and has a fireplace. ', 6700),
#   ('A room filled with clutter and a fireplace.', 7717),
#   ('A small living room with a fireplace and work baskets.\n', 10264),
#   ('A room with a fir place and several baskets and a bench in the background.',
#    11542)],
#  238836: [('A car is stopped at a red light', 6666),
#   ('The car is at the intersection while the sun is setting.', 9264),
#   ('A truck nears a stop light in rainy weather.', 9270),
#   ('A car is at a red light in the rain.', 10845),
#   ('An intersection with a red traffic light and a vehicle.', 18810)],
#  264461: [('A bathroom with a traditional toilet next to a floor toilet.',
#    6752),
#   ('A squat toilet and a Western toilet are next to each other.', 7049),
#   ('Mans bathroom with two visible fixtures, trash basket and plunger in sight.',
#    10325),
#   ('A toilet stall, complete with two clean toilets.', 11315),
#   ('A bathroom with an odd toilette next to a normal toilette.', 11702)],
#  342387: [('A group of people preparing food in a kitchen.', 7454),
#   ('Group of people all sorting vegetables in a line.', 8198),
#   ('Six different people in aprons and hats preparing vegetables', 10973),
#   ('A group of people are in a line working on green vegetables.', 12851),
#   ('A team of chefs work together to prepare a meal.', 15170)],
#  488327: [('Posted signs point the way through a parking garage.', 7627),
#   ('Three traffic signs at the entrance of a parking garage. ', 11512),
#   ('Three road signs posted in a parking garage.', 12007),
#   ('This is a parking garage with several signs.', 14275),
#   (' directing signs in front of a parking garage', 15457)],
#  540860: [('A green car on display next to a busy street.', 7732),
#   ('A sculpture of a green hot rod on a city sidewalk', 11986),
#   ('A sculpture of a hot rod sitting on a sidewalk.', 12496),
#   ('This is a city art piece of a small car.', 828028),
#   ('A small green vehicle model is on display next to a busy city street.',
#    828310)],
#  172851: [('A large passenger jet taking off from an airport.', 7748),
#   ('A plane that just took off flying from an airport.', 9845),
#   ('The airplane has begun its ascent in the skies.', 11138),
#   ('A plane is shown taking off from an airstrip.', 15059),
#   ('An airplane is taking off at an airport.', 18533)],
#  486194: [('Young woman carrying an opened umbrella in a city neighborhood.',
#    7777),
#   ('A woman walking while holding up a red umbrella ', 9691),
#   ('A beautiful young lady walking in the rain while holding an umbrella.',
#    11860),
#   ('A woman holding a red umbrella traveling down a sidewalk.', 16924),
#   ('A young woman is carrying a red umbrella.', 17848)],
#  236148: [("An older man backing up a truck with a bicycle in it's flat bed.",
#    8226),
#   ('A man looking out the back window of his truck.', 11508),
#   ('A man sits in the drivers seat of a truck.', 15198),
#   ('A man in a truck looks out his rear window.', 15441),
#   ('A man in a truck looking behind him.', 22356)],
#  115930: [('A group of men standing in front of a bar having a conversation.',
#    8299),
#   ('Restaurant staff taking a break near the bar.', 12169),
#   ('Several men having a conversation at a restaurant.', 12313),
#   ('Three workers at a restaurant visiting with each other and customers.',
#    19339),
#   ('Three chefs talking to each other at a bar.', 818690)],
#  75663: [('A children play area absent of any children.', 8469),
#   ('A craft supply room with craft supplies and containers.', 12189),
#   ('A work area room that is very very clean.', 13488),
#   ("A little children's classroom with materials and toys. ", 20421),
#   ('A counter top that has bins and a bucket of glue on it.', 21159),
#   ('A toy kitchen with a small table phone hat and teddy bear, with assorted crafts on the counter.',
#    21516)],
#  352794: [('Fruit in a jar filled with liquid sitting on a wooden table.',
#    8503),
#   ('Some yellow objects are floating in red liquid in a jar.', 10570),
#   ('There is a jar filled with an unknown liquid and solid.', 14044),
#   ('A jar of homemade sangria sitting on a table.', 14398),
#   ('A jar filled with liquid sits on a wood surface.', 15172)],
#  175954: [('A work station in use inside an office.', 8739),
#   ('A desk inside a library with a computer and several papers on it.', 9345),
#   ('A workstation with a computer, notebook, and papers.', 9624),
#   ('An office desk with a lot of paperwork and a turned on computer', 10002),
#   ('The computer is turned on at the cluttered workstation.', 818412)],
#  484751: [('Three computer screens showing a panoramic beach scene.', 8833),
#   ('Three computer screens at a desk show a panoramic view of the ocean.',
#    9616),
#   ('A desk with multiple computer screens forming one large screen.', 11821),
#   ('A computer desk with a triple monitor computer setup.', 13846),
#   (' There are three tvs with a keyboard in front of it', 824851)],
#  457834: [('Elephants are in a long line with people on top of them.', 8986),
#   ('Several people riding on the back of elephants', 12949),
#   ('A group of men riding elephants down a street surrounded by trees.',
#    13489),
#   ('People riding on top of elephants that are walking in a line across a road. ',
#    14041),
#   ('There is a parade of elephants walking across the road.', 818980)],
#  412151: [('A bicycle store shows two males leaning toward a bike.', 9006),
#   ('A man adjust a bicycle in a bike shop with a child.', 9891),
#   ('The bike shop employee is helping a customer. ', 12564),
#   ('A man and a boy are talking about a bicycle in a store.', 12831),
#   ('Two people in a shop looking at a bike.', 15861)],
#  427091: [('City traffic and pedestrians are headed in multiple directions on the street.',
#    9108),
#   ('A city street busy with many cars driving as well as pedestrians', 9861),
#   ('People in a city cross in front of traffic. ', 13542),
#   ('Traffic in New York City during the day. ', 17190),
#   ('Cars stopped on a busy street while pedestrians cross.', 18333)],
#  32203: [('There are some dirt bike riders taking a sharp turn', 9195),
#   ('Dirt bikers racing around a corner on the track', 14196),
#   ('Motor bike racers race each other around a track.', 14592),
#   ('Dirt bike racers rounding a corner on a track with orange barriers',
#    15378),
#   ('Three people on motorbikes racing around a track.', 823682)],
#  525971: [('A large group of motorcycle riders collect in a parking lot. ',
#    9250),
#   ('A street full of motorcycles and their riders', 10045),
#   ('Several bikers are lined up in a parking lot.', 10657),
#   ('Motorcyclist meeting with one another before a ride.', 11221),
#   ('There is no picture or image sorry sorry', 11740)],
#  354572: [('People sitting under an umbrella looking at the scenery.', 9434),
#   ('A person with a colorful umbrella sits on a fountain.', 10718),
#   ('A man with a colored umbrella sits on a monument.', 12197),
#   ('A man sis on a public area while holding an umbrella.', 12731),
#   ('This is a photo of two people sitting on the ledge of a piece of city artwork.',
#    824568)],
#  185360: [('A cow standing next to a damaged car on a dirty lot.', 9595),
#   ('A broken down car being investigated by a cow.', 14218),
#   ('A cow stands in the mud next to a car.', 15274),
#   ('An abandoned car and a cow on a field.', 16114),
#   ('A cow standing by a damaged car in a field.', 18463)],
#  321064: [('A small wooden table covered with delicious vegetables. ', 9990),
#   ('A dining table with a bowl of garlic cloves.', 10107),
#   ('A kitchen table with a juicer and vegetable on it.', 11460),
#   ('A kitchen table with vegetables and food processor.', 17883),
#   ('A food processor sit on a small table in a kitchen next to fresh vegetables and a colander of mushrooms.',
#    825083)],
#  263664: [('A couple on a motorcycle in front of a bus and a metermaid car',
#    10031),
#   ('A busy city street with a bus, taxi, and motorcycle.', 10940),
#   ('A bus, riksha, and two men on a scooter all on the same road. ', 16928),
#   ('Buses and motorcycles driving down a city street.', 19043),
#   ('Two people riding on a moped with a bus in the next lane.', 19712)],
#  468508: [('A red motorcycle parked on a sidewalk near multi-story buildings.',
#    10100),
#   ('A motorcycle that is parked on the side of the road.', 13526),
#   ('A motorcycle is parked on a cobblestone road', 13751),
#   ('A red motorcycle parked on a brick street.', 22514),
#   ('Motorcycle parked along brick paved street with shops.', 818833)],
#  31984: [('A model standing next to a scooter in the middle of a room of people',
#    10176),
#   ('A model posing next to a motorbike at a motorcycle show.', 13155),
#   ('A young woman standing next to a dirt bike at an automobile event.',
#    13317),
#   ('A girl that is standing next to a motorcycle.', 16422),
#   ('a women that is standing next to a motorcycle', 819852)],
#  322791: [('An airplane is doing tricks and emitting smoke.', 10581),
#   ('An aerial stunt plane in a climb with smoke coming out of the back.',
#    11724),
#   ('A biplane performing tricks in the sky with smoke coming from behind. ',
#    13557),
#   ('White and yellow propeller stunt plane trailing smoke while climbing steeply.',
#    14358),
#   ('a plane in the air with a trail of smoke', 16221)],
#  295768: [('Computer monitor and accesories sitting on a desk.', 10625),
#   ('An Apple computer on a table next to an iPhone and an iPad.', 12014),
#   ('Mac computer, tablet, and iphone sitting on a computer desk.', 15491),
#   ('A Mac computer monitor on a desk which is turned off, and an ipad underneath.',
#    19055),
#   ('A white apple computer and keyboard on desk.', 20885)],
#  229067: [('A group of people skiing down a snow covered slope.', 10667),
#   ('Six people in snow field with ski equipment.', 10823),
#   ('Six people, adults and children, wearing skis and helmets standing or skiing on snow.',
#    14090),
#   ('A group of children and adults are skiing in the snow.', 14564),
#   ('A group of people ski down the mountain slope.', 15242)],
#  156324: [('A woman takes a selfie in front of a bathroom mirror.', 10668),
#   ('Woman taking picture of self in bathroom mirror.', 10824),
#   ('A women is taking a picture of herself and her bathroom in the bathroom mirror.',
#    14091),
#   ('A woman is taking a picture of herself in a bathroom mirror.', 14565),
#   ('A woman stands in front of the mirror to take a picture.', 15243)],
#  508605: [('Boy rides skateboard and does trick over stairs.', 10673),
#   ('Man in air on skateboard at night by light of street lamps.', 13055),
#   ('Skateboarder does airborne trick in front of concrete steps.', 14312),
#   ('A skateboarder jumping over the set of steps. ', 17246),
#   ('A person is doing a skateboarding trick on the stairs of a public plaza.',
#    17696)],
#  268224: [('Three young people in a kitchen pointing to a pizza.', 10682),
#   ('Two girls and a boy point to an unbaked pizza.', 20033),
#   ('Three people are posing next to a raw pizza.', 20513),
#   ('A group of friends posing for a picture together next to a pizza.', 22094),
#   ('Three people in a kitchen hug and point at pizza', 818796)],
#  206260: [('Assorted flavored donuts being grabbed by multiple hands.', 10725),
#   ('A group of people with a bunch of doughnuts. ', 12639),
#   ('Individuals holding pastries or donuts of some kind', 15558),
#   ('Several people holding pastries in front of the camera.', 17085),
#   ('A group of people are putting their sweet treats all towards each other.  ',
#    820872)],
#  489528: [('An outside doorway to a restroom showing a destroyed wall and damaged floor.',
#    10730),
#   ('A doorway  looking into a demolished bathroom', 13805),
#   ('A doorway leading into a delapitated wall in a room.', 15995),
#   ('A bathroom with walls that are falling down and a toilet.', 23663),
#   ('A broken door frame showing a a bathroom with a cement floor and a broken back wall',
#    27212)],
#  450308: [('A man stands with his bike in ankle deep water in a flooded city.',
#    10947),
#   ('A man on a bike in a street that is flooded.', 13506),
#   ('A man on a bicycle stands in flooding waters.', 14427),
#   ('A man in shorts sits on his bike, surrounded by flood water up to his calf. ',
#    14706),
#   ('A boy sits on a bicycle in a flooded street.', 16215)],
#  446409: [('A tabby cat laying on a cat scratcher in front of a bicycle wheel. ',
#    11053),
#   ('A cat is falling asleep on top of a scratching pad.', 13834),
#   ('a cat laying down next to a bike tire', 15817),
#   ('A cat is resting underneath a bicycle wheel.', 17995),
#   ('A cat is laying on a small piece of rough fabric', 19747)],
#  420958: [('This a view from an airplane of the landscape below.', 11083),
#   ('A view from a window on board an airplane flying in the sky.', 11605),
#   ('An overhead view of a landscape from a plane.', 14428),
#   ('The right wing of an airplane as it flies over a mountain range.', 16759),
#   ('A plane taking in the view of a mountainside.', 18232)],
#  523400: [('A bathroom with double sinks, mirrors, toilet and towel racks.',
#    11127),
#   ('A fancy bathroom with his and her mirrors and sinks next to a toilette.',
#    11574),
#   ('A bathroom with a double sink and mirrors.', 12597),
#   ('A fancy bathroom with double mirrors and sinks.', 17004),
#   ('Two bathroom sinks mounted beneath two matching mirrors.', 18927)],
#  40986: [('Raw cookies in a pan on the counter and baked cookies in a pan on the stove.',
#    11208),
#   ('Assorted items on a counter top in a kitchenette.', 12762),
#   ('A man points at the wall in his kitchen.', 15384),
#   ('Two pans with cookies in them sitting on a counter with liquor bottles, a coffee maker and knives.',
#    827796),
#   ('A countertop in a kitchen with fresh cookies.', 827895)],
#  8045: [('Tub and shower on platform in modern tiled bathroom.', 11673),
#   ('A bathroom with a shower combination tub and sink.', 12111),
#   ('A  tiled bathroom with a sink, shower, and tub.', 12972),
#   ('A modernized full bathroom with several small LEDs.', 20472),
#   ('A bathroom with a sink and a tub and a minimal, modern style design.',
#    820904)],
#  529691: [('A row of park benches on the side of a green grassy hill. ',
#    11842),
#   ('A train traveling on a track through a nature park.', 16600),
#   ('A picturesque park with benches and big trees.', 16675),
#   ('There is a train traveling through a wooded area in the country.', 16873),
#   ('Several park benches lined up under a row of trees.', 19378)],
#  482597: [('A man in an ATV is moving the cows along.', 11931),
#   ('A man is riding a tractor following some cows.', 12426),
#   ('A man herds cows down a road. ', 14979),
#   ('A person driving a 4 wheeler after a herd of cows.', 20919),
#   ('A man wrangling some cows with a four wheeler.', 827635)],
#  51191: [('The view of a large bathroom with a walk in closet.', 11990),
#   ('A bathroom with a walk-in closet and a jacuzzi tub.', 12938),
#   ('A white and beige tiled bathroom and adjoining walk-in closet.', 12941),
#   ('White tiled bathroom with a vanity tub and white flowers.', 20792),
#   ('Long shot of a bathroom includes closet and tub.', 20840)],
#  249371: [('Many sheep grazing in a large, green pasture.', 12217),
#   ('Many sheep graze in a grassy pasture in a valley. ', 12583),
#   (' A flock of sheep spread out in  a grassy pasture.', 14461),
#   ('A large herd of sheep grazing in a pasture,', 16429),
#   ('A large group of sheep are grazing in a field.', 18028)],
#  408364: [("A young man standing next to a race car with the red sox logo on it's hood.",
#    12261),
#   ('A young boy standing in front of a sponsored car.', 21168),
#   ('A man standing near a red sox nascar', 23874),
#   ('A young boy  standing by a Red Sox car wearing Red Sox shirt and visor',
#    24546),
#   ('A young man standing next to a racecar on a display lot.', 28761)],
#  267862: [('A guy sitting on his motorcycle while a woman stands beside him',
#    12312),
#   ('A gang of bikers sitting on top of motorcycles on a sidewalk.', 14439),
#   ('Three motorcyclists and their bikes stand on the pavement.', 14880),
#   ('Several people around some motorcycles on the side of a road.', 15411),
#   ('a man and woman leaning against a motorcycle', 15561)],
#  536321: [('An adorable caleco cat sitting underneath a bicycle.', 12500),
#   ('A cat on a red sheet is right under a bicycle wheel.', 18017),
#   ('A multi-colored cat peers from a blanket between the wheels of a bicycle.',
#    19433),
#   ('A cat sits behind a bicycle tire and peddles.', 21602),
#   ('A cat sitting under a bicycle with a red blanket in the background.',
#    22622)],
#  148272: [('An adorable cat attempts to hide in a purse to steal the persons identity.',
#    12501),
#   ("A little kitten is stuffed into a woman's purse.", 18018),
#   ('A captioned image of a small cat hiding in a purse.', 19434),
#   ('A cat sits in the bottom of a purse with text at the bottom.', 21603),
#   ('A cat laying in a purse with a funny saying.', 22623)],
#  36450: [('A very big teddy bear is next to a woman.', 12570),
#   ('A smiling woman at work with a life size teddy bear', 16638),
#   ('An associate holding a big teddy bear at an office.', 16752),
#   ('A woman in an office with a large teddy bear.', 20226),
#   ('A giant teddy bear sitting on an office chair.', 22947)],
#  138599: [('A BMW motor cycle parked next to shrub..', 12627),
#   ('A motorcycle sitting on display on a driveway.', 16836),
#   ('Parked motorcycle sitting in a driveway on a sunny day. ', 18138),
#   ('A silver Sport Tourer BMW motorcycle on a sidewalk.', 18267),
#   ('A silver BMW motorcycle being posed for a picture.', 827309)],
#  501055: [('A photograph taken from an airplane window while in flight.',
#    12746),
#   ('A photo of a landscape from an airplane.', 15827),
#   ('i see part of an airplane flying in the sky.', 17903),
#   ('An aerial view of the ground from an airplane.', 19244),
#   ('Mountains and terrain seen from above by plane', 22910)],
#  363272: [('A man sitting on a stone block talking on a cell phone.', 13138),
#   ('A man sitting on a concrete pedestal talking on the phone.', 17866),
#   ('A man sitting on a concrete post, talking on a cell phone.', 19354),
#   ('A man sitting on a post talking on a cell phone.', 21028),
#   ('A man sitting on a pillar talking on the phone', 36871)],
#  231846: [('A yellow stripped cat sitting in a bathroom sink.', 13214),
#   ('a cat sitting in a bathroom sink looking at the floor.', 15980),
#   ('closeup of a cat in a bathroom sink', 16418),
#   ('A brown cat sitting in a bathroom sink.', 24365),
#   ('An orange tabby cat lying in a bathroom sink.', 25412)],
#  260409: [('A person in a helmet standing by their motorcycle.', 13271),
#   ('A motorcyclist stands next to a motorcycle at a lookout over a beach.',
#    13745),
#   ('A person with his motorcycle by the ocean.', 21503),
#   ('A person posing next to their motorcycle by the shore.', 24152),
#   ('A motorcyclist in his helmet parked along side a road near the ocean',
#    27224)],
#  220704: [('A cafeteria type kitchen that is not in use.', 13304),
#   ('A commercial kitchen with pots several pots on the stove.', 15143),
#   ('An industrial kitchen with white walls and stainless steel counters.',
#    15161),
#   ('A clean steel industrial kitchen with minimal lighting. ', 19391),
#   ('a very clean kitchen with pots and pans', 821703)],
#  158466: [('A young man jumping up into the air to catch a Frisbee.', 13423),
#   ('someone jumping up to get a frisbee out of a tree', 14305),
#   ('A male getting an object out of a tree.', 16630),
#   ('A man jumping in the air and catching a frisbee.', 16819),
#   ('A man catching a frisbee in the front yard.', 20692)],
#  100138: [('A black motorcycle parked in front of trees.', 13497),
#   ('A black motorcycle in front of some shrubs. ', 14949),
#   ('A motorcycle with no rider is parked by the grass.', 18483),
#   ('The black motorcycle is parked on the asphalt. ', 20148),
#   ('A black motorcycle sitting on the pavement in front of a bush. ', 22116)],
#  349344: [('A yellow dune buggy on display amongst other automobiles.', 13737),
#   ('Hot Wheels prop car in a studio exhibit.', 22341),
#   ('A car show features a yellow hot wheels car.', 25581),
#   ('People at a auto show viewing very fancy cars.', 26337),
#   ('A yellow sporty jeep is on an indoor display.', 819624)],
#  317639: [('A woman is taking a picture of herself in a bathroom mirror.',
#    14119),
#   ('A double sinked bathroom has circular twig wreaths hanging above.', 17548),
#   ('The two wreaths were each hung above a sink.', 20914),
#   ('A woman taking a selfie in a bathroom with a digital camera.', 21361),
#   ('Two wreaths above two sinks in a bathroom', 822406)],
#  556837: [('A toilet in a stall with remote control buttons.', 14209),
#   ('An automatic toilet bowl that can do many functions.', 15748),
#   ('A toilet  with some kind of remote control.', 17320),
#   ('A toilet with buttons or a remote control.', 17374),
#   ('A toilet is equipped with some buttons on a panel at the side.', 18730)],
#  282346: [('A skateboarder is riding his skateboard at night.', 14343),
#   ('A young man riding a skateboard on a street.', 19281),
#   ('A skateboarder wearing a plaid shirt and jeans.', 20019),
#   ('A skate boarder at night prepairing to skate away.', 20979),
#   ('A man who is riding on a skateboard.', 818812)],
#  477016: [('A young child stands in the kitchen with an adult.', 14618),
#   ('A girl observes a life size toy kitchen.', 15155),
#   ('A child standing in front of a toy dishwasher.', 17852),
#   ('A child standing in front of a fake appliance. ', 22157),
#   ('A child and adult are in a play kitchen.', 820799)],
#  172710: [('A woman kisses a man as they sit on a motorcycle.', 14850),
# ...
#   ('THERE IS A MNA RIDING A MOTORCYCLE DOWN THE STREET', 116720),
#   ('a close up of a person riding a motorcycle on a long empty road', 116744),
#   ('A photo taken from the back of a motorcycle cruising down the road.',
#    121070),
#   ('A motorcyclist surveys the sunlit road into the horizon.', 125768)],
#  204757: [("A close up of a person's hand with a scissors cutting something wet.",
#    116603),
#   ('A hand opening a clam with a pair of scissors.', 120941),
#   ('A pair of scissors being used to clean a shrimp', 130145),
#   ('an image of a person splitting snails shell in half', 139076),
#   ('A close-up of someone shelling a shrimp with scissors.', 141746)],
#  469719: [('A skier in the midst of a jump', 116699),
#   ('The person is skiing down the hill fast.', 130586),
#   ('A skier takes off down a snowy hill.', 140201),
#   ('A man riding skis down the side of a snow covered ski slope.', 148430),
#   ('A man leans forward on skis while jumping on a mountain.', 155930)],
#  275270: [('A very clean sink that is in the bathroom.', 116874),
#   ('A bathroom sink with soap lotion and hand towel', 119763),
#   ('A bathroom scene with focus on the bathroom sink.', 122358),
#   ('A bathroom counter with toiletries and natural decor. ', 123597),
#   ('a light brown bathroom with a white sink and mirror', 124566)],
#  338044: [('A parked motorcycle on display next to the skull of a demon.',
#    117013),
#   ('A customized motorcycle on display at a show.', 132418),
#   ('A red, metallic motorcycle on display behind chain barrier.', 175747),
#   ('An orange motorcycle sits on display at a bike show.', 182089),
#   ('An orange chopper motorcycle is on display. ', 183793)],
#  222494: [('A traffic light with a smile green light above a red sign.',
#    117052),
#   ('A traffic light is displaying a green smiley face.', 142996),
#   ('Picture of a traffic light with a green smiley light showing.', 164662),
#   ('A smiley face made out of black tape on a green traffic signal.', 174355),
#   ('Tape on a green like makes it look like it has a happy face. ', 822194)],
#  368541: [('A picture of some people about to board a plane.', 117279),
#   ('an air plane on an air port run way', 121848),
#   ('A LINE OF PEOPLE ENTERING AN  AIRPLANE ON THE TARMAC', 131040),
#   ('A crowd of people standing on top of an airport.', 135045),
#   ('A line of people waiting to board a jumbo jet.', 135879)],
#  237568: [('Person on a motorcycle coming up to a stop sign on the street.',
#    117446),
#   ('A motorcycle drives down a street near a couple of cars.', 120419),
#   ('a person is riding a motorcycle and a few parked cars', 123206),
#   ('a person riding a bike on the street in traffic.', 127922),
#   ('A street scene with a man on a motorcycle next to a parking lot.',
#    130700)],
#  62443: [('A brick building with an open window next to a few colorful bushes.',
#    117488),
#   ("The stone building has an opened window on it's side.", 117914),
#   ('A building with wide open windows and red ivy', 118055),
#   ('A view form under a tree of a window', 121913),
#   ('There is a small window in a stone building', 140402)],
#  519479: [('A man in  library looking at his laptop.', 117500),
#   ('This painting shows a perplexed fellow staring at a laptop computer.',
#    118262),
#   ("An artist's rendering of an artist sitting before a laptop computer.",
#    118871),
#   ('The painting is of a man studying on his computer.', 119444),
#   ('A painting of a man sitting at a computer in his library.', 120662)],
#  306404: [('An man taking a picture of a sink through a mirror.', 117568),
#   ('A bathroom sink with a mirror and modern towel holder.', 118579),
#   ('A bathroom with a sink, counter top, and mirror is shown.', 119545),
#   ('a white bathroom with a black counter a mirror and a sink', 123904),
#   ('A man in a black jacket taking a picture of a sink area.', 123943)],
#  257448: [('A cop car parked in front of a white fire hydrant.', 117605),
#   ('A police car parked next to an old fire hydrant.', 124862),
#   ('POLICE CAR STOPPED IN FRONT OF A FIRE HYDRANT', 132497),
#   ('A Berkeley Police car parked in front of a fire hydrant', 133262),
#   ('A police car sitting in front of a fire hydrant.', 136562)],
#  164: [('A small kitchen with low a ceiling ', 117663),
#   ('A small kichen area with a sunlight and and angled ceiling.', 145464),
#   ('an image of a kitchen loft style setting', 173583),
#   ('a small kitchen with a lot of filled up shelves ', 205026),
#   ('A kitchen with a slanted ceiling and skylight.', 213867)],
#  267861: [('A red motorcycle with a back seat parked on the side of a road.',
#    117686),
#   ('A tricycle is shown on the side of the road.', 153644),
#   ('There is a nice tricycle motrocycle parked on a sidewalk', 156278),
#   ('A red motorcycle with three wheels and two seats.', 172163),
#   ('a close up of a three wheeled motor cycle', 180680)],
#  469638: [('A bathroom that is very clean and white.', 117856),
#   ('A white bathroom looking at the cabinet sink', 120367),
#   ('a white bathroom with a black and white shower curtain', 123013),
#   ('A bathroom sink under a window.next to a shower.', 133669),
#   ('The small bathroom is very clean and empty.', 137656)],
#  246265: [('Many motorcycles are parked around a crowd of people.', 117887),
#   ('A bunch of motorcycles parked outside a factory building', 118040),
#   ('A group of bikers sitting in front of a mechanic shop.', 120086),
#   ('A garage has many riders and motorcycles outside.', 140156),
#   ('A group of motorcycles are parked outside of the garage.', 157901)],
#  10114: [('A picture of a very nice kitchen that is white.', 117909),
#   ('A small residential kitchen with white cabinets and appliances.', 120384),
#   ('A kitchen filled with a white stove top oven.', 133785),
#   ('A kitchen scene complete with a fridge and an oven.', 134022),
#   ('A dated kitchen reveals a wall hung faucet under a closed off window.',
#    139719)],
#  371683: [('A bunch of bananas hanging from a green tree.', 117993),
#   ('A bunch of bananas and leaves are pictured up close.', 156894),
#   ('A large bunch of bananas hanging from a tree.', 164001),
#   ('A banana tree with a bunch of bananas hanging from it', 173739),
#   ('an image of a plantation of bananas on vine', 175401)],
#  392650: [('A large Delta passenger jet flying through a blue sky.', 118066),
#   ('An airplane soaring into a cloudless blue sky.', 182779),
#   ('Blue sky with delta jumbo jet taking off', 185458),
#   ('A commercial airplane is ascending in the sky.', 188575),
#   ('A delta flight lifting taking off into the sky.', 822188)],
#  579602: [('Three kites in the air with many umbrellas on a beach', 118158),
#   ('an image of a kite flying high in the air', 126324),
#   ('Three colorful kites fly high above a beach with a radio controlled model plane.',
#    129588),
#   ('A crowded beach with giant kites flying over head.', 148833),
#   ('Colorful kites flying above a beach scene of sand and umbrellas.',
#    157512)],
#  23623: [('His and her bathroom sinks underneath a large mirror.', 118184),
#   ('A bathroom vanity with two sinks and a large mirror over it.', 148118),
#   ('Two sinks are shown on a bathroom counter.', 153413),
#   ('a bathroom with two sinks at the counter with a large mirror on top',
#    168977),
#   ('A BATHROOM WITH A SINK AND A MIRROR ', 174128)],
#  180787: [('A picture of some people that are cooking some food.', 118211),
#   ('some people wearing black and cooking food in a big kitchen', 123437),
#   ('A kitchen scene with several people preparing food.', 134882),
#   ('The kitchen of a large restaurant showing a carving station', 144221),
#   ('A couple of chefs preparing food in a kitchen.', 148994)],
#  467475: [('A formation of birds in a sky at sunset.', 118247),
#   ('A airplane followed by birds flying in "v-formation."', 126059),
#   ('AIRPLANE IN THE SKY WITH A FOLLOWING OF GEESE BEHIND', 126206),
#   ('A flock of birds below an airplane in the sunset', 128546),
#   ('A plane flying in the sky, as birds fly behind it.', 129386)],
#  95772: [('A pile of rusted metal junk laying in the weeds.', 118352),
#   ('A rusty apparatus is laying in a green thicket.', 125264),
#   ('old rusted metal on the floor with many plants and trees', 128438),
#   ('A pile of scrap metal sitting on the floor of a forest.', 131300),
#   ('The rusty remains of a metal device in green weeds', 131672)],
#  453020: [('A public restroom with several urinals and stalls.', 118379),
#   ('a bathroom with multiple toilet stalls and urinals ', 120716),
#   ('A clean public bathroom with black and white tile.', 130760),
#   ('A restroom filled with urinals and toilet stalls.', 131738),
#   ('A public bathroom with four toilet stalls and four urinals on the wall.',
#    132191)],
#  255482: [('A blue turboprop airplane races across the blue sky.', 118390),
#   ('an air plane flying thru the air with a sky background', 128413),
#   ('View of a plane flying through a very blue sky', 130216),
#   ('A large airplane with four propellers flying through a blue sky', 131413),
#   ('A blue airplane in a blue, cloudless sky', 132409)],
#  188651: [('The picture of a cat under a car.', 118487),
#   ('A white and broncat is sitting under a car ', 120902),
#   ('A cat lays on the ground underneath a vehicle.', 122714),
#   ('a cat chillin under a car, asking to get run over', 124652),
#   ('A white cat is sitting under a car.', 134267)],
#  370090: [('A blue toilet bowl in a bathroom that says rabies', 118612),
#   ('This is a blue toilet that has white graffiti on it', 122221),
#   ('A blue toilet with the word rabies written on the underside of the toilet seat.',
#    123859),
#   ('an image of a blue toilet with the word babies', 126217),
#   ('Blue toilet in a small restroom with words written on it. ', 134617)],
#  327514: [('A man standing in a kitchen ironing his clothes while cooking food.',
#    118615),
#   ('A person in the kitchen ironing and checking the contents of a pot.',
#    133366),
#   ('Man ironing while opening a pot on top of a stove. ', 134590),
#   ('A person that is ironing some clothes and getting some food.', 146965),
#   ('A young man checks on his cooking while he irons.', 149863)],
#  428234: [('A plant is growing on the window sill in the bathroom.', 118664),
#   ('a bathroom with a toilet a window and a shelf', 121760),
#   ('A bathroom with the focus on the toilet.', 122540),
#   ('A white bathroom area with a plant and yellow bottle.', 123911),
#   ('A bathroom toilet, scrub brush holder and a spider plant on the windowsill',
#    125447)],
#  213932: [('A picture of a motorcycle on the street.', 119092),
#   ('A motorcycle sits on a street near shops.', 122845),
#   ('A black motorcycle parked on a city street.', 125986),
#   ('A black motorcycle parked on a street by a store.', 130675),
#   ('A motorcycle parked on the side of the road.', 131713)],
#  462026: [('Several beautiful vintage racing motorcycles on public display.',
#    119205),
#   ('there are many different dirt bikes on display', 120804),
#   ('Two small bikes in front of signs describing them.', 123957),
#   ('a motored bike display for a minarelli bike', 125106),
#   ('Several dirt bikes are standing in a row.', 125610)],
#  401783: [('A view of the mountains is shown from an airplane window.',
#    119277),
#   ('You can see a long way in the plane.', 120381),
#   ('WING OF AN AIRPLANE SHOWN FLYING OVER THE MOUNTAINS', 125892),
#   ('The view from an airplane window over mountains', 129615),
#   ('A picture of a plane that is in the air around the mountains.', 130029)],
#  168512: [('A turkey or chicken cooks inside a kitchen oven.', 119360),
#   ('A lit oven displays a turkey and a pan of vegetables roasting side by side.',
#    126386),
#   ('A turkey and other foods are cooking in an oven.', 132542),
#   ('A turkey and vegetables cooking in an oven with a glass window on the door.',
#    138221),
#   ('Stainless steel oven with pan of vegetables and a turkey in the oven.',
#    140450)],
#  431236: [('A kitchen with a washer and a stove top oven.', 119568),
#   ('A room is shown with a washer and oven.', 153789),
#   ('A kitchen with a white stove and washing machine', 166515),
#   ('An oven, and clothes washer are in a small kitchen.', 178935),
#   ('a kitchen with a stove a dih washer and a mcirowave', 197400)],
#  172911: [('A car seat covered in a piece of cake and frosting.', 119581),
#   ('Junk in green and other colors sit on a car seat.', 143350),
#   ('A bunch of garbage is on a car seat.', 152728),
#   ('Broken glass is shown in the seat of a car.', 153586),
#   ('A phone lies amid shattered glass on a car seat.', 166207)],
#  484432: [('A bunt cake sitting on a glaze cake plate with glazed being drizzled over it.',
#    119667),
#   ('A large round cake rests on a glass plate.', 161205),
#   ('Someone spooning a glaze over a bundt cake.', 169275),
#   ('A person is spooning melted butter over a bundt cake. ', 174063),
#   ('A person spooning a liquid over the top of a bunt cake that is one a glass serving plate.',
#    174258)],
#  414156: [('A kitchen with wooden counter tops and a stove top oven.', 119711),
#   ('A small and clean home kitchen with wooden counters', 153194),
#   ('Here is a nice and homey little kitchen arrangement', 163943),
#   ('an image of kitchen setting with an island kitchen', 175226),
#   ('a kitchen with plates a stove a sink and counter tops', 177083)],
#  320703: [('A narrow kitchen with a white stove top oven.', 119802),
#   ('A long galley kitchen with cabinets on both sides', 129678),
#   ('a long narrow kitchen with cups in the sink', 144303),
#   ('A white and light gray kitchen with stove, sink, and refrigerator. ',
#    161721),
#   ('an image of a kitchen setting with formica counter', 175386)],
#  555686: [('A woman posing and riding on a red motorcycle', 119972),
#   ('A woman in leather pants posing on a red motorcycle.', 122324),
#   ('A woman outside in front of a building posing on a motorcycle', 126203),
#   ('A picture of a person on a motorcycle.', 129200),
#   ('The woman is sitting on the motorcycle by the plants.', 134024)],
#  253223: [('a building with two towers and an air plane in the background',
#    120079),
#   ('A jet airliner in flight over a religious structure.', 120214),
#   ('A plane flying high over a historically built building.', 123715),
#   ('a view of an old building with a plane flying in the background', 127303),
#   ('The upper portion of an ornate stone church, with an airplane flying overhead',
#    129274)],
#  579468: [('A beautiful woman with a blue fro brushing her teeth with a giant toothbrush.',
#    120140),
#   ('an image of a girl with a blue wig and a tootbrush', 139169),
#   ('A young woman with blue hair uses an oversized toothbrush.', 150368),
#   ('A woman with blue hair and a giant toothbrush', 164309),
#   ('A woman with a blue wig brushes her teeth. ', 184433)],
#  255248: [('A cook sanding between two women inside of a kitchen.', 120205),
#   ('A man in camo pointing at the ceiling', 131686),
#   ('a guy in blue camo in a kitchen teaching girls how to cook', 156028),
#   ('The soldier is talking to an attentive student.', 161680),
#   ('three people in a kitchen area with a table with bowls', 191692)],
#  456328: [('A bathroom photo focusing on the toilet and the window.', 120269),
#   ('A bathroom is shown in a dim lit setting.', 120953),
#   ('A bathroom with a toilet and no toilet paper.', 120959),
#   ('A small bathroom, toilet and sink with a large window.', 126767),
#   ('A bathroom with toilet and a curtained window', 127958)],
#  390241: [('A white train car lays on its side in the dark while a man with a light is nearby.',
#    120328),
#   ('on overturned bus on the side of the road ', 121222),
#   ('A bus is tipped over on its side.', 122635),
#   ('A bus tipped over on the side of the road', 127327),
#   ('A picture of a bus that is turned over.', 130156)],
#  564699: [('A tiled bathroom altered to suit the needs of the handicapped.',
#    120565),
#   ('a handicapped toilet with bars and a sink', 123322),
#   ('This toilet is accessible to a handicapped person.', 130978),
#   ('A toilet with extended help bars and a handle for lifting.', 138502),
#   ('A small bathroom that appears to be handicapped accessory. ', 157951)],
#  ...}

# %%
with open("annotations_trainval/captions_val2017.json") as in_file:
    val_coco = json.load(in_file)
        
val_captions_per_image = dict()

for vc in val_coco['annotations']:
    if vc['image_id'] in val_captions_per_image:
        val_captions_per_image[vc['image_id']].append((vc['caption'], vc['id']))
    else:
        val_captions_per_image[vc['image_id']] = [(vc['caption'], vc['id'])]

# %%
with open("annotations_test/image_info_test2017.json") as in_file:
    test_cap = json.load(in_file)

# %%
test_cap['images'][0]
# Out:
# {'coco_url': 'http://images.cocodataset.org/test2017/000000466319.jpg',
#  'date_captured': '2013-11-14 11:04:33',
#  'file_name': '000000466319.jpg',
#  'height': 480,
#  'id': 466319,
#  'license': 6,
#  'width': 640}

# %%
test_cap['categories'] #object categories
# Out:
# [{'id': 1, 'name': 'person', 'supercategory': 'person'},
#  {'id': 2, 'name': 'bicycle', 'supercategory': 'vehicle'},
#  {'id': 3, 'name': 'car', 'supercategory': 'vehicle'},
#  {'id': 4, 'name': 'motorcycle', 'supercategory': 'vehicle'},
#  {'id': 5, 'name': 'airplane', 'supercategory': 'vehicle'},
#  {'id': 6, 'name': 'bus', 'supercategory': 'vehicle'},
#  {'id': 7, 'name': 'train', 'supercategory': 'vehicle'},
#  {'id': 8, 'name': 'truck', 'supercategory': 'vehicle'},
#  {'id': 9, 'name': 'boat', 'supercategory': 'vehicle'},
#  {'id': 10, 'name': 'traffic light', 'supercategory': 'outdoor'},
#  {'id': 11, 'name': 'fire hydrant', 'supercategory': 'outdoor'},
#  {'id': 13, 'name': 'stop sign', 'supercategory': 'outdoor'},
#  {'id': 14, 'name': 'parking meter', 'supercategory': 'outdoor'},
#  {'id': 15, 'name': 'bench', 'supercategory': 'outdoor'},
#  {'id': 16, 'name': 'bird', 'supercategory': 'animal'},
#  {'id': 17, 'name': 'cat', 'supercategory': 'animal'},
#  {'id': 18, 'name': 'dog', 'supercategory': 'animal'},
#  {'id': 19, 'name': 'horse', 'supercategory': 'animal'},
#  {'id': 20, 'name': 'sheep', 'supercategory': 'animal'},
#  {'id': 21, 'name': 'cow', 'supercategory': 'animal'},
#  {'id': 22, 'name': 'elephant', 'supercategory': 'animal'},
#  {'id': 23, 'name': 'bear', 'supercategory': 'animal'},
#  {'id': 24, 'name': 'zebra', 'supercategory': 'animal'},
#  {'id': 25, 'name': 'giraffe', 'supercategory': 'animal'},
#  {'id': 27, 'name': 'backpack', 'supercategory': 'accessory'},
#  {'id': 28, 'name': 'umbrella', 'supercategory': 'accessory'},
#  {'id': 31, 'name': 'handbag', 'supercategory': 'accessory'},
#  {'id': 32, 'name': 'tie', 'supercategory': 'accessory'},
#  {'id': 33, 'name': 'suitcase', 'supercategory': 'accessory'},
#  {'id': 34, 'name': 'frisbee', 'supercategory': 'sports'},
#  {'id': 35, 'name': 'skis', 'supercategory': 'sports'},
#  {'id': 36, 'name': 'snowboard', 'supercategory': 'sports'},
#  {'id': 37, 'name': 'sports ball', 'supercategory': 'sports'},
#  {'id': 38, 'name': 'kite', 'supercategory': 'sports'},
#  {'id': 39, 'name': 'baseball bat', 'supercategory': 'sports'},
#  {'id': 40, 'name': 'baseball glove', 'supercategory': 'sports'},
#  {'id': 41, 'name': 'skateboard', 'supercategory': 'sports'},
#  {'id': 42, 'name': 'surfboard', 'supercategory': 'sports'},
#  {'id': 43, 'name': 'tennis racket', 'supercategory': 'sports'},
#  {'id': 44, 'name': 'bottle', 'supercategory': 'kitchen'},
#  {'id': 46, 'name': 'wine glass', 'supercategory': 'kitchen'},
#  {'id': 47, 'name': 'cup', 'supercategory': 'kitchen'},
#  {'id': 48, 'name': 'fork', 'supercategory': 'kitchen'},
#  {'id': 49, 'name': 'knife', 'supercategory': 'kitchen'},
#  {'id': 50, 'name': 'spoon', 'supercategory': 'kitchen'},
#  {'id': 51, 'name': 'bowl', 'supercategory': 'kitchen'},
#  {'id': 52, 'name': 'banana', 'supercategory': 'food'},
#  {'id': 53, 'name': 'apple', 'supercategory': 'food'},
#  {'id': 54, 'name': 'sandwich', 'supercategory': 'food'},
#  {'id': 55, 'name': 'orange', 'supercategory': 'food'},
#  {'id': 56, 'name': 'broccoli', 'supercategory': 'food'},
#  {'id': 57, 'name': 'carrot', 'supercategory': 'food'},
#  {'id': 58, 'name': 'hot dog', 'supercategory': 'food'},
#  {'id': 59, 'name': 'pizza', 'supercategory': 'food'},
#  {'id': 60, 'name': 'donut', 'supercategory': 'food'},
#  {'id': 61, 'name': 'cake', 'supercategory': 'food'},
#  {'id': 62, 'name': 'chair', 'supercategory': 'furniture'},
#  {'id': 63, 'name': 'couch', 'supercategory': 'furniture'},
#  {'id': 64, 'name': 'potted plant', 'supercategory': 'furniture'},
#  {'id': 65, 'name': 'bed', 'supercategory': 'furniture'},
#  {'id': 67, 'name': 'dining table', 'supercategory': 'furniture'},
#  {'id': 70, 'name': 'toilet', 'supercategory': 'furniture'},
#  {'id': 72, 'name': 'tv', 'supercategory': 'electronic'},
#  {'id': 73, 'name': 'laptop', 'supercategory': 'electronic'},
#  {'id': 74, 'name': 'mouse', 'supercategory': 'electronic'},
#  {'id': 75, 'name': 'remote', 'supercategory': 'electronic'},
#  {'id': 76, 'name': 'keyboard', 'supercategory': 'electronic'},
#  {'id': 77, 'name': 'cell phone', 'supercategory': 'electronic'},
#  {'id': 78, 'name': 'microwave', 'supercategory': 'appliance'},
#  {'id': 79, 'name': 'oven', 'supercategory': 'appliance'},
#  {'id': 80, 'name': 'toaster', 'supercategory': 'appliance'},
#  {'id': 81, 'name': 'sink', 'supercategory': 'appliance'},
#  {'id': 82, 'name': 'refrigerator', 'supercategory': 'appliance'},
#  {'id': 84, 'name': 'book', 'supercategory': 'indoor'},
#  {'id': 85, 'name': 'clock', 'supercategory': 'indoor'},
#  {'id': 86, 'name': 'vase', 'supercategory': 'indoor'},
#  {'id': 87, 'name': 'scissors', 'supercategory': 'indoor'},
#  {'id': 88, 'name': 'teddy bear', 'supercategory': 'indoor'},
#  {'id': 89, 'name': 'hair drier', 'supercategory': 'indoor'},
#  {'id': 90, 'name': 'toothbrush', 'supercategory': 'indoor'}]

# %%
with open("annotations_test/image_info_test2014.json") as in_file:
    test_cap2014 = json.load(in_file)
    
print(len(test_cap2014['categories']))

for c in range(len(test_cap2014['categories'])):
    print(test_cap['categories'][c]['name'], test_cap2014['categories'][c]['name'], )
# Out:
# 80
# person person
# bicycle bicycle
# car car
# motorcycle motorcycle
# airplane airplane
# bus bus
# train train
# truck truck
# boat boat
# traffic light traffic light
# fire hydrant fire hydrant
# stop sign stop sign
# parking meter parking meter
# bench bench
# bird bird
# cat cat
# dog dog
# horse horse
# sheep sheep
# cow cow
# elephant elephant
# bear bear
# zebra zebra
# giraffe giraffe
# backpack backpack
# umbrella umbrella
# handbag handbag
# tie tie
# suitcase suitcase
# frisbee frisbee
# skis skis
# snowboard snowboard
# sports ball sports ball
# kite kite
# baseball bat baseball bat
# baseball glove baseball glove
# skateboard skateboard
# surfboard surfboard
# tennis racket tennis racket
# bottle bottle
# wine glass wine glass
# cup cup
# fork fork
# knife knife
# spoon spoon
# bowl bowl
# banana banana
# apple apple
# sandwich sandwich
# orange orange
# broccoli broccoli
# carrot carrot
# hot dog hot dog
# pizza pizza
# donut donut
# cake cake
# chair chair
# couch couch
# potted plant potted plant
# bed bed
# dining table dining table
# toilet toilet
# tv tv
# laptop laptop
# mouse mouse
# remote remote
# keyboard keyboard
# cell phone cell phone
# microwave microwave
# oven oven
# toaster toaster
# sink sink
# refrigerator refrigerator
# book book
# clock clock
# vase vase
# scissors scissors
# teddy bear teddy bear
# hair drier hair drier
# toothbrush toothbrush

# %%
obj_cat = []
super_cat = []
obj_sup_cat = dict()
mult_obj_cat = []
mult_sup_cat = dict()

for c in test_cap['categories']:
    if len(c['name'].split()) == 1:
        obj_cat.append(c['name']) 
        super_cat.append(c['supercategory'])
        
        if c['supercategory'] in obj_sup_cat:
            obj_sup_cat[c['supercategory']].append(c['name'])
        else:
            obj_sup_cat[c['supercategory']] = [c['name']]
            
    else:
        mult_obj_cat.append(c['name'])
        
        if c['supercategory'] in mult_sup_cat:
            mult_sup_cat[c['supercategory']].append(c['name'])
        else:
            mult_sup_cat[c['supercategory']] = [c['name']]

# %%
# obj_cat = sorted(obj_cat)
# #print(len(obj_cat)
# print(obj_cat)
# print()
# print(len(mult_obj_cat), mult_obj_cat)

all_cat = []
all_cat.extend(obj_cat)
all_cat.extend(mult_obj_cat)
all_cat = sorted(all_cat)

# %%
len(all_cat)
# Out:
# 80

# %%
#different compared to the file I received from Ravi 
#categories such as: dining table vs. table, sports ball vs. ball

print(len(obj_targ), obj_targ)
# Out:
# 73 ['airplane', 'apple', 'backpack', 'ball', 'banana', 'bat', 'bear', 'bed', 'bench', 'bicycle', 'bird', 'boat', 'book', 'bottle', 'bowl', 'broccoli', 'bus', 'cake', 'car', 'carrot', 'cat', 'chair', 'clock', 'couch', 'cow', 'cup', 'dog', 'donut', 'drier', 'elephant', 'fork', 'frisbee', 'giraffe', 'glass', 'glove', 'handbag', 'horse', 'hydrant', 'keyboard', 'kite', 'knife', 'laptop', 'microwave', 'motorcycle', 'mouse', 'orange', 'oven', 'phone', 'pizza', 'racket', 'refrigerator', 'remote', 'sandwich', 'scissors', 'sheep', 'sink', 'skateboard', 'skis', 'snowboard', 'spoon', 'suitcase', 'surfboard', 'table', 'tie', 'toaster', 'toilet', 'toothbrush', 'train', 'truck', 'tv', 'umbrella', 'vase', 'zebra']

# %%
#mismatches

# R ball
# R bat
# R drier
# R glass
# R glove
# R hydrant
# R phone
# R racket
# R table


# E 'baseball bat' bat
# E 'baseball glove' glove
# E 'cell phone' phone
# E 'dining table' table
# E 'fire hydrant' hydrant
# E 'hair drier' drier
# E 'hot dog' dog
# E 'parking meter' NOT IN OLD LIST
# E 'person' NOT IN OLD LIST  +person
# E 'potted plant' NOT IN OLD LIST +plant
# E 'sports ball' ball
# E 'stop sign' NOT IN OLD LIST +sign
# E 'teddy bear' NOT IN OLD LIST
# E 'tennis racket'racket
# E 'traffic light' NOT IN OLD LIST +light
# E 'wine glass' glass

# %%
# obj_targ.extend(['person', 'plant', 'sign', 'light'])
# obj_targ = sorted(obj_targ)

with open('new_obj_categories.txt', 'w') as f:
    
    for c in range(len(obj_targ)):
        f.write(obj_targ[c])    
        if c < (len(obj_targ) - 1):
            f.write('\n')

# %%
with open('new_obj_categories.txt', 'r') as f:
    foil2_categories = [l.split()[0] for l in f.readlines()]

# %%
len(foil2_categories)
# Out:
# 73

# %%
#manual addition of single-word categories, obtained from multi-word counterparts

obj_sup_cat['outdoor'].append('light')
obj_sup_cat['outdoor'].append('hydrant')
obj_sup_cat['outdoor'].append('sign')

obj_sup_cat['sports'].append('ball')
obj_sup_cat['sports'].append('bat')
obj_sup_cat['sports'].append('glove')
obj_sup_cat['sports'].append('racket')

obj_sup_cat['kitchen'].append('glass')

obj_sup_cat['furniture'].append('plant')
obj_sup_cat['furniture'].append('table')

obj_sup_cat['electronic'].append('phone')

obj_sup_cat['indoor'].append('drier')

# %%
count = 0

for c in obj_sup_cat:
    count += len(obj_sup_cat[c])
    
count
# Out:
# 77

# %%
target_foil_pairs = []
train_pairs = []
test_pairs = []

for cat in obj_sup_cat:
    if len(obj_sup_cat[cat]) > 1: #there are some supercategories with 1 object category
        perms = list(itertools.permutations(obj_sup_cat[cat], 2))
        target_foil_pairs.extend(perms)
        
        for p in perms:
            if randint(0, 1) == 1:
                train_pairs.append(p)
            else:
                test_pairs.append(p)

print(target_foil_pairs)
# Out:
# [('bicycle', 'car'), ('bicycle', 'motorcycle'), ('bicycle', 'airplane'), ('bicycle', 'bus'), ('bicycle', 'train'), ('bicycle', 'truck'), ('bicycle', 'boat'), ('car', 'bicycle'), ('car', 'motorcycle'), ('car', 'airplane'), ('car', 'bus'), ('car', 'train'), ('car', 'truck'), ('car', 'boat'), ('motorcycle', 'bicycle'), ('motorcycle', 'car'), ('motorcycle', 'airplane'), ('motorcycle', 'bus'), ('motorcycle', 'train'), ('motorcycle', 'truck'), ('motorcycle', 'boat'), ('airplane', 'bicycle'), ('airplane', 'car'), ('airplane', 'motorcycle'), ('airplane', 'bus'), ('airplane', 'train'), ('airplane', 'truck'), ('airplane', 'boat'), ('bus', 'bicycle'), ('bus', 'car'), ('bus', 'motorcycle'), ('bus', 'airplane'), ('bus', 'train'), ('bus', 'truck'), ('bus', 'boat'), ('train', 'bicycle'), ('train', 'car'), ('train', 'motorcycle'), ('train', 'airplane'), ('train', 'bus'), ('train', 'truck'), ('train', 'boat'), ('truck', 'bicycle'), ('truck', 'car'), ('truck', 'motorcycle'), ('truck', 'airplane'), ('truck', 'bus'), ('truck', 'train'), ('truck', 'boat'), ('boat', 'bicycle'), ('boat', 'car'), ('boat', 'motorcycle'), ('boat', 'airplane'), ('boat', 'bus'), ('boat', 'train'), ('boat', 'truck'), ('bench', 'light'), ('bench', 'hydrant'), ('bench', 'sign'), ('light', 'bench'), ('light', 'hydrant'), ('light', 'sign'), ('hydrant', 'bench'), ('hydrant', 'light'), ('hydrant', 'sign'), ('sign', 'bench'), ('sign', 'light'), ('sign', 'hydrant'), ('bird', 'cat'), ('bird', 'dog'), ('bird', 'horse'), ('bird', 'sheep'), ('bird', 'cow'), ('bird', 'elephant'), ('bird', 'bear'), ('bird', 'zebra'), ('bird', 'giraffe'), ('cat', 'bird'), ('cat', 'dog'), ('cat', 'horse'), ('cat', 'sheep'), ('cat', 'cow'), ('cat', 'elephant'), ('cat', 'bear'), ('cat', 'zebra'), ('cat', 'giraffe'), ('dog', 'bird'), ('dog', 'cat'), ('dog', 'horse'), ('dog', 'sheep'), ('dog', 'cow'), ('dog', 'elephant'), ('dog', 'bear'), ('dog', 'zebra'), ('dog', 'giraffe'), ('horse', 'bird'), ('horse', 'cat'), ('horse', 'dog'), ('horse', 'sheep'), ('horse', 'cow'), ('horse', 'elephant'), ('horse', 'bear'), ('horse', 'zebra'), ('horse', 'giraffe'), ('sheep', 'bird'), ('sheep', 'cat'), ('sheep', 'dog'), ('sheep', 'horse'), ('sheep', 'cow'), ('sheep', 'elephant'), ('sheep', 'bear'), ('sheep', 'zebra'), ('sheep', 'giraffe'), ('cow', 'bird'), ('cow', 'cat'), ('cow', 'dog'), ('cow', 'horse'), ('cow', 'sheep'), ('cow', 'elephant'), ('cow', 'bear'), ('cow', 'zebra'), ('cow', 'giraffe'), ('elephant', 'bird'), ('elephant', 'cat'), ('elephant', 'dog'), ('elephant', 'horse'), ('elephant', 'sheep'), ('elephant', 'cow'), ('elephant', 'bear'), ('elephant', 'zebra'), ('elephant', 'giraffe'), ('bear', 'bird'), ('bear', 'cat'), ('bear', 'dog'), ('bear', 'horse'), ('bear', 'sheep'), ('bear', 'cow'), ('bear', 'elephant'), ('bear', 'zebra'), ('bear', 'giraffe'), ('zebra', 'bird'), ('zebra', 'cat'), ('zebra', 'dog'), ('zebra', 'horse'), ('zebra', 'sheep'), ('zebra', 'cow'), ('zebra', 'elephant'), ('zebra', 'bear'), ('zebra', 'giraffe'), ('giraffe', 'bird'), ('giraffe', 'cat'), ('giraffe', 'dog'), ('giraffe', 'horse'), ('giraffe', 'sheep'), ('giraffe', 'cow'), ('giraffe', 'elephant'), ('giraffe', 'bear'), ('giraffe', 'zebra'), ('backpack', 'umbrella'), ('backpack', 'handbag'), ('backpack', 'tie'), ('backpack', 'suitcase'), ('umbrella', 'backpack'), ('umbrella', 'handbag'), ('umbrella', 'tie'), ('umbrella', 'suitcase'), ('handbag', 'backpack'), ('handbag', 'umbrella'), ('handbag', 'tie'), ('handbag', 'suitcase'), ('tie', 'backpack'), ('tie', 'umbrella'), ('tie', 'handbag'), ('tie', 'suitcase'), ('suitcase', 'backpack'), ('suitcase', 'umbrella'), ('suitcase', 'handbag'), ('suitcase', 'tie'), ('frisbee', 'skis'), ('frisbee', 'snowboard'), ('frisbee', 'kite'), ('frisbee', 'skateboard'), ('frisbee', 'surfboard'), ('frisbee', 'ball'), ('frisbee', 'bat'), ('frisbee', 'glove'), ('frisbee', 'racket'), ('skis', 'frisbee'), ('skis', 'snowboard'), ('skis', 'kite'), ('skis', 'skateboard'), ('skis', 'surfboard'), ('skis', 'ball'), ('skis', 'b ...

# %%
len(target_foil_pairs)
# Out:
# 492

# %%
test_pairs
# Out:
# [('bicycle', 'motorcycle'),
#  ('bicycle', 'bus'),
#  ('bicycle', 'boat'),
#  ('car', 'motorcycle'),
#  ('car', 'airplane'),
#  ('car', 'train'),
#  ('car', 'truck'),
#  ('car', 'boat'),
#  ('motorcycle', 'car'),
#  ('motorcycle', 'airplane'),
#  ('motorcycle', 'bus'),
#  ('motorcycle', 'truck'),
#  ('airplane', 'bicycle'),
#  ('airplane', 'car'),
#  ('airplane', 'bus'),
#  ('airplane', 'train'),
#  ('bus', 'car'),
#  ('train', 'car'),
#  ('train', 'motorcycle'),
#  ('train', 'airplane'),
#  ('train', 'bus'),
#  ('train', 'boat'),
#  ('truck', 'bicycle'),
#  ('truck', 'airplane'),
#  ('truck', 'bus'),
#  ('truck', 'train'),
#  ('boat', 'bicycle'),
#  ('boat', 'car'),
#  ('boat', 'motorcycle'),
#  ('boat', 'airplane'),
#  ('bench', 'sign'),
#  ('light', 'bench'),
#  ('light', 'sign'),
#  ('hydrant', 'light'),
#  ('hydrant', 'sign'),
#  ('sign', 'bench'),
#  ('sign', 'light'),
#  ('sign', 'hydrant'),
#  ('bird', 'cow'),
#  ('bird', 'elephant'),
#  ('bird', 'bear'),
#  ('bird', 'zebra'),
#  ('cat', 'bird'),
#  ('cat', 'dog'),
#  ('cat', 'horse'),
#  ('cat', 'cow'),
#  ('cat', 'elephant'),
#  ('cat', 'giraffe'),
#  ('dog', 'sheep'),
#  ('dog', 'elephant'),
#  ('dog', 'bear'),
#  ('dog', 'giraffe'),
#  ('horse', 'bird'),
#  ('horse', 'dog'),
#  ('horse', 'zebra'),
#  ('horse', 'giraffe'),
#  ('sheep', 'elephant'),
#  ('sheep', 'bear'),
#  ('sheep', 'zebra'),
#  ('sheep', 'giraffe'),
#  ('cow', 'dog'),
#  ('cow', 'sheep'),
#  ('cow', 'bear'),
#  ('cow', 'giraffe'),
#  ('elephant', 'cat'),
#  ('elephant', 'dog'),
#  ('bear', 'bird'),
#  ('bear', 'cat'),
#  ('bear', 'horse'),
#  ('bear', 'elephant'),
#  ('bear', 'zebra'),
#  ('zebra', 'bird'),
#  ('zebra', 'dog'),
#  ('zebra', 'horse'),
#  ('zebra', 'sheep'),
#  ('zebra', 'cow'),
#  ('zebra', 'bear'),
#  ('giraffe', 'sheep'),
#  ('giraffe', 'bear'),
#  ('giraffe', 'zebra'),
#  ('backpack', 'handbag'),
#  ('umbrella', 'backpack'),
#  ('umbrella', 'handbag'),
#  ('umbrella', 'tie'),
#  ('umbrella', 'suitcase'),
#  ('handbag', 'tie'),
#  ('tie', 'backpack'),
#  ('tie', 'handbag'),
#  ('suitcase', 'handbag'),
#  ('suitcase', 'tie'),
#  ('frisbee', 'skis'),
#  ('frisbee', 'snowboard'),
#  ('frisbee', 'kite'),
#  ('frisbee', 'skateboard'),
#  ('skis', 'frisbee'),
#  ('skis', 'snowboard'),
#  ('skis', 'kite'),
#  ('skis', 'ball'),
#  ('skis', 'bat'),
#  ('snowboard', 'frisbee'),
#  ('snowboard', 'skis'),
#  ('snowboard', 'surfboard'),
#  ('snowboard', 'ball'),
#  ('snowboard', 'racket'),
#  ('kite', 'frisbee'),
#  ('kite', 'skis'),
#  ('kite', 'skateboard'),
#  ('kite', 'bat'),
#  ('kite', 'glove'),
#  ('kite', 'racket'),
#  ('skateboard', 'kite'),
#  ('skateboard', 'glove'),
#  ('skateboard', 'racket'),
#  ('surfboard', 'frisbee'),
#  ('surfboard', 'skis'),
#  ('surfboard', 'ball'),
#  ('surfboard', 'bat'),
#  ('ball', 'skis'),
#  ('ball', 'kite'),
#  ('ball', 'skateboard'),
#  ('ball', 'surfboard'),
#  ('ball', 'glove'),
#  ('bat', 'kite'),
#  ('glove', 'skateboard'),
#  ('glove', 'surfboard'),
#  ('glove', 'bat'),
#  ('racket', 'skis'),
#  ('racket', 'surfboard'),
#  ('racket', 'bat'),
#  ('bottle', 'cup'),
#  ('bottle', 'knife'),
#  ('bottle', 'spoon'),
#  ('cup', 'bottle'),
#  ('cup', 'bowl'),
#  ('cup', 'glass'),
#  ('fork', 'cup'),
#  ('fork', 'knife'),
#  ('fork', 'bowl'),
#  ('knife', 'bottle'),
#  ('knife', 'cup'),
#  ('knife', 'fork'),
#  ('knife', 'spoon'),
#  ('spoon', 'cup'),
#  ('spoon', 'knife'),
#  ('spoon', 'glass'),
#  ('bowl', 'cup'),
#  ('bowl', 'fork'),
#  ('glass', 'bottle'),
#  ('glass', 'cup'),
#  ('glass', 'fork'),
#  ('glass', 'spoon'),
#  ('banana', 'sandwich'),
#  ('banana', 'broccoli'),
#  ('banana', 'pizza'),
#  ('apple', 'banana'),
#  ('apple', 'sandwich'),
#  ('apple', 'broccoli'),
#  ('apple', 'pizza'),
#  ('apple', 'cake'),
#  ('sandwich', 'banana'),
#  ('sandwich', 'orange'),
#  ('sandwich', 'donut'),
#  ('sandwich', 'cake'),
#  ('orange', 'sandwich'),
#  ('orange', 'cake'),
#  ('broccoli', 'apple'),
#  ('broccoli', 'sandwich'),
#  ('broccoli', 'orange'),
#  ('broccoli', 'carrot'),
#  ('broccoli', 'donut'),
#  ('broccoli', 'cake'),
#  ('carrot', 'orange'),
#  ('carrot', 'pizza'),
#  ('pizza', 'apple'),
#  ('pizza', 'sandwich'),
#  ('pizza', 'broccoli'),
#  ('pizza', 'donut'),
#  ('donut', 'banana'),
#  ('donut', 'apple'),
#  ('donut', 'orange'),
#  ('donut', 'broccoli'),
#  ('cake', 'banana'),
#  ('cake', 'sandwich'),
#  ('cake', 'pizza'),
#  ('chair', 'couch'),
#  ('chair', 'toilet'),
#  ('chair', 'plant'),
#  ('couch', 'chair'),
#  ('couch', 'bed'),
#  ('couch', 'table'),
#  ('bed', 'chair'),
#  ('plant', 'couch'),
#  ('plant', 'toilet'),
#  ('plant', 'table'),
#  ('table', 'chair'),
#  ('table', 'toilet'),
#  ('table', 'plant'),
#  ('tv', 'mouse'),
#  ('tv', 'remote'),
#  ('tv', 'phone'),
#  ('laptop', 'tv'),
#  ('laptop', 'remote'),
#  ('laptop', 'phone'),
#  ('mouse', 'tv'),
#  ('remote', 'tv'),
#  ('keyboard', 'laptop'),
#  ('keyboard', 'mouse'),
#  ('keyboard', 'remote'),
#  ('keyboard', 'phone'),
#  ('phone', 'laptop'),
#  ('phone', 'keyboard'),
#  ('microwave', 'oven'),
#  ('microwave', 'toaster'),
#  ('microwave', 'sink'),
#  ('microwave', 'refrigerator'),
#  ('oven', 'refrigerator'),
#  ('toaster', 'microwave'),
#  ('toaster', 'oven'),
#  ('toaster', 'sink'),
#  ('sink', 'refrigerator'),
#  ('refrigerator', 'microwave'),
#  ('refrigerator', 'oven'),
#  ('refrigerator', 'sink'),
#  ('book', 'clock'),
#  ('book', 'vase'),
#  ('book', 'scissors'),
#  ('book', 'toothbrush'),
#  ('clock', 'vase'),
#  ('clock', 'toothbrush'),
#  ('vase', 'book'),
#  ('vase', 'clock'),
#  ('vase', 'toothbrush'),
#  ('scissors', 'book'),
#  ('scissors', 'vase'),
#  ('scissors', 'toothbrush'),
#  ('toothbrush', 'clock'),
#  ('toothbrush', 'vase'),
#  ('toothbrush', 'drier'),
#  ('drier', 'clock'),
#  ('drier', 'scissors'),
#  ('drier', 'toothbrush')]

# %%
len(test_pairs)
# Out:
# 241

# %%
train_pairs
# Out:
# [('bicycle', 'car'),
#  ('bicycle', 'airplane'),
#  ('bicycle', 'train'),
#  ('bicycle', 'truck'),
#  ('car', 'bicycle'),
#  ('car', 'bus'),
#  ('motorcycle', 'bicycle'),
#  ('motorcycle', 'train'),
#  ('motorcycle', 'boat'),
#  ('airplane', 'motorcycle'),
#  ('airplane', 'truck'),
#  ('airplane', 'boat'),
#  ('bus', 'bicycle'),
#  ('bus', 'motorcycle'),
#  ('bus', 'airplane'),
#  ('bus', 'train'),
#  ('bus', 'truck'),
#  ('bus', 'boat'),
#  ('train', 'bicycle'),
#  ('train', 'truck'),
#  ('truck', 'car'),
#  ('truck', 'motorcycle'),
#  ('truck', 'boat'),
#  ('boat', 'bus'),
#  ('boat', 'train'),
#  ('boat', 'truck'),
#  ('bench', 'light'),
#  ('bench', 'hydrant'),
#  ('light', 'hydrant'),
#  ('hydrant', 'bench'),
#  ('bird', 'cat'),
#  ('bird', 'dog'),
#  ('bird', 'horse'),
#  ('bird', 'sheep'),
#  ('bird', 'giraffe'),
#  ('cat', 'sheep'),
#  ('cat', 'bear'),
#  ('cat', 'zebra'),
#  ('dog', 'bird'),
#  ('dog', 'cat'),
#  ('dog', 'horse'),
#  ('dog', 'cow'),
#  ('dog', 'zebra'),
#  ('horse', 'cat'),
#  ('horse', 'sheep'),
#  ('horse', 'cow'),
#  ('horse', 'elephant'),
#  ('horse', 'bear'),
#  ('sheep', 'bird'),
#  ('sheep', 'cat'),
#  ('sheep', 'dog'),
#  ('sheep', 'horse'),
#  ('sheep', 'cow'),
#  ('cow', 'bird'),
#  ('cow', 'cat'),
#  ('cow', 'horse'),
#  ('cow', 'elephant'),
#  ('cow', 'zebra'),
#  ('elephant', 'bird'),
#  ('elephant', 'horse'),
#  ('elephant', 'sheep'),
#  ('elephant', 'cow'),
#  ('elephant', 'bear'),
#  ('elephant', 'zebra'),
#  ('elephant', 'giraffe'),
#  ('bear', 'dog'),
#  ('bear', 'sheep'),
#  ('bear', 'cow'),
#  ('bear', 'giraffe'),
#  ('zebra', 'cat'),
#  ('zebra', 'elephant'),
#  ('zebra', 'giraffe'),
#  ('giraffe', 'bird'),
#  ('giraffe', 'cat'),
#  ('giraffe', 'dog'),
#  ('giraffe', 'horse'),
#  ('giraffe', 'cow'),
#  ('giraffe', 'elephant'),
#  ('backpack', 'umbrella'),
#  ('backpack', 'tie'),
#  ('backpack', 'suitcase'),
#  ('handbag', 'backpack'),
#  ('handbag', 'umbrella'),
#  ('handbag', 'suitcase'),
#  ('tie', 'umbrella'),
#  ('tie', 'suitcase'),
#  ('suitcase', 'backpack'),
#  ('suitcase', 'umbrella'),
#  ('frisbee', 'surfboard'),
#  ('frisbee', 'ball'),
#  ('frisbee', 'bat'),
#  ('frisbee', 'glove'),
#  ('frisbee', 'racket'),
#  ('skis', 'skateboard'),
#  ('skis', 'surfboard'),
#  ('skis', 'glove'),
#  ('skis', 'racket'),
#  ('snowboard', 'kite'),
#  ('snowboard', 'skateboard'),
#  ('snowboard', 'bat'),
#  ('snowboard', 'glove'),
#  ('kite', 'snowboard'),
#  ('kite', 'surfboard'),
#  ('kite', 'ball'),
#  ('skateboard', 'frisbee'),
#  ('skateboard', 'skis'),
#  ('skateboard', 'snowboard'),
#  ('skateboard', 'surfboard'),
#  ('skateboard', 'ball'),
#  ('skateboard', 'bat'),
#  ('surfboard', 'snowboard'),
#  ('surfboard', 'kite'),
#  ('surfboard', 'skateboard'),
#  ('surfboard', 'glove'),
#  ('surfboard', 'racket'),
#  ('ball', 'frisbee'),
#  ('ball', 'snowboard'),
#  ('ball', 'bat'),
#  ('ball', 'racket'),
#  ('bat', 'frisbee'),
#  ('bat', 'skis'),
#  ('bat', 'snowboard'),
#  ('bat', 'skateboard'),
#  ('bat', 'surfboard'),
#  ('bat', 'ball'),
#  ('bat', 'glove'),
#  ('bat', 'racket'),
#  ('glove', 'frisbee'),
#  ('glove', 'skis'),
#  ('glove', 'snowboard'),
#  ('glove', 'kite'),
#  ('glove', 'ball'),
#  ('glove', 'racket'),
#  ('racket', 'frisbee'),
#  ('racket', 'snowboard'),
#  ('racket', 'kite'),
#  ('racket', 'skateboard'),
#  ('racket', 'ball'),
#  ('racket', 'glove'),
#  ('bottle', 'fork'),
#  ('bottle', 'bowl'),
#  ('bottle', 'glass'),
#  ('cup', 'fork'),
#  ('cup', 'knife'),
#  ('cup', 'spoon'),
#  ('fork', 'bottle'),
#  ('fork', 'spoon'),
#  ('fork', 'glass'),
#  ('knife', 'bowl'),
#  ('knife', 'glass'),
#  ('spoon', 'bottle'),
#  ('spoon', 'fork'),
#  ('spoon', 'bowl'),
#  ('bowl', 'bottle'),
#  ('bowl', 'knife'),
#  ('bowl', 'spoon'),
#  ('bowl', 'glass'),
#  ('glass', 'knife'),
#  ('glass', 'bowl'),
#  ('banana', 'apple'),
#  ('banana', 'orange'),
#  ('banana', 'carrot'),
#  ('banana', 'donut'),
#  ('banana', 'cake'),
#  ('apple', 'orange'),
#  ('apple', 'carrot'),
#  ('apple', 'donut'),
#  ('sandwich', 'apple'),
#  ('sandwich', 'broccoli'),
#  ('sandwich', 'carrot'),
#  ('sandwich', 'pizza'),
#  ('orange', 'banana'),
#  ('orange', 'apple'),
#  ('orange', 'broccoli'),
#  ('orange', 'carrot'),
#  ('orange', 'pizza'),
#  ('orange', 'donut'),
#  ('broccoli', 'banana'),
#  ('broccoli', 'pizza'),
#  ('carrot', 'banana'),
#  ('carrot', 'apple'),
#  ('carrot', 'sandwich'),
#  ('carrot', 'broccoli'),
#  ('carrot', 'donut'),
#  ('carrot', 'cake'),
#  ('pizza', 'banana'),
#  ('pizza', 'orange'),
#  ('pizza', 'carrot'),
#  ('pizza', 'cake'),
#  ('donut', 'sandwich'),
#  ('donut', 'carrot'),
#  ('donut', 'pizza'),
#  ('donut', 'cake'),
#  ('cake', 'apple'),
#  ('cake', 'orange'),
#  ('cake', 'broccoli'),
#  ('cake', 'carrot'),
#  ('cake', 'donut'),
#  ('chair', 'bed'),
#  ('chair', 'table'),
#  ('couch', 'toilet'),
#  ('couch', 'plant'),
#  ('bed', 'couch'),
#  ('bed', 'toilet'),
#  ('bed', 'plant'),
#  ('bed', 'table'),
#  ('toilet', 'chair'),
#  ('toilet', 'couch'),
#  ('toilet', 'bed'),
#  ('toilet', 'plant'),
#  ('toilet', 'table'),
#  ('plant', 'chair'),
#  ('plant', 'bed'),
#  ('table', 'couch'),
#  ('table', 'bed'),
#  ('tv', 'laptop'),
#  ('tv', 'keyboard'),
#  ('laptop', 'mouse'),
#  ('laptop', 'keyboard'),
#  ('mouse', 'laptop'),
#  ('mouse', 'remote'),
#  ('mouse', 'keyboard'),
#  ('mouse', 'phone'),
#  ('remote', 'laptop'),
#  ('remote', 'mouse'),
#  ('remote', 'keyboard'),
#  ('remote', 'phone'),
#  ('keyboard', 'tv'),
#  ('phone', 'tv'),
#  ('phone', 'mouse'),
#  ('phone', 'remote'),
#  ('oven', 'microwave'),
#  ('oven', 'toaster'),
#  ('oven', 'sink'),
#  ('toaster', 'refrigerator'),
#  ('sink', 'microwave'),
#  ('sink', 'oven'),
#  ('sink', 'toaster'),
#  ('refrigerator', 'toaster'),
#  ('book', 'drier'),
#  ('clock', 'book'),
#  ('clock', 'scissors'),
#  ('clock', 'drier'),
#  ('vase', 'scissors'),
#  ('vase', 'drier'),
#  ('scissors', 'clock'),
#  ('scissors', 'drier'),
#  ('toothbrush', 'book'),
#  ('toothbrush', 'scissors'),
#  ('drier', 'book'),
#  ('drier', 'vase')]

# %%
len(train_pairs)
# Out:
# 251

# %%
def convert_sentence(orig_sent, orig_word, foil_word):
    #change only the tokens, not accidental ones etc.
    
    orig_list = orig_sent.split()
    
    for o in range(len(orig_list)):
        
        if orig_list[o] == orig_word:
            orig_list[o] = foil_word
            
            
    foil_sent = ''
    for o in range(len(orig_list)):
        foil_sent = foil_sent.join(orig_list)
        
        if o < len(orig_list)-1:
            foil_sent = foil_sent.join(' ')
        
    return foil_sent


def find_object_mentions(captions, obj_cat, lem, constraint_mentions):
    
    freq_words = defaultdict(int)
    
    #find the visually salient object words, ones that were mentioned multiple times in the captions
    for c in obj_cat:
        for cap in captions:
            sent = cap[0]
            for w in sent.split():
                if w.lower() == c or lem.lemmatize(w.lower()) == c: #convert to lowercase and lemmatize            
                    freq_words[c] += 1
    
    #todo: at least 2 user mentioned the word
    temp_freq_words = freq_words.copy()
    
    for f in temp_freq_words:
        if freq_words[f] < constraint_mentions:
            freq_words.pop(f)
            
    return freq_words


def generate_not_present_foil(captions, img_id, object_instances, salient_words, obj_cat, target_foil_pairs, lem):
    
    foil_pairs = []
    
    word_mode = defaultdict(list)
    #find potential foil words from the same supercategory as the salient word
    for sw in salient_words:
            for tf in target_foil_pairs:
                if tf[0] == sw:
                    potential_foil = tf[1]
                    foil_pairs.append((sw, potential_foil))
                   
    #remove the foil words that were mentioned in the captions
    
    #NEW! also check the instances set for the object annotations
    #remove object categories annotated as being present in the image
    
    obj_insts = object_instances[img_id]
    
    temp_foil_pairs = foil_pairs
    
    for fp in temp_foil_pairs:
        for c in captions:
            sent = c[0]
            for w in sent.split():
                if w.lower() == fp[1] or lem.lemmatize(w) == fp[1]:  
                    if fp in foil_pairs:
                        foil_pairs.remove(fp)
              
        for obj in obj_insts:
            if obj == fp[1]: #obj is the same as foil word
                if fp in foil_pairs:
                    foil_pairs.remove(fp)
    
    return foil_pairs

# %%
lemmatizer = WordNetLemmatizer()
word = 'mice'
print(lemmatizer.lemmatize(word))

p = inflect.engine()
print(p.plural('Mouse'))
plurals = defaultdict(str)

for obj in obj_cat:
    plurals[obj] = p.plural(obj)
# Out:
# mouse
# Mice

# %%
constraint_mentions = 2 #at least 2 caption includes that category

# %%
for tc in train_captions_per_image[322141]:
    print(tc)
salient_words = find_object_mentions(train_captions_per_image[322141], obj_cat, lemmatizer, constraint_mentions)
print()
print(salient_words)
foil_pairs = generate_not_present_foil(train_captions_per_image[203564], 203564, train_object_instances, salient_words, obj_cat, target_foil_pairs, lemmatizer)
print()
print(foil_pairs)
# Out:
# ('A room with blue walls and a white sink and door.', 49)
# ('Blue and white color scheme in a small bathroom.', 109)
# ('This is a blue and white bathroom with a wall sink and a lifesaver on the wall.', 121)
# ('A blue boat themed bathroom with a life preserver on the wall', 163)
# ('A bathroom with walls that are painted baby blue.', 250)
#
# defaultdict(<class 'int'>, {'sink': 2})
#
# [('sink', 'microwave'), ('sink', 'oven'), ('sink', 'toaster'), ('sink', 'refrigerator')]

# %%
with MosesTokenizer('en') as tokenize:
    tokenize('Hello World!')

# %%
def get_tokenized_captions(captions):
    
    tokenized_captions = []
    
    for caption in captions:
        with MosesTokenizer('en') as tokenize:
            sentence = tokenize(caption[0])
            
        #now punctuation marks are all separated
        #combine the tokens with a space between them
        new_sentence = ''
        for t in range(len(sentence)):
            new_sentence += sentence[t]
            
            if t < (len(sentence)-1):
                new_sentence += ' '
                
        temp_caption = (new_sentence, caption[1])#tokenized_caption, sentence_id
        
        tokenized_captions.append(temp_caption)
    
    return tokenized_captions

# %%
def get_tokenized_sentence(sentence):
    
    tokenized_sentence = []
    
    with MosesTokenizer('en') as tokenize:
        sentence = tokenize(caption[0])
            
        #now punctuation marks are all separated
        #combine the tokens with a space between them
        new_sentence = ''
        for t in range(len(sentence)):
            new_sentence += sentence[t]
            
            if t < (len(sentence)-1):
                new_sentence += ' '
                
       
    return new_sentence

# %%
foil_sentences= defaultdict(list)

#for each image
for tp in train_captions_per_image:
    
    print(tp)
    #all 5 captions of an image
    captions = train_captions_per_image[tp]
    
    captions = get_tokenized_captions(captions)
    
    #find the visually salient words given all captions for an image
    vis_sal_words = find_object_mentions(captions, obj_cat, lemmatizer,constraint_mentions)
    
    #find possible foil words for the captions
    
    #IMPORTANT CHANGE: target_foil_pairs to train_pairs
    #also removing visually present objects
    foil_pairs =  generate_not_present_foil(captions, tp, train_object_instances, vis_sal_words, obj_cat, test_pairs, lemmatizer)
     
    for caption in captions:
        
        sent = caption[0]
        sentid = caption[1]
        
        for w in sent.split():

            #if the word is a salient word
            if w in vis_sal_words:
                
                for fp in foil_pairs:
                    
                    #check if that word is an original word in the list of target-foil pairs
                    #convert the sentence into foil sentence 
                    #check for singular-plural form and upper,lower,title cases
                    
                    if w == fp[0]:
                        foil_sentences[tp].append([convert_sentence(sent, w, fp[1]), w , fp[1], sentid])
                        
                    elif w == fp[0].upper():
                        foil_sentences[tp].append([convert_sentence(sent, w, fp[1].upper()), w , fp[1].upper(), sentid])
                        
                    elif w == fp[0].title():    
                        foil_sentences[tp].append([convert_sentence(sent, w, fp[1].title()), w , fp[1].title(), sentid])
                        
                    elif p.singular_noun(w) == fp[0]:
                        foil_sentences[tp].append([convert_sentence(sent, w, p.plural(fp[1])), w , p.plural(fp[1]), sentid])
                        
                    elif p.singular_noun(w) == fp[0].upper():
                        foil_sentences[tp].append([convert_sentence(sent, w, p.plural(fp[1]).upper()), w , p.plural(fp[1]).upper(), sentid])
                        
                    elif p.singular_noun(w) == fp[0].title():
                        foil_sentences[tp].append([convert_sentence(sent, w, p.plural(fp[1]).title()), w , p.plural(fp[1]).title(), sentid])
# Out:
# 203564
# 322141
# 16977
# 106140
# 571635
# 301837
# 315702
# 189634
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-52-646f07f63642> in <module>()
#       8     captions = train_captions_per_image[tp]
#       9
# ---> 10     captions = get_tokenized_captions(captions)
#      11
#      12     #find the visually salient words given all captions for an image
#
# <ipython-input-50-b2aa2a497a52> in get_tokenized_captions(captions)
#       4
#       5     for caption in captions:
# ----> 6         with MosesTokenizer('en') as tokenize:
#       7             sentence = tokenize(caption[0])
#       8
#
# ~/anaconda3/lib/python3.6/site-packages/mosestokenizer/tokenizer.py in __init__(self, lang, old_version)
#      53             # -a = aggressive hyphen splitting
#      54             argv.extend(["-b", "-a"])
# ---> 55         super().__init__(argv)
#      56
#      57     def __str__(self):
#
# ~/anaconda3/lib/python3.6/site-packages/toolwrapper.py in __init__(self, argv, encoding, start, cwd, stdbuf)
#      50         self.logger = logging.getLogger(self.__class__.__name__)
#      51         if start:
# ---> 52             self.start()
#      53
#      54     def __del__(self):
#
# ~/anaconda3/lib/python3.6/site-packages/toolwrapper.py in start(self)
#      90             stdout=subprocess.PIPE,
#      91             stderr=subprocess.PIPE,
# ---> 92             cwd=self.cwd
#      93         )
#      94         self.stdin = io.TextIOWrapper(
#
# ~/anaconda3/lib/python3.6/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors)
#     707                                 c2pread, c2pwrite,
#     708                                 errread, errwrite,
# --> 709                                 restore_signals, start_new_session)
#     710         except:
#     711             # Cleanup if the child failed starting.
#
# ~/anaconda3/lib/python3.6/subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, start_new_session)
#    1273                             errread, errwrite,
#    1274                             errpipe_read, errpipe_write,
# -> 1275                             restore_signals, start_new_session, preexec_fn)
#    1276                     self._child_created = True
#    1277                 finally:
#
# KeyboardInterrupt:

# %%
foil_sentences[203564] #foil sentence, orig word, foil word

# %%
with open('train_foil_sentences_ece.json', 'w') as f:
    json.dump(foil_sentences, f)

# %%
foil_sentences_val= defaultdict(list)

#for each image
for tp in val_captions_per_image:
    
    #all 5 captions of an image
    captions = val_captions_per_image[tp]
    
    captions = get_tokenized_captions(captions)
        
    #find the visually salient words given all captions for an image
    vis_sal_words = find_object_mentions(captions, obj_cat, lemmatizer,constraint_mentions)
    
    #find possible foil words for the captions
    
    #IMPORTANT CHANGE: target_foil_pairs to test_pairs
    foil_pairs =  generate_not_present_foil(captions, tp, val_object_instances, vis_sal_words, obj_cat, test_pairs, lemmatizer)
     
    for caption in captions:
        
        sent = caption[0]
        sentid = caption[1]
        
        for w in sent.split():
            
             #if the word is a salient word
            if w in vis_sal_words:
                
                for fp in foil_pairs:
                    
                    #check if that word is an original word in the list of target-foil pairs
                    #convert the sentence into foil sentence 
                    #check for singular-plural form and upper,lower,title cases
                    
                    if w == fp[0]:
                        foil_sentences_val[tp].append([convert_sentence(sent, w, fp[1]), w , fp[1], sentid])
                        
                    elif w == fp[0].upper():
                        foil_sentences_val[tp].append([convert_sentence(sent, w, fp[1].upper()), w , fp[1].upper(), sentid])
                        
                    elif w == fp[0].title():    
                        foil_sentences_val[tp].append([convert_sentence(sent, w, fp[1].title()), w , fp[1].title(), sentid])
                        
                    elif p.singular_noun(w) == fp[0]:
                        foil_sentences_val[tp].append([convert_sentence(sent, w, p.plural(fp[1])), w , p.plural(fp[1]), sentid])
                        
                    elif p.singular_noun(w) == fp[0].upper():
                        foil_sentences_val[tp].append([convert_sentence(sent, w, p.plural(fp[1]).upper()), w , p.plural(fp[1]).upper(), sentid])
                        
                    elif p.singular_noun(w) == fp[0].title():
                        foil_sentences_val[tp].append([convert_sentence(sent, w, p.plural(fp[1]).title()), w , p.plural(fp[1]).title(), sentid])

# %%
foil_sentences_val[179765]

# %%
val_captions_per_image[179765]

# %%
with open('val_foil_sentences_ece.json', 'w') as f:
    json.dump(foil_sentences_val, f)

# %%
def coco_lookup(coco):
    
    lookup_table = defaultdict(dict)
    
    for im in coco['images']:
        
        cocoid = im['cocoid']
        
        filename = im['filename']
        filepath = im['filepath']
        
        imgid = im['imgid']
        
        sentids = im['sentids']
        
        sentences = im['sentences']
        
        lookup_table[cocoid] = {'filename' : filename, 'filepath':filepath, 'imgid': imgid, 'sentids':sentids, 'sentences':sentences}
    
    return lookup_table


with open("neuraltalk-master/data/coco/coco_dataset.json") as in_file:
    coco = json.load(in_file)

# %%
lookup = coco_lookup(coco)
print(lookup[203564]['filename'])
print(coco.keys())
print(coco['images'][0])
# Out:
# COCO_val2014_000000203564.jpg
# dict_keys(['images', 'dataset'])
# {'filepath': 'val2014', 'sentids': [770337, 771687, 772707, 776154, 781998], 'filename': 'COCO_val2014_000000391895.jpg', 'imgid': 0, 'split': 'test', 'sentences': [{'tokens': ['a', 'man', 'with', 'a', 'red', 'helmet', 'on', 'a', 'small', 'moped', 'on', 'a', 'dirt', 'road'], 'raw': 'A man with a red helmet on a small moped on a dirt road. ', 'imgid': 0, 'sentid': 770337}, {'tokens': ['man', 'riding', 'a', 'motor', 'bike', 'on', 'a', 'dirt', 'road', 'on', 'the', 'countryside'], 'raw': 'Man riding a motor bike on a dirt road on the countryside.', 'imgid': 0, 'sentid': 771687}, {'tokens': ['a', 'man', 'riding', 'on', 'the', 'back', 'of', 'a', 'motorcycle'], 'raw': 'A man riding on the back of a motorcycle.', 'imgid': 0, 'sentid': 772707}, {'tokens': ['a', 'dirt', 'path', 'with', 'a', 'young', 'person', 'on', 'a', 'motor', 'bike', 'rests', 'to', 'the', 'foreground', 'of', 'a', 'verdant', 'area', 'with', 'a', 'bridge', 'and', 'a', 'background', 'of', 'cloud', 'wreathed', 'mountains'], 'raw': 'A dirt path with a young person on a motor bike rests to the foreground of a verdant area with a bridge and a background of cloud-wreathed mountains. ', 'imgid': 0, 'sentid': 776154}, {'tokens': ['a', 'man', 'in', 'a', 'red', 'shirt', 'and', 'a', 'red', 'hat', 'is', 'on', 'a', 'motorcycle', 'on', 'a', 'hill', 'side'], 'raw': 'A man in a red shirt and a red hat is on a motorcycle on a hill side.', 'imgid': 0, 'sentid': 781998}], 'cocoid': 391895}

# %%
with open('train_foil_sentences_ece.json', 'r') as f:
    foil_sentences = json.load(f)
    
with open('val_foil_sentences_ece.json', 'r') as f:
    foil_sentences_val = json.load(f)

# %%
train_check_dataset = defaultdict(list)
train_check_dataset['dataset'] = 'train_check'

#create the dataset so that it can be utilized in NeuralTalk

for ft in foil_sentences:
    
    sentences = foil_sentences[ft]
    
    cocoid = int(ft)
    
    split = 'train'

    filename = lookup[cocoid]['filename']
    filepath = lookup[cocoid]['filepath']
    imgid = lookup[cocoid]['imgid']
    posTag = 'Original' 

    #first the original captions for this cocoid
    
    for org_cap in train_captions_per_image[cocoid]:
        
        sent = org_cap[0]
        
        sent = get_tokenized_sentence(sent)
        
        sentid = org_cap[1]
        
        #print(sent)
        changeid = 'Original'

        sentids = [sentid]

        targetfoilPair = 'Original'
        
        im_dict = defaultdict()
        
        im_dict['change_id'] = changeid
        im_dict['cocoid'] = cocoid
        im_dict['filename'] = filename
        im_dict['filepath'] = filepath
        im_dict['imgid'] = imgid
        im_dict['posTag'] = posTag
        im_dict['sentids'] = sentids
        im_dict['split'] = split
        im_dict['targetfoilPair'] = targetfoilPair


        im_sent_dict = defaultdict()
        
        im_sent_dict['imgid'] = imgid
        im_sent_dict['raw'] = sent
        im_sent_dict['sentid'] = sentid
        im_sent_dict['tokens'] = sent.split()

        im_dict['sentences'] = [im_sent_dict]
      
        train_check_dataset['images'].append(im_dict)

    c = 1 #foil counter per caption
    
    #then all the foil captions
    for s in sentences:
    
        #print(s)
        foil_sent = s[0]
        pair0 = s[1]
        pair1 = s[2]
        sentid = s[3]

        targetfoilPair = pair0 + '_' + pair1
        
        changeid = str(sentid) + '_' + str(c)
        c += 1
        sentids = [sentid]
        
        posTag = 'noun'
        
        im_dict = defaultdict()
        
        im_dict['change_id'] = changeid
        im_dict['cocoid'] = cocoid
        im_dict['filename'] = filename
        im_dict['filepath'] = filepath
        im_dict['imgid'] = imgid
        im_dict['posTag'] = posTag
        im_dict['sentids'] = sentids
        im_dict['split'] = split
        im_dict['targetfoilPair'] = targetfoilPair


        im_sent_dict = defaultdict()
        
        im_sent_dict['imgid'] = imgid
        im_sent_dict['raw'] = foil_sent
        im_sent_dict['sentid'] = sentid
        im_sent_dict['tokens'] = foil_sent.split()

        im_dict['sentences'] = [im_sent_dict]
      
        train_check_dataset['images'].append(im_dict)

# %%
train_check_dataset['images'][5]['sentences']

# %%
test_check_dataset = defaultdict(list)
test_check_dataset['dataset'] = 'test_check'

for ft in foil_sentences_val:
    
    sentences = foil_sentences_val[ft]
    
    cocoid = int(ft)
    
    split = 'test'

    filename = lookup[cocoid]['filename']
    filepath = lookup[cocoid]['filepath']
    imgid = lookup[cocoid]['imgid']
    posTag = 'Original' 

    #first the original captions for this cocoid
    
    for org_cap in val_captions_per_image[cocoid]:
        
        sent = org_cap[0]
        
        sent = get_tokenized_sentence(sent)
        
        sentid = org_cap[1]
        
        #print(sent)
        changeid = 'Original'

        sentids = [sentid]

        im_dict = defaultdict()
        
        im_dict['change_id'] = changeid
        im_dict['cocoid'] = cocoid
        im_dict['filename'] = filename
        im_dict['filepath'] = filepath
        im_dict['imgid'] = imgid
        im_dict['posTag'] = posTag
        im_dict['sentids'] = sentids
        im_dict['split'] = split
        im_dict['targetfoilPair'] = targetfoilPair


        im_sent_dict = defaultdict()
        
        im_sent_dict['imgid'] = imgid
        im_sent_dict['raw'] = sent
        im_sent_dict['sentid'] = sentid
        im_sent_dict['tokens'] = sent.split()

        im_dict['sentences'] = [im_sent_dict]
      
        test_check_dataset['images'].append(im_dict)
        

    c = 1 #foil counter per caption
    
    #then all the foil captions
    for s in sentences:
    
        #print(s)
        foil_sent = s[0]
        pair0 = s[1]
        pair1 = s[2]
        sentid = s[3]

        targetfoilPair = pair0 + '_' + pair1
        
        changeid = str(sentid) + '_' + str(c)
        c += 1
        sentids = [sentid]
        
        posTag = 'noun'
        
        im_dict = defaultdict()
        
        im_dict['change_id'] = changeid
        im_dict['cocoid'] = cocoid
        im_dict['filename'] = filename
        im_dict['filepath'] = filepath
        im_dict['imgid'] = imgid
        im_dict['posTag'] = posTag
        im_dict['sentids'] = sentids
        im_dict['split'] = split
        im_dict['targetfoilPair'] = targetfoilPair


        im_sent_dict = defaultdict()
        
        im_sent_dict['imgid'] = imgid
        im_sent_dict['raw'] = foil_sent
        im_sent_dict['sentid'] = sentid
        im_sent_dict['tokens'] = foil_sent.split()

        im_dict['sentences'] = [im_sent_dict]
      
        test_check_dataset['images'].append(im_dict)

# %%
with open('train_dataset.json', 'w') as f:
    json.dump(train_check_dataset, f)
    
with open('test_dataset.json', 'w') as f:
    json.dump(test_check_dataset, f)

# %%
with open("annotations_trainval/instances_train2017.json") as in_file:
    instances_train = json.load(in_file)

# %%
with open("annotations_trainval/instances_val2017.json") as in_file:
    instances_val = json.load(in_file)

# %%
instances_train.keys()
# Out:
# dict_keys(['info', 'licenses', 'images', 'annotations', 'categories'])

# %%
instances_train['annotations'][0]
# Out:
# {'area': 2765.1486500000005,
#  'bbox': [199.84, 200.46, 77.71, 70.88],
#  'category_id': 58,
#  'id': 156,
#  'image_id': 558840,
#  'iscrowd': 0,
#  'segmentation': [[239.97,
#    260.24,
#    222.04,
#    270.49,
#    199.84,
#    253.41,
#    213.5,
#    227.79,
#    259.62,
#    200.46,
#    274.13,
#    202.17,
#    277.55,
#    210.71,
#    249.37,
#    253.41,
#    237.41,
#    264.51,
#    242.54,
#    261.95,
#    228.87,
#    271.34]]}

# %%
for inst in instances_train['annotations']:
    if inst['image_id'] == 558840:
        print(inst['category_id'])
# Out:
# 58
# 44
# 44
# 47
# 1
# 44
# 50
# 1
# 44
# 67
# 50

# %%
for cat in instances_train['categories']:
    if cat['id']== 67:
        print(cat['supercategory'],cat['name'])
# Out:
# furniture dining table

# %%
def get_category_lookup(instances_set):
    
    category_lookup = defaultdict(lambda: defaultdict(str))
    
    for cat in instances_train['categories']:
        
        category_lookup[cat['id']] = {'name':cat['name'], 'supercategory':cat['supercategory']}
    
    return category_lookup

# %%
category_lookup = get_category_lookup(instances_train)

# %%
def get_image_object_instances(instances_set):
    
    instances = defaultdict(set)
    
    for inst in instances_set['annotations']:
        category_name_supcat = category_lookup[inst['category_id']]
        instances[inst['image_id']].add(category_name_supcat['name'])
        
    return instances

# %%
train_object_instances = get_image_object_instances(instances_train)

# %%
val_object_instances = get_image_object_instances(instances_val)

# %%
train_object_instances[558840]
# Out:
# {'bottle', 'cup', 'dining table', 'hot dog', 'person', 'spoon'}

# %%
# def get_multiword_obj(categories):
    
#     multiword_dicts = defaultdict(list)
    
#     for cat in categories:
#         name = cat['name']
        
#         words = name.split()
        
#         if len(words) > 1:
#             #multiword
            
#             first = words[0]
#             second = words[1]
#             concat_without_space = words[0] + words[1]
    
        
#             multiword_dicts[name] = [first, second, concat_without_space]
            
    
#     return multiword_dicts
    

# multiword_dicts = get_multiword_obj(test_cap['categories'])

# multiword_dicts
